# %% [markdown]
# <a href="https://colab.research.google.com/github/zahra-sharifzadeh/thesis_demo/blob/main/Ravdess/mfcc_Cnn_AE_Transformer/mfc_coefficients_two_CNNAE_Parallel_transformer_Ravdess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Setup

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os, glob
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import warnings; warnings.filterwarnings('ignore') #matplot lib complains about librosa

# %%
# needed to import dataset from google drive into colab
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# copy RAVDESS dataset from gdrive and unzip
# !cp '/content/gdrive/MyDrive/RAVDESS.zip' .
# !unzip -q RAVDESS.zip

# %% [markdown]
# ## Define features
#
# Define features as in the previous notebook on this task from my ['sklearn-audio-classification' repo](https://github.com/IliaZenkov/sklearn-audio-classification). That notebook explains the motivation behind the Mel Spectrogram and its derivative MFCC, which we use as a feature. In short, we're looking for transitions in audible pitch frequencies.
#
# **MFCCs alone provide the best accuracy in this model with training considerations in mind - and provide as good an accuracy as using chromagrams + mel spectrograms + MFCCs. We don't want extra complexity in a highly parameterized deep neural net such as this one** (unless we absolutely need it).

# %%
# RAVDESS native sample rate is 16000
sample_rate = 48000

# Mel Spectrograms are not directly used as a feature in this model
# Mel Spectrograms are used in calculating MFCCs, which are a higher-level representation of pitch transition
# MFCCs work better - left the mel spectrogram function here in case anyone wants to experiment
def feature_melspectrogram(
    waveform,
    sample_rate,
    fft = 1024,
    winlen = 512,
    window='hamming',
    hop=256,
    mels=128,
    ):

    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram = librosa.feature.melspectrogram(
        y=waveform,
        sr=sample_rate,
        n_fft=fft,
        win_length=winlen,
        window=window,
        hop_length=hop,
        n_mels=mels,
        fmax=sample_rate/2)

    # convert from power (amplitude**2) to decibels
    # necessary for network to learn - doesn't converge with raw power spectrograms
    melspectrogram = librosa.power_to_db(melspectrogram, ref=np.max)

    return melspectrogram

def feature_mfcc(
    waveform,
    sample_rate,
    n_mfcc = 40,
    fft = 1024,
    winlen = 512,
    window='hamming',
    #hop=256, # increases # of time steps; was not helpful
    mels=128
    ):

    # Compute the MFCCs for all STFT frames
    # 40 mel filterbanks (n_mfcc) = 40 coefficients
    mfc_coefficients=librosa.feature.mfcc(
        y=waveform,
        sr=sample_rate,
        n_mfcc=n_mfcc,
        n_fft=fft,
        win_length=winlen,
        window=window,
        #hop_length=hop,
        n_mels=mels,
        fmax=sample_rate/2
        )

    return mfc_coefficients

def get_features(waveforms, features, samplerate):

    # initialize counter to track progress
    file_count = 0

    # process each waveform individually to get its MFCCs
    for waveform in waveforms:
        mfccs = feature_mfcc(waveform, sample_rate)
        features.append(mfccs)
        file_count += 1
        # print progress
        print('\r'+f' Processed {file_count}/{len(waveforms)} waveforms',end='')

    # return all features from list of waveforms
    return features

def get_waveforms(file):

    # load an individual sample audio file
    # read the full 3 seconds of the file, cut off the first 0.5s of silence; native sample rate = 48k
    # don't need to store the sample rate that librosa.load returns
    waveform, _ = librosa.load(file, duration=3, offset=0.5, sr=sample_rate)

    # make sure waveform vectors are homogenous by defining explicitly
    waveform_homo = np.zeros((int(sample_rate*3,)))
    waveform_homo[:len(waveform)] = waveform

    # return a single file's waveform
    return waveform_homo

# RAVDESS dataset emotions
# shift emotions left to be 0 indexed for PyTorch
emotions_dict ={
    '0':'surprised',
    '1':'neutral',
    '2':'calm',
    '3':'happy',
    '4':'sad',
    '5':'angry',
    '6':'fearful',
    '7':'disgust'
}

# Additional attributes from RAVDESS to play with
emotion_attributes = {
    '01': 'normal',
    '02': 'strong'
}

# %% [markdown]
# ## Load Data and Extract Features
#
#
# We process each file in the dataset and extract its features.
#
# We return the waveforms and the labels (from the file names of the RAVDESS audio samples). We return the raw waveforms because we're going to do some extra processing.

# %%
# path to data for glob
data_path = '/content/Actor_*/*.wav'

def load_data():
    # features and labels
    emotions = []
    # raw waveforms to augment later
    waveforms = []
    # extra labels
    intensities, genders = [],[]
    # progress counter
    file_count = 0
    for file in glob.glob(data_path):
        # get file name with labels
        file_name = os.path.basename(file)

        # get emotion label from the sample's file
        emotion = int(file_name.split("-")[2])

        #  move surprise to 0 for cleaner behaviour with PyTorch/0-indexing
        if emotion == 8: emotion = 0 # surprise is now at 0 index; other emotion indeces unchanged

        # can convert emotion label to emotion string if desired, but
        # training on number is better; better convert to emotion string after predictions are ready
        # emotion = emotions_dict[str(emotion)]

        # get other labels we might want
        intensity = emotion_attributes[file_name.split("-")[3]]
        # even actors are female, odd are male
        if (int((file_name.split("-")[6]).split(".")[0]))%2==0:
            gender = 'female'
        else:
            gender = 'male'

        # get waveform from the sample
        waveform = get_waveforms(file)

        # store waveforms and labels
        waveforms.append(waveform)
        emotions.append(emotion)
        intensities.append(intensity) # store intensity in case we wish to predict
        genders.append(gender) # store gender in case we wish to predict

        file_count += 1
        # keep track of data loader's progress
        print('\r'+f' Processed {file_count}/{1440} audio samples',end='')

    return waveforms, emotions, intensities, genders

# %%
# load data
# init explicitly to prevent data leakage from past sessions, since load_data() appends
waveforms, emotions, intensities, genders = [],[],[],[]
waveforms, emotions, intensities, genders = load_data()
# Out:
#  Processed 1440/1440 audio samples

# %% [markdown]
# ## Check extracted audio waveforms and labels:

# %%
print(f'Waveforms set: {len(waveforms)} samples')
# we have 1440 waveforms but we need to know their length too; should be 3 sec * 48k = 144k
print(f'Waveform signal length: {len(waveforms[0])}')
print(f'Emotions set: {len(emotions)} sample labels')
# Out:
# Waveforms set: 1440 samples
# Waveform signal length: 144000
# Emotions set: 1440 sample labels

# %% [markdown]
# Looks good. 1440 samples and 1440 labels in total.
#
# **Waveforms are 144k long because 3 seconds * 48k sample rate = 144k length array representing the 3 second audio snippet.**

# %% [markdown]
# ## Split into Train/Validation/Test Sets
# We'll use an 80/10/10 train/validation/test split to maximize training data and keep a reasonable validation/test set.
#
# **We're splitting waveforms so we can process train/validation/test waveforms separately and avoid data leakage.**
#
# **Have to take care to split the sets proportionally w.r.t. emotion.**
#
# **Yes, we can use sklearn - but to convince myself I've eradicated data leakage issues I did this manually.**

# %%
# create storage for train, validation, test sets and their indices
train_set,valid_set,test_set = [],[],[]
X_train,X_valid,X_test = [],[],[]
y_train,y_valid,y_test = [],[],[]

# convert waveforms to array for processing
waveforms = np.array(waveforms)

# process each emotion separately to make sure we builf balanced train/valid/test sets
for emotion_num in range(len(emotions_dict)):

    # find all indices of a single unique emotion
    emotion_indices = [index for index, emotion in enumerate(emotions) if emotion==emotion_num]

    # seed for reproducibility
    np.random.seed(69)
    # shuffle indicies
    emotion_indices = np.random.permutation(emotion_indices)

    # store dim (length) of the emotion list to make indices
    dim = len(emotion_indices)

    # store indices of training, validation and test sets in 80/10/10 proportion
    # train set is first 80%
    train_indices = emotion_indices[:int(0.8*dim)]
    # validation set is next 10% (between 80% and 90%)
    valid_indices = emotion_indices[int(0.8*dim):int(0.9*dim)]
    # test set is last 10% (between 90% - end/100%)
    test_indices = emotion_indices[int(0.9*dim):]

    # create train waveforms/labels sets
    X_train.append(waveforms[train_indices,:])
    y_train.append(np.array([emotion_num]*len(train_indices),dtype=np.int32))
    # create validation waveforms/labels sets
    X_valid.append(waveforms[valid_indices,:])
    y_valid.append(np.array([emotion_num]*len(valid_indices),dtype=np.int32))
    # create test waveforms/labels sets
    X_test.append(waveforms[test_indices,:])
    y_test.append(np.array([emotion_num]*len(test_indices),dtype=np.int32))

    # store indices for each emotion set to verify uniqueness between sets
    train_set.append(train_indices)
    valid_set.append(valid_indices)
    test_set.append(test_indices)

# concatenate, in order, all waveforms back into one array
X_train = np.concatenate(X_train,axis=0)
X_valid = np.concatenate(X_valid,axis=0)
X_test = np.concatenate(X_test,axis=0)

# concatenate, in order, all emotions back into one array
y_train = np.concatenate(y_train,axis=0)
y_valid = np.concatenate(y_valid,axis=0)
y_test = np.concatenate(y_test,axis=0)

# combine and store indices for all emotions' train, validation, test sets to verify uniqueness of sets
train_set = np.concatenate(train_set,axis=0)
valid_set = np.concatenate(valid_set,axis=0)
test_set = np.concatenate(test_set,axis=0)

# check shape of each set
print(f'Training waveforms:{X_train.shape}, y_train:{y_train.shape}')
print(f'Validation waveforms:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'Test waveforms:{X_test.shape}, y_test:{y_test.shape}')

# make sure train, validation, test sets have no overlap/are unique
# get all unique indices across all sets and how many times each index appears (count)
uniques, count = np.unique(np.concatenate([train_set,test_set,valid_set],axis=0), return_counts=True)

# if each index appears just once, and we have 1440 such unique indices, then all sets are unique
if sum(count==1) == len(emotions):
    print(f'\nSets are unique: {sum(count==1)} samples out of {len(emotions)} are unique')
else:
    print(f'\nSets are NOT unique: {sum(count==1)} samples out of {len(emotions)} are unique')
# Out:
# Training waveforms:(1147, 144000), y_train:(1147,)
# Validation waveforms:(143, 144000), y_valid:(143,)
# Test waveforms:(150, 144000), y_test:(150,)
#
# Sets are unique: 1440 samples out of 1440 are unique

# %% [markdown]
# ## Extract Features

# %% [markdown]
# Extract the features from unaugmented waveforms first. In the next step, we'll append features from augmented waveforms to these 'native' features.

# %%
# initialize feature arrays
# We extract MFCC features from waveforms and store in respective 'features' array
features_train, features_valid, features_test = [],[],[]

print('Train waveforms:') # get training set features
features_train = get_features(X_train, features_train, sample_rate)

print('\n\nValidation waveforms:') # get validation set features
features_valid = get_features(X_valid, features_valid, sample_rate)

print('\n\nTest waveforms:') # get test set features
features_test = get_features(X_test, features_test, sample_rate)

print(f'\n\nFeatures set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'Features (MFC coefficient matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
#  Processed 1147/1147 waveforms
#
# Validation waveforms:
#  Processed 143/143 waveforms
#
# Test waveforms:
#  Processed 150/150 waveforms
#
# Features set: 1440 total, 1147 train, 143 validation, 150 test samples
# Features (MFC coefficient matrix) shape: 40 mel frequency coefficients x 282 time steps

# %% [markdown]
# ## Augmenting the Data with AWGN - Additive White Gaussian Noise
#
# ### Motivation
#
# Since our dataset is small, it is prone to overfitting - especially with highly parameterized deep neural net models
# such as the one we aim to build in this notebook. As such, we're going to want to augment our data. Generating more real samples will be immensely difficult. Instead, we can add white noise to the audio signals - not only to mask the effect of random noise present in the training set - but also **to create pseudo-new training samples and offset the impact of noise intrinsic to the dataset.**
#
# In addition, the RAVDESS dataset is extremely clean - we will likely want to make predictions on noisy, real-world data - yet another reason to augment the training data.
#
# We're going to use Additive White Gaussian Noise (AWGN). It's Additive because we're adding it to the source audio signal,
# **it's Gaussian because the noise vector will be sampled from a normal distribution and have a time average of zero (zero-mean), and it's white because after a whitening transformation the noise will add power to the audio signal uniformly across the frequency distribution.**
#
# We need a good balance of noise - too little will be useless, and too much will make it too difficult for the network to learn from the training data. **Note that this is just for training - we would _not_ need to add AWGN to real-world data on which we make predictions** (although we could).
#
# ### Math
# The key parameters in AWGN are the signal to noise ratio (SNR), defining the magnitude of the noise added w.r.t. the audio signal. We parameterize AWGN with the minimum and maximize SNR so we can pick a random SNR to use in augmenting each sample's waveform.
#
# We need to constrain covariance to make it true AWGN. **We make a zero-mean vector of Gaussian noises (np.random.normal) that are statistically dependent. We need to apply a [whitening transformation](https://en.wikipedia.org/wiki/Whitening_transformation)**, a linear transformation taking a vector of random normal (Gaussian) variables with a known covariance matrix and mapping it to a new vector whose covariance is the identity matrix, i.e. the vector is now perfectly uncorrelated with a diaganol covariance matrix, each point of noise having variance == stdev == 1. **The whitening transformation by definition transforms a vector into a white noise vector.**
#
# We're going to add the AWGN augmented waveforms as new samples to our dataset. **Since we generate AWGN which is random for each and every sample - random random noise - we can add multiples of our noise-augmented dataset. I'll add 2 extra identical, randomly noisy datasets with 1440 samples each to get a dataset with 1440 native + 1440x2 == 4320 noisy samples.**

# %%
def awgn_augmentation(waveform, multiples=2, bits=16, snr_min=15, snr_max=30):

    # get length of waveform (should be 3*48k = 144k)
    wave_len = len(waveform)

    # Generate normally distributed (Gaussian) noises
    # one for each waveform and multiple (i.e. wave_len*multiples noises)
    noise = np.random.normal(size=(multiples, wave_len))

    # Normalize waveform and noise
    norm_constant = 2.0**(bits-1)
    norm_wave = waveform / norm_constant
    norm_noise = noise / norm_constant

    # Compute power of waveform and power of noise
    signal_power = np.sum(norm_wave ** 2) / wave_len
    noise_power = np.sum(norm_noise ** 2, axis=1) / wave_len

    # Choose random SNR in decibels in range [15,30]
    snr = np.random.randint(snr_min, snr_max)

    # Apply whitening transformation: make the Gaussian noise into Gaussian white noise
    # Compute the covariance matrix used to whiten each noise
    # actual SNR = signal/noise (power)
    # actual noise power = 10**(-snr/10)
    covariance = np.sqrt((signal_power / noise_power) * 10 ** (- snr / 10))
    # Get covariance matrix with dim: (144000, 2) so we can transform 2 noises: dim (2, 144000)
    covariance = np.ones((wave_len, multiples)) * covariance

    # Since covariance and noise are arrays, * is the haddamard product
    # Take Haddamard product of covariance and noise to generate white noise
    multiple_augmented_waveforms = waveform + covariance.T * noise

    return multiple_augmented_waveforms

# %%
def augment_waveforms(waveforms, features, emotions, multiples):
    # keep track of how many waveforms we've processed so we can add correct emotion label in the same order
    emotion_count = 0
    # keep track of how many augmented samples we've added
    added_count = 0
    # convert emotion array to list for more efficient appending
    emotions = emotions.tolist()

    for waveform in waveforms:

        # Generate 2 augmented multiples of the dataset, i.e. 1440 native + 1440*2 noisy = 4320 samples total
        augmented_waveforms = awgn_augmentation(waveform, multiples=multiples)

        # compute spectrogram for each of 2 augmented waveforms
        for augmented_waveform in augmented_waveforms:

            # Compute MFCCs over augmented waveforms
            augmented_mfcc = feature_mfcc(augmented_waveform, sample_rate=sample_rate)

            # append the augmented spectrogram to the rest of the native data
            features.append(augmented_mfcc)
            emotions.append(emotions[emotion_count])

            # keep track of new augmented samples
            added_count += 1

            # check progress
            print('\r'+f'Processed {emotion_count + 1}/{len(waveforms)} waveforms for {added_count}/{len(waveforms)*multiples} new augmented samples',end='')

        # keep track of the emotion labels to append in order
        emotion_count += 1

        # store augmented waveforms to check their shape
        augmented_waveforms_temp.append(augmented_waveforms)

    return features, emotions

# %% [markdown]
# ### Compute AWGN-augmented features and add to the rest of the dataset

# %%
# store augmented waveforms to verify their shape and random-ness
augmented_waveforms_temp = []

# specify multiples of our dataset to add as augmented data
multiples = 2

print('Train waveforms:') # augment waveforms of training set
features_train , y_train = augment_waveforms(X_train, features_train, y_train, multiples)

print('\n\nValidation waveforms:') # augment waveforms of validation set
features_valid, y_valid = augment_waveforms(X_valid, features_valid, y_valid, multiples)

print('\n\nTest waveforms:') # augment waveforms of test set
features_test, y_test = augment_waveforms(X_test, features_test, y_test, multiples)

# Check new shape of extracted features and data:
print(f'\n\nNative + Augmented Features set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'{len(y_train)} training sample labels, {len(y_valid)} validation sample labels, {len(y_test)} test sample labels')
print(f'Features (MFCC matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
# Processed 1147/1147 waveforms for 2294/2294 new augmented samples
#
# Validation waveforms:
# Processed 143/143 waveforms for 286/286 new augmented samples
#
# Test waveforms:
# Processed 150/150 waveforms for 300/300 new augmented samples
#
# Native + Augmented Features set: 4320 total, 3441 train, 429 validation, 450 test samples
# 3441 training sample labels, 429 validation sample labels, 450 test sample labels
# Features (MFCC matrix) shape: 40 mel frequency coefficients x 282 time steps

# %% [markdown]
# ### Check Augmented Waveforms:

# %%
# pick a random waveform, but same one from native and augmented set for easier comparison
plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveshow(waveforms[12], sr=sample_rate)
plt.title('Native')

plt.subplot(1, 2, 2)
# augmented waveforms are 2D len 1440 list with 2 waveforms in each position
librosa.display.waveshow(augmented_waveforms_temp[0][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveshow(augmented_waveforms_temp[2][0], sr=sample_rate)
plt.title('AWGN Augmented')

plt.subplot(1, 2, 2)
librosa.display.waveshow(augmented_waveforms_temp[7][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

# %% [markdown]
# Looks noisy alright. Noise is clearly visible in otherwise-silent regions of the waveform. We can see the variability of the noise, which should have an SNR between 15 and 30.
#
# **Note that augmentation was only done after splitting data into train, validation, and test sets - and we processed each set separately.**
#
# **When we augmented the data before splitting it, test and validation data leaked into the training set giving a 97% test accuracy after training.**
#
# ## Format Data into Tensor Ready 4D Arrays
# We don't have a colour channel in our MFCC feature array of dim (#samples, #MFC coefficients, time steps). **We have an analog of a black and white image: instead of 3 colour channels, we have 1 signal intensity channel: magnitude of each of 40 mel frequency coefficients at time t.**
#
# **We need an input channel dim to expand to output channels using CNN filters. We create a dummy channel dim to expand features into 2D-CNN-ready 4D tensor format: N x C x H x W.**

# %%
# need to make dummy input channel for CNN input feature tensor
X_train = np.expand_dims(features_train,1)
X_valid = np.expand_dims(features_valid, 1)
X_test = np.expand_dims(features_test,1)

# convert emotion labels from list back to numpy arrays for PyTorch to work with
y_train = np.array(y_train)
y_valid = np.array(y_valid)
y_test = np.array(y_test)

# confiorm that we have tensor-ready 4D data array
# should print (batch, channel, width, height) == (4320, 1, 128, 282) when multiples==2
print(f'Shape of 4D feature array for input tensor: {X_train.shape} train, {X_valid.shape} validation, {X_test.shape} test')
print(f'Shape of emotion labels: {y_train.shape} train, {y_valid.shape} validation, {y_test.shape} test')
# Out:
# Shape of 4D feature array for input tensor: (3441, 1, 40, 282) train, (429, 1, 40, 282) validation, (450, 1, 40, 282) test
# Shape of emotion labels: (3441,) train, (429,) validation, (450,) test

# %%
# free up some RAM - no longer need full feature set or any waveforms
del features_train, features_valid, features_test, waveforms, augmented_waveforms_temp

# %% [markdown]
# ## Feature Scaling
# Scaling will drastically decrease the length of time the model needs to train to convergence - it will have easier computations to perform on smaller magnitudes. **For reference, scaling reduces the time to convergence from about 500 to 200 epochs for this model.**
#
# **Standard Scaling makes the most sense because we have features whose target distribution we don't know.** When I performed classification on this dataset with an MLP classifier standard scaling was best across a variety of conditions and features.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

#### Scale the training data ####
# store shape so we can transform it back
N,C,H,W = X_train.shape
# Reshape to 1D because StandardScaler operates on a 1D array
# tell numpy to infer shape of 1D array with '-1' argument
X_train = np.reshape(X_train, (N,-1))
X_train = scaler.fit_transform(X_train)
# Transform back to NxCxHxW 4D tensor format
X_train = np.reshape(X_train, (N,C,H,W))

##### Scale the validation set ####
N,C,H,W = X_valid.shape
X_valid = np.reshape(X_valid, (N,-1))
X_valid = scaler.transform(X_valid)
X_valid = np.reshape(X_valid, (N,C,H,W))

#### Scale the test set ####
N,C,H,W = X_test.shape
X_test = np.reshape(X_test, (N,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, (N,C,H,W))

# check shape of each set again
print(f'X_train scaled:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid scaled:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test scaled:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train scaled:(3441, 1, 40, 282), y_train:(3441,)
# X_valid scaled:(429, 1, 40, 282), y_valid:(429,)
# X_test scaled:(450, 1, 40, 282), y_test:(450,)

# %% [markdown]
# ## Save and Reload Data as NumPy Arrays
# We can save the training/validation/test data as numpy arrays to enable faster loading in case the notebook kernel crashes / google colab runtime crashes / any number of reasons the training data might be cleared from memory. This is much faster than loading 1440 files and computing their features again - not to mention augmented features.

# %%
###### SAVE #########
# choose save file name
filename = 'features+labels.npy'

# open file in write mode and write data
with open(filename, 'wb') as f:
    np.save(f, X_train)
    np.save(f, X_valid)
    np.save(f, X_test)
    np.save(f, y_train)
    np.save(f, y_valid)
    np.save(f, y_test)

print(f'Features and labels saved to {filename}')
# Out:
# Features and labels saved to features+labels.npy

# %%
##### LOAD #########
# choose load file name
filename = 'features+labels.npy'

# open file in read mode and read data
with open(filename, 'rb') as f:
    X_train = np.load(f)
    X_valid = np.load(f)
    X_test = np.load(f)
    y_train = np.load(f)
    y_valid = np.load(f)
    y_test = np.load(f)

# Check that we've recovered the right data
print(f'X_train:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train:(3441, 1, 40, 282), y_train:(3441,)
# X_valid:(429, 1, 40, 282), y_valid:(429,)
# X_test:(450, 1, 40, 282), y_test:(450,)

# %%
X_train.min()
# Out:
# -10.010025860145177

# %%
import torch
import torch.nn as nn

class Encoder1(nn.Module):
    def __init__(self):
        super(Encoder1, self).__init__()

        self.encoder1 = nn.Sequential(
            # 1st 2D convolution layer
            nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(16),
            nn.SELU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),

            # 2nd 2D convolution layer
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.SELU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),

            # 3rd 2D convolution layer
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.SELU(),
            nn.MaxPool2d(kernel_size=4, stride=4)
        )

    def forward(self, x):
        return self.encoder1(x)

# %%
class Decoder1(nn.Module):
    def __init__(self):
        super(Decoder1, self).__init__()

        self.decoder1 = nn.Sequential(
            # 1st 2D transpose convolution layer
            nn.ConvTranspose2d(64, 32, kernel_size=5, stride=(1, 4), padding=0, output_padding=(0, 2)),
            nn.BatchNorm2d(32),
            nn.SELU(),

            # 2nd 2D transpose convolution layer
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=4, padding=0, output_padding=(1, 2)),
            nn.BatchNorm2d(16),
            nn.SELU(),

            # 3rd 2D transpose convolution layer
            nn.ConvTranspose2d(16, 1, kernel_size=3, stride=2, padding=1, output_padding=1)
        )

    def forward(self, x):
        return self.decoder1(x)

# %%
class Autoencoder1(nn.Module):
    def __init__(self):
        super(Autoencoder1, self).__init__()
        self.encoder = Encoder1()
        self.decoder = Decoder1()

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return encoded, decoded

# %%
# Example usage
autoencoder = Autoencoder1()
input_data = torch.randn(1, 1, 40, 282)  # Replace with your input shape
encoded1, decoded1 = autoencoder(input_data)
encoded1.shape, decoded1.shape
# Out:
# (torch.Size([1, 64, 1, 8]), torch.Size([1, 1, 40, 282]))

# %%
import torch.nn as nn

class Encoder2(nn.Module):
    def __init__(self):
        super(Encoder2, self).__init__()

        # Define the 2D convolutional layers
        self.conv2Dblock = nn.Sequential(
            # 1st 2D convolution layer
            nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(16),
            nn.SELU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),

            # 2nd 2D convolution layer
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.SELU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),

            # 3rd 2D convolution layer
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.SELU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3)
        )

    def forward(self, x):
        # Pass the input through the convolutional layers
        return self.conv2Dblock(x)

# %%
import torch.nn as nn

class Decoder2(nn.Module):
    def __init__(self):
        super(Decoder2, self).__init__()

        # Define the 2D transposed convolutional layers for the decoder
        self.decoder2 = nn.Sequential(
            # 1st 2D transposed convolution layer
            nn.ConvTranspose2d(64, 32, kernel_size=5, stride=(1, 4), padding=0, output_padding=(0, 2)),
            nn.BatchNorm2d(32),
            nn.SELU(),

            # 2nd 2D transposed convolution layer
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=4, padding=0, output_padding=(1, 2)),
            nn.BatchNorm2d(16),
            nn.SELU(),

            # 3rd 2D transposed convolution layer
            nn.ConvTranspose2d(16, 1, kernel_size=3, stride=2, padding=1, output_padding=1)
        )

    def forward(self, x):
        # Pass the input through the decoder's transposed convolutional layers
        return self.decoder2(x)

# %%
import torch.nn as nn

class Autoencoder2(nn.Module):
    def __init__(self):
        super(Autoencoder2, self).__init__()

        # Define the encoder and decoder
        self.encoder = Encoder2()
        self.decoder = Decoder2()

    def forward(self, x):
        # Encode the input
        encoded = self.encoder(x)

        # Decode the encoded representation
        decoded = self.decoder(encoded)

        return encoded, decoded
# Example usage
autoencoder2 = Autoencoder2()
input_data = torch.randn(1, 1, 40, 282)  # Replace with your input shape
encoded2, decoded2 = autoencoder2(input_data)
encoded2.shape, decoded2.shape
# Out:
# (torch.Size([1, 64, 1, 8]), torch.Size([1, 1, 40, 282]))

# %%
import torch.nn as nn

class TransformerBlock(nn.Module):
    def __init__(self):
        super(TransformerBlock, self).__init__()

        # Maxpool the input feature map/tensor to the transformer
        self.transformer_maxpool = nn.MaxPool2d(kernel_size=[1, 4], stride=[1, 4])

        # Define a single transformer encoder layer
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=40,            # Input feature (frequency) dim after max-pooling: 40*282 -> 40*70 (MFC * time)
            nhead=4,               # Number of self-attention layers in each multi-head self-attention layer in each encoder block
            dim_feedforward=512,   # Dimension for the feedforward network in each encoder block: 40 -> 512 -> 40
            dropout=0.4,
            activation='relu'      # Activation function (e.g., ReLU) for feedforward network
        )

        # The complete transformer block contains 4 full transformer encoder layers
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=4)

    def forward(self, x):


                ########## 4-encoder-layer Transformer block w/ 40-->512-->40 feedfwd network ##############
        # maxpool input feature map: 1*40*282 w/ 1*4 kernel --> 1*40*70
        x_maxpool = self.transformer_maxpool(x)

        # remove channel dim: 1*40*70 --> 40*70
        x_maxpool_reduced = torch.squeeze(x_maxpool,1)

        # convert maxpooled feature map format: batch * freq * time ---> time * batch * freq format
        # because transformer encoder layer requires tensor in format: time * batch * embedding (freq)
        x = x_maxpool_reduced.permute(2,0,1)

        # finally, pass reduced input feature map x into transformer encoder layers
        transformer_output = self.transformer_encoder(x)

        # create final feature emedding from transformer layer by taking mean in the time dimension (now the 0th dim)
        # transformer outputs 2x40 (MFCC embedding*time) feature map, take mean of columns i.e. take time average
        transformer_embedding = torch.mean(transformer_output, dim=0) # dim 40x70 --> 40
        return transformer_embedding

# You can use this TransformerBlock within your larger model as needed.

# %%
import torch.nn as nn

class EmotionClassifier(nn.Module):
    def __init__(self, num_emotions):
        super(EmotionClassifier, self).__init__()

        # Linear softmax layer to take the final concatenated embedding tensor
        # from parallel 2D convolutional and transformer blocks, output 8 logits
        # Each full convolution block outputs (64*1*8) embedding flattened to dim 512 1D array
        # Full transformer block outputs 40*70 feature map, which we time-avg to dim 40 1D array
        # 512*2 + 40 == 1064 input features --> 8 output emotions
        self.fc1_linear = nn.Linear(512*2 + 40, num_emotions)

        # Softmax layer for the 8 output logits from the final FC linear layer
        self.softmax_out = nn.Softmax(dim=1)  # dim==1 refers to the frequency embedding

    def forward(self,x):

        # Pass the concatenated features through the final linear layer
        output = self.fc1_linear(x)

        # Apply softmax to get the class probabilities
        class_probs = self.softmax_out(output)

        return output , class_probs

# You can use this EmotionClassifier as part of your larger model to perform emotion classification.

# %%
# Combine the models
class MultiTaskModel(nn.Module):
    def __init__(self,num_emotions):
        super(MultiTaskModel, self).__init__()
        self.autoencoder1 = Autoencoder1()
        self.autoencoder2 = Autoencoder2()
        self.transformerblock = TransformerBlock()
        self.emotion_classifier = EmotionClassifier(num_emotions)

    def forward(self, x):
        encoded1, decoded1 = self.autoencoder1(x)
        encoded1_embedding1 = torch.flatten(encoded1, start_dim=1)

        encoded2, decoded2= self.autoencoder2(x)
        encoded2_embedding2 = torch.flatten(encoded2, start_dim=1)

        transformer_embedding = self.transformerblock(x)

        complete_embedding = torch.cat([encoded1_embedding1, encoded2_embedding2,transformer_embedding], dim=1)

        output_logits, output_softmax = self.emotion_classifier(complete_embedding)

        return decoded1, decoded2, output_logits, output_softmax

# %%
# Example usage
model = MultiTaskModel(num_emotions=8)
input_data = torch.randn(1, 1, 40, 282)  # Replace with your input shape
decoded1, decoded2, output_logits, output_softmax = model(input_data)
decoded1.shape, decoded2.shape, output_logits, output_softmax
# Out:
# (torch.Size([1, 1, 40, 282]),
#  torch.Size([1, 1, 40, 282]),
#  tensor([[ 1.5953, -2.8805, -0.3941,  0.1263, -0.9326,  0.1070,  0.7617,  0.0846]],
#         grad_fn=<AddmmBackward0>),
#  tensor([[0.4275, 0.0049, 0.0585, 0.0984, 0.0341, 0.0965, 0.1858, 0.0944]],
#         grad_fn=<SoftmaxBackward0>))

# %%
# Loss functions
autoencoder_criterion = nn.MSELoss()  # Use Mean Squared Error for autoencoder loss
classifier_criterion = nn.CrossEntropyLoss()  # Use Cross-Entropy for emotion classification loss
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# %%
# define function to create a single step of the training phase
def make_train_step(model, autoencoder_criterion, classifier_criterion, optimizer):

    # define the training step of the training phase
    def train_step(X,Y):

        # forward pass
        decoded1, decoded2, output_logits, output_softmax  = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))

        # Compute losses
        autoencoder_loss1 = autoencoder_criterion(decoded1, X)
        autoencoder_loss2 = autoencoder_criterion(decoded2, X)
        classifier_loss = classifier_criterion(output_logits, Y)

        # Define a trade-off parameter to balance losses
        tradeoff = 0.4 # Adjust as needed

        # Calculate the combined loss
        loss = tradeoff * (autoencoder_loss1 + autoencoder_loss2) + (1 - tradeoff) * classifier_loss

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100, autoencoder_loss1.item(), autoencoder_loss2.item(), classifier_loss.item()
    return train_step

# %%
def make_validate_fnc(model,autoencoder_criterion, classifier_criterion):
    def validate(X,Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()

            # get the model's predictions on the validation set
            decoded1, decoded2, output_logits, output_softmax  = model(X)
            predictions = torch.argmax(output_softmax,dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y==predictions)/float(len(Y))

            # Compute losses
            autoencoder_loss1 = autoencoder_criterion(decoded1, X)
            autoencoder_loss2 = autoencoder_criterion(decoded2, X)
            classifier_loss = classifier_criterion(output_logits, Y)

            # compute error from logits (nn.crossentropy implements softmax)
            # Define a trade-off parameter to balance losses
            tradeoff = 0.4 # Adjust as needed

            # Calculate the combined loss
            loss = tradeoff * (autoencoder_loss1 + autoencoder_loss2) + (1 - tradeoff) * classifier_loss


        return loss.item(), accuracy*100, autoencoder_loss1.item(), autoencoder_loss2.item(), classifier_loss.item(), predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint

def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
# get training set size to calculate # iterations and minibatch indices
train_size = X_train.shape[0]

# pick minibatch size (of 32... always)
minibatch = 32

# set device to GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'{device} selected')
# Out:
# cuda selected

# %%
# instantiate model and move to GPU for training
model = MultiTaskModel(num_emotions=len(emotions_dict)).to(device)
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )
# Out:
# Number of trainable params:  360682

# %%
# encountered bugs in google colab only, unless I explicitly defined optimizer in this cell...
optimizer = torch.optim.SGD(model.parameters(),lr=0.0001, weight_decay=1e-3, momentum=0.8)
# Loss functions
autoencoder_criterion = nn.MSELoss()  # Use Mean Squared Error for autoencoder loss
classifier_criterion = nn.CrossEntropyLoss()  # Use Cross-Entropy for emotion classification loss

# %%
# instantiate the checkpoint save function
save_checkpoint = make_save_checkpoint()

# instantiate the training step function
train_step = make_train_step(model, autoencoder_criterion, classifier_criterion, optimizer=optimizer)

# instantiate the validation loop function
validate = make_validate_fnc(model,autoencoder_criterion, classifier_criterion)

# %%
# instantiate lists to hold scalar performance metrics to plot later
train_losses=[]
valid_losses = []
train_autoencoder_losses1=[]
train_autoencoder_losses2=[]
train_classifier_losses=[]


valid_autoencoder_losses1=[]
valid_autoencoder_losses2=[]
valid_classifier_losses=[]

# %%
# create training loop for one complete epoch (entire training set)
def train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid):

    for epoch in range(num_epochs):

        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices,:,:,:]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        epoch_autoencoder_loss1 = 0
        epoch_autoencoder_loss2 = 0
        epoch_classifier_loss = 0




        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end,:,:,:]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]

            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc, autoencoder_loss1, autoencoder_loss2, classifier_loss = train_step(X_tensor,Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size
            epoch_autoencoder_loss1 += autoencoder_loss1 * actual_batch_size / train_size
            epoch_autoencoder_loss2 += autoencoder_loss2 * actual_batch_size / train_size
            epoch_classifier_loss += classifier_loss * actual_batch_size / train_size



            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}',end='')

        # create tensors from validation set
        X_valid_tensor = torch.tensor(X_valid,device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)

        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, valid_autoencoder_loss1, valid_autoencoder_loss2, valid_classifier_loss, _ = validate(X_valid_tensor,
                                                                                                                     Y_valid_tensor)

        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        train_autoencoder_losses1.append(epoch_autoencoder_loss1)
        train_autoencoder_losses2.append(epoch_autoencoder_loss2)
        train_classifier_losses.append(epoch_classifier_loss)

        valid_losses.append(valid_loss)
        valid_autoencoder_losses1.append(valid_autoencoder_loss1)
        valid_autoencoder_losses2.append(valid_autoencoder_loss2)
        valid_classifier_losses.append(valid_classifier_loss)


        # Save checkpoint of the model
        checkpoint_filename = '/content/parallel_all_you_wantFINAL.pkl'.format(epoch)
        save_checkpoint(optimizer, model, epoch, checkpoint_filename)

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')
        print(f'\nEpoch {epoch} --- epoch_autoencoder_loss1:{epoch_autoencoder_loss1:.3f}, epoch_autoencoder_loss2:{epoch_autoencoder_loss2:.2f}, epoch_classifier_loss:{epoch_classifier_loss:.3f}')
        print(f'\nEpoch {epoch} --- valid_autoencoder_loss1:{valid_autoencoder_loss1:.3f}, valid_autoencoder_loss2:{valid_autoencoder_loss2:.2f}, valid_classifier_loss:{valid_classifier_loss:.3f}\n\n')

# %%
# choose number of epochs higher than reasonable so we can manually stop training
num_epochs = 500

# train it!
train(optimizer, model, num_epochs, X_train, y_train, X_valid, y_valid)
# Out:
# Epoch 0: iteration 106/107
# Epoch 0 --- loss:0.777, Epoch accuracy:98.72%, Validation loss:1.233, Validation accuracy:75.52%
#
# Epoch 0 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.060
#
# Epoch 0 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.822
#
#
# Epoch 1: iteration 106/107
# Epoch 1 --- loss:0.774, Epoch accuracy:98.78%, Validation loss:1.237, Validation accuracy:75.52%
#
# Epoch 1 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 1 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.829
#
#
# Epoch 2: iteration 106/107
# Epoch 2 --- loss:0.775, Epoch accuracy:98.95%, Validation loss:1.234, Validation accuracy:76.22%
#
# Epoch 2 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 2 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.824
#
#
# Epoch 3: iteration 106/107
# Epoch 3 --- loss:0.778, Epoch accuracy:98.55%, Validation loss:1.237, Validation accuracy:75.99%
#
# Epoch 3 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.063
#
# Epoch 3 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.828
#
#
# Epoch 4: iteration 106/107
# Epoch 4 --- loss:0.775, Epoch accuracy:98.87%, Validation loss:1.236, Validation accuracy:76.22%
#
# Epoch 4 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 4 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.827
#
#
# Epoch 5: iteration 106/107
# Epoch 5 --- loss:0.775, Epoch accuracy:98.87%, Validation loss:1.237, Validation accuracy:75.52%
#
# Epoch 5 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 5 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.828
#
#
# Epoch 6: iteration 106/107
# Epoch 6 --- loss:0.775, Epoch accuracy:98.95%, Validation loss:1.236, Validation accuracy:75.76%
#
# Epoch 6 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 6 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.827
#
#
# Epoch 7: iteration 106/107
# Epoch 7 --- loss:0.777, Epoch accuracy:98.75%, Validation loss:1.237, Validation accuracy:75.06%
#
# Epoch 7 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.060
#
# Epoch 7 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.829
#
#
# Epoch 8: iteration 106/107
# Epoch 8 --- loss:0.775, Epoch accuracy:98.66%, Validation loss:1.233, Validation accuracy:76.69%
#
# Epoch 8 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 8 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.822
#
#
# Epoch 9: iteration 106/107
# Epoch 9 --- loss:0.775, Epoch accuracy:98.81%, Validation loss:1.233, Validation accuracy:76.22%
#
# Epoch 9 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 9 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.822
#
#
# Epoch 10: iteration 106/107
# Epoch 10 --- loss:0.774, Epoch accuracy:98.98%, Validation loss:1.232, Validation accuracy:75.99%
#
# Epoch 10 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 10 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.820
#
#
# Epoch 11: iteration 106/107
# Epoch 11 --- loss:0.776, Epoch accuracy:98.92%, Validation loss:1.232, Validation accuracy:76.22%
#
# Epoch 11 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 11 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.819
#
#
# Epoch 12: iteration 106/107
# Epoch 12 --- loss:0.774, Epoch accuracy:98.90%, Validation loss:1.235, Validation accuracy:75.99%
#
# Epoch 12 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 12 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.825
#
#
# Epoch 13: iteration 106/107
# Epoch 13 --- loss:0.776, Epoch accuracy:98.95%, Validation loss:1.231, Validation accuracy:75.52%
#
# Epoch 13 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 13 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.819
#
#
# Epoch 14: iteration 106/107
# Epoch 14 --- loss:0.774, Epoch accuracy:98.98%, Validation loss:1.231, Validation accuracy:76.22%
#
# Epoch 14 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 14 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 15: iteration 106/107
# Epoch 15 --- loss:0.776, Epoch accuracy:98.84%, Validation loss:1.227, Validation accuracy:76.69%
#
# Epoch 15 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 15 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.813
#
#
# Epoch 16: iteration 106/107
# Epoch 16 --- loss:0.774, Epoch accuracy:98.78%, Validation loss:1.230, Validation accuracy:76.92%
#
# Epoch 16 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 16 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.817
#
#
# Epoch 17: iteration 106/107
# Epoch 17 --- loss:0.779, Epoch accuracy:98.55%, Validation loss:1.231, Validation accuracy:76.46%
#
# Epoch 17 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.065
#
# Epoch 17 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 18: iteration 106/107
# Epoch 18 --- loss:0.774, Epoch accuracy:98.90%, Validation loss:1.229, Validation accuracy:76.46%
#
# Epoch 18 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 18 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.816
#
#
# Epoch 19: iteration 106/107
# Epoch 19 --- loss:0.775, Epoch accuracy:98.78%, Validation loss:1.228, Validation accuracy:76.69%
#
# Epoch 19 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 19 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.813
#
#
# Epoch 20: iteration 106/107
# Epoch 20 --- loss:0.774, Epoch accuracy:98.98%, Validation loss:1.232, Validation accuracy:76.46%
#
# Epoch 20 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.056
#
# Epoch 20 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.820
#
#
# Epoch 21: iteration 106/107
# Epoch 21 --- loss:0.775, Epoch accuracy:98.78%, Validation loss:1.232, Validation accuracy:75.99%
#
# Epoch 21 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 21 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.821
#
#
# Epoch 22: iteration 106/107
# Epoch 22 --- loss:0.778, Epoch accuracy:98.69%, Validation loss:1.231, Validation accuracy:75.76%
#
# Epoch 22 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.063
#
# Epoch 22 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 23: iteration 106/107
# Epoch 23 --- loss:0.772, Epoch accuracy:99.07%, Validation loss:1.229, Validation accuracy:76.46%
#
# Epoch 23 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.053
#
# Epoch 23 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.816
#
#
# Epoch 24: iteration 106/107
# Epoch 24 --- loss:0.773, Epoch accuracy:99.04%, Validation loss:1.232, Validation accuracy:75.29%
#
# Epoch 24 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.055
#
# Epoch 24 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.821
#
#
# Epoch 25: iteration 106/107
# Epoch 25 --- loss:0.776, Epoch accuracy:98.81%, Validation loss:1.231, Validation accuracy:76.22%
#
# Epoch 25 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 25 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.819
#
#
# Epoch 26: iteration 106/107
# Epoch 26 --- loss:0.775, Epoch accuracy:98.92%, Validation loss:1.231, Validation accuracy:75.06%
#
# Epoch 26 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 26 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 27: iteration 106/107
# Epoch 27 --- loss:0.775, Epoch accuracy:98.87%, Validation loss:1.231, Validation accuracy:76.22%
#
# Epoch 27 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 27 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.819
#
#
# Epoch 28: iteration 106/107
# Epoch 28 --- loss:0.774, Epoch accuracy:98.87%, Validation loss:1.231, Validation accuracy:75.99%
#
# Epoch 28 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 28 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.819
#
#
# Epoch 29: iteration 106/107
# Epoch 29 --- loss:0.776, Epoch accuracy:98.92%, Validation loss:1.230, Validation accuracy:75.99%
#
# Epoch 29 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.061
#
# Epoch 29 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 30: iteration 106/107
# Epoch 30 --- loss:0.774, Epoch accuracy:99.01%, Validation loss:1.230, Validation accuracy:76.46%
#
# Epoch 30 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.056
#
# Epoch 30 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.817
#
#
# Epoch 31: iteration 106/107
# Epoch 31 --- loss:0.774, Epoch accuracy:98.92%, Validation loss:1.232, Validation accuracy:76.69%
#
# Epoch 31 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 31 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.820
#
#
# Epoch 32: iteration 106/107
# Epoch 32 --- loss:0.774, Epoch accuracy:98.95%, Validation loss:1.232, Validation accuracy:75.76%
#
# Epoch 32 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.056
#
# Epoch 32 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.820
#
#
# Epoch 33: iteration 106/107
# Epoch 33 --- loss:0.776, Epoch accuracy:98.69%, Validation loss:1.230, Validation accuracy:76.92%
#
# Epoch 33 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.060
#
# Epoch 33 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.817
#
#
# Epoch 34: iteration 106/107
# Epoch 34 --- loss:0.774, Epoch accuracy:99.01%, Validation loss:1.230, Validation accuracy:76.22%
#
# Epoch 34 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 34 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.816
#
#
# Epoch 35: iteration 106/107
# Epoch 35 --- loss:0.773, Epoch accuracy:99.04%, Validation loss:1.231, Validation accuracy:76.22%
#
# Epoch 35 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.055
#
# Epoch 35 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 36: iteration 106/107
# Epoch 36 --- loss:0.775, Epoch accuracy:98.84%, Validation loss:1.235, Validation accuracy:76.69%
#
# Epoch 36 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 36 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.825
#
#
# Epoch 37: iteration 106/107
# Epoch 37 --- loss:0.775, Epoch accuracy:98.98%, Validation loss:1.231, Validation accuracy:76.22%
#
# Epoch 37 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 37 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 38: iteration 106/107
# Epoch 38 --- loss:0.776, Epoch accuracy:98.81%, Validation loss:1.229, Validation accuracy:75.29%
#
# Epoch 38 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 38 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.815
#
#
# Epoch 39: iteration 106/107
# Epoch 39 --- loss:0.775, Epoch accuracy:99.01%, Validation loss:1.228, Validation accuracy:76.92%
#
# Epoch 39 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 39 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.813
#
#
# Epoch 40: iteration 106/107
# Epoch 40 --- loss:0.776, Epoch accuracy:98.84%, Validation loss:1.231, Validation accuracy:75.76%
#
# Epoch 40 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.060
#
# Epoch 40 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 41: iteration 106/107
# Epoch 41 --- loss:0.773, Epoch accuracy:98.95%, Validation loss:1.235, Validation accuracy:75.76%
#
# Epoch 41 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.055
#
# Epoch 41 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.825
#
#
# Epoch 42: iteration 106/107
# Epoch 42 --- loss:0.774, Epoch accuracy:99.13%, Validation loss:1.232, Validation accuracy:75.76%
#
# Epoch 42 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 42 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.821
#
#
# Epoch 43: iteration 106/107
# Epoch 43 --- loss:0.778, Epoch accuracy:98.55%, Validation loss:1.232, Validation accuracy:76.69%
#
# Epoch 43 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.063
#
# Epoch 43 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.821
#
#
# Epoch 44: iteration 106/107
# Epoch 44 --- loss:0.775, Epoch accuracy:98.78%, Validation loss:1.234, Validation accuracy:76.92%
#
# Epoch 44 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 44 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.824
#
#
# Epoch 45: iteration 106/107
# Epoch 45 --- loss:0.775, Epoch accuracy:98.98%, Validation loss:1.230, Validation accuracy:75.99%
#
# Epoch 45 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 45 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 46: iteration 106/107
# Epoch 46 --- loss:0.775, Epoch accuracy:98.75%, Validation loss:1.232, Validation accuracy:76.22%
#
# Epoch 46 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 46 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.820
#
#
# Epoch 47: iteration 106/107
# Epoch 47 --- loss:0.774, Epoch accuracy:98.92%, Validation loss:1.232, Validation accuracy:76.46%
#
# Epoch 47 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 47 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.821
#
#
# Epoch 48: iteration 106/107
# Epoch 48 --- loss:0.777, Epoch accuracy:98.72%, Validation loss:1.229, Validation accuracy:76.46%
#
# Epoch 48 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.062
#
# Epoch 48 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.816
#
#
# Epoch 49: iteration 106/107
# Epoch 49 --- loss:0.775, Epoch accuracy:99.07%, Validation loss:1.230, Validation accuracy:75.76%
#
# Epoch 49 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 49 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.817
#
#
# Epoch 50: iteration 106/107
# Epoch 50 --- loss:0.774, Epoch accuracy:99.04%, Validation loss:1.235, Validation accuracy:76.46%
#
# Epoch 50 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.056
#
# Epoch 50 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.824
#
#
# Epoch 51: iteration 106/107
# Epoch 51 --- loss:0.775, Epoch accuracy:98.90%, Validation loss:1.228, Validation accuracy:76.46%
#
# Epoch 51 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 51 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.814
#
#
# Epoch 52: iteration 106/107
# Epoch 52 --- loss:0.776, Epoch accuracy:98.81%, Validation loss:1.231, Validation accuracy:75.99%
#
# Epoch 52 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 52 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.819
#
#
# Epoch 53: iteration 106/107
# Epoch 53 --- loss:0.772, Epoch accuracy:99.13%, Validation loss:1.232, Validation accuracy:75.06%
#
# Epoch 53 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.053
#
# Epoch 53 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.821
#
#
# Epoch 54: iteration 106/107
# Epoch 54 --- loss:0.775, Epoch accuracy:99.01%, Validation loss:1.235, Validation accuracy:76.22%
#
# Epoch 54 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 54 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.826
#
#
# Epoch 55: iteration 106/107
# Epoch 55 --- loss:0.776, Epoch accuracy:98.75%, Validation loss:1.232, Validation accuracy:76.46%
#
# Epoch 55 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.060
#
# Epoch 55 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.820
#
#
# Epoch 56: iteration 106/107
# Epoch 56 --- loss:0.775, Epoch accuracy:98.95%, Validation loss:1.231, Validation accuracy:76.46%
#
# Epoch 56 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 56 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.819
#
#
# Epoch 57: iteration 106/107
# Epoch 57 --- loss:0.775, Epoch accuracy:98.81%, Validation loss:1.233, Validation accuracy:76.46%
#
# Epoch 57 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 57 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.822
#
#
# Epoch 58: iteration 106/107
# Epoch 58 --- loss:0.775, Epoch accuracy:98.84%, Validation loss:1.235, Validation accuracy:76.92%
#
# Epoch 58 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 58 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.825
#
#
# Epoch 59: iteration 106/107
# Epoch 59 --- loss:0.775, Epoch accuracy:98.90%, Validation loss:1.233, Validation accuracy:75.99%
#
# Epoch 59 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 59 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.821
#
#
# Epoch 60: iteration 106/107
# Epoch 60 --- loss:0.774, Epoch accuracy:98.87%, Validation loss:1.232, Validation accuracy:76.69%
#
# Epoch 60 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.056
#
# Epoch 60 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.821
#
#
# Epoch 61: iteration 106/107
# Epoch 61 --- loss:0.776, Epoch accuracy:98.78%, Validation loss:1.229, Validation accuracy:76.69%
#
# Epoch 61 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 61 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.815
#
#
# Epoch 62: iteration 106/107
# Epoch 62 --- loss:0.774, Epoch accuracy:99.04%, Validation loss:1.228, Validation accuracy:76.46%
#
# Epoch 62 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.056
#
# Epoch 62 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.814
#
#
# Epoch 63: iteration 106/107
# Epoch 63 --- loss:0.775, Epoch accuracy:98.92%, Validation loss:1.230, Validation accuracy:75.99%
#
# Epoch 63 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 63 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 64: iteration 106/107
# Epoch 64 --- loss:0.775, Epoch accuracy:98.78%, Validation loss:1.232, Validation accuracy:76.22%
#
# Epoch 64 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 64 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.820
#
#
# Epoch 65: iteration 106/107
# Epoch 65 --- loss:0.773, Epoch accuracy:98.92%, Validation loss:1.234, Validation accuracy:75.76%
#
# Epoch 65 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.056
#
# Epoch 65 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.824
#
#
# Epoch 66: iteration 106/107
# Epoch 66 --- loss:0.773, Epoch accuracy:99.01%, Validation loss:1.232, Validation accuracy:75.52%
#
# Epoch 66 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.055
#
# Epoch 66 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.821
#
#
# Epoch 67: iteration 106/107
# Epoch 67 --- loss:0.773, Epoch accuracy:99.13%, Validation loss:1.231, Validation accuracy:76.46%
#
# Epoch 67 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.054
#
# Epoch 67 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.820
#
#
# Epoch 68: iteration 106/107
# Epoch 68 --- loss:0.774, Epoch accuracy:98.84%, Validation loss:1.234, Validation accuracy:75.99%
#
# Epoch 68 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 68 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.823
#
#
# Epoch 69: iteration 106/107
# Epoch 69 --- loss:0.775, Epoch accuracy:98.98%, Validation loss:1.234, Validation accuracy:75.29%
#
# Epoch 69 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 69 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.823
#
#
# Epoch 70: iteration 106/107
# Epoch 70 --- loss:0.775, Epoch accuracy:98.90%, Validation loss:1.237, Validation accuracy:75.76%
#
# Epoch 70 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 70 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.830
#
#
# Epoch 71: iteration 106/107
# Epoch 71 --- loss:0.774, Epoch accuracy:98.95%, Validation loss:1.230, Validation accuracy:76.69%
#
# Epoch 71 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.056
#
# Epoch 71 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 72: iteration 106/107
# Epoch 72 --- loss:0.773, Epoch accuracy:99.01%, Validation loss:1.232, Validation accuracy:76.46%
#
# Epoch 72 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.056
#
# Epoch 72 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.820
#
#
# Epoch 73: iteration 106/107
# Epoch 73 --- loss:0.779, Epoch accuracy:98.58%, Validation loss:1.233, Validation accuracy:76.22%
#
# Epoch 73 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.064
#
# Epoch 73 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.822
#
#
# Epoch 74: iteration 106/107
# Epoch 74 --- loss:0.774, Epoch accuracy:98.90%, Validation loss:1.235, Validation accuracy:76.22%
#
# Epoch 74 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 74 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.825
#
#
# Epoch 75: iteration 106/107
# Epoch 75 --- loss:0.775, Epoch accuracy:98.90%, Validation loss:1.232, Validation accuracy:75.99%
#
# Epoch 75 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 75 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.820
#
#
# Epoch 76: iteration 106/107
# Epoch 76 --- loss:0.775, Epoch accuracy:98.78%, Validation loss:1.230, Validation accuracy:75.99%
#
# Epoch 76 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 76 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 77: iteration 106/107
# Epoch 77 --- loss:0.774, Epoch accuracy:99.01%, Validation loss:1.230, Validation accuracy:75.99%
#
# Epoch 77 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.056
#
# Epoch 77 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.817
#
#
# Epoch 78: iteration 106/107
# Epoch 78 --- loss:0.775, Epoch accuracy:99.07%, Validation loss:1.235, Validation accuracy:76.46%
#
# Epoch 78 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 78 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.826
#
#
# Epoch 79: iteration 106/107
# Epoch 79 --- loss:0.773, Epoch accuracy:99.24%, Validation loss:1.229, Validation accuracy:76.46%
#
# Epoch 79 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.055
#
# Epoch 79 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.815
#
#
# Epoch 80: iteration 106/107
# Epoch 80 --- loss:0.774, Epoch accuracy:98.90%, Validation loss:1.229, Validation accuracy:75.99%
#
# Epoch 80 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.056
#
# Epoch 80 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.816
#
#
# Epoch 81: iteration 106/107
# Epoch 81 --- loss:0.776, Epoch accuracy:98.87%, Validation loss:1.228, Validation accuracy:76.22%
#
# Epoch 81 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.060
#
# Epoch 81 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.814
#
#
# Epoch 82: iteration 106/107
# Epoch 82 --- loss:0.773, Epoch accuracy:99.10%, Validation loss:1.230, Validation accuracy:76.22%
#
# Epoch 82 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.054
#
# Epoch 82 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 83: iteration 106/107
# Epoch 83 --- loss:0.776, Epoch accuracy:98.75%, Validation loss:1.231, Validation accuracy:76.22%
#
# Epoch 83 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.061
#
# Epoch 83 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 84: iteration 106/107
# Epoch 84 --- loss:0.775, Epoch accuracy:98.75%, Validation loss:1.233, Validation accuracy:75.52%
#
# Epoch 84 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 84 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.823
#
#
# Epoch 85: iteration 106/107
# Epoch 85 --- loss:0.775, Epoch accuracy:98.90%, Validation loss:1.231, Validation accuracy:75.76%
#
# Epoch 85 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 85 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 86: iteration 106/107
# Epoch 86 --- loss:0.777, Epoch accuracy:98.66%, Validation loss:1.228, Validation accuracy:76.69%
#
# Epoch 86 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.062
#
# Epoch 86 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.814
#
#
# Epoch 87: iteration 106/107
# Epoch 87 --- loss:0.773, Epoch accuracy:98.84%, Validation loss:1.233, Validation accuracy:76.46%
#
# Epoch 87 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.056
#
# Epoch 87 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.823
#
#
# Epoch 88: iteration 106/107
# Epoch 88 --- loss:0.775, Epoch accuracy:98.75%, Validation loss:1.234, Validation accuracy:76.22%
#
# Epoch 88 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 88 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.824
#
#
# Epoch 89: iteration 106/107
# Epoch 89 --- loss:0.774, Epoch accuracy:99.04%, Validation loss:1.232, Validation accuracy:76.22%
#
# Epoch 89 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 89 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.821
#
#
# Epoch 90: iteration 106/107
# Epoch 90 --- loss:0.776, Epoch accuracy:98.92%, Validation loss:1.227, Validation accuracy:76.46%
#
# Epoch 90 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 90 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.813
#
#
# Epoch 91: iteration 106/107
# Epoch 91 --- loss:0.773, Epoch accuracy:98.90%, Validation loss:1.233, Validation accuracy:75.06%
#
# Epoch 91 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.055
#
# Epoch 91 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.822
#
#
# Epoch 92: iteration 106/107
# Epoch 92 --- loss:0.775, Epoch accuracy:98.87%, Validation loss:1.230, Validation accuracy:76.69%
#
# Epoch 92 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 92 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.817
#
#
# Epoch 93: iteration 106/107
# Epoch 93 --- loss:0.775, Epoch accuracy:98.81%, Validation loss:1.235, Validation accuracy:75.99%
#
# Epoch 93 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 93 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.826
#
#
# Epoch 94: iteration 106/107
# Epoch 94 --- loss:0.775, Epoch accuracy:99.04%, Validation loss:1.233, Validation accuracy:75.76%
#
# Epoch 94 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 94 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.823
#
#
# Epoch 95: iteration 106/107
# Epoch 95 --- loss:0.774, Epoch accuracy:98.66%, Validation loss:1.229, Validation accuracy:75.76%
#
# Epoch 95 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.056
#
# Epoch 95 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.815
#
#
# Epoch 96: iteration 106/107
# Epoch 96 --- loss:0.774, Epoch accuracy:98.92%, Validation loss:1.230, Validation accuracy:75.76%
#
# Epoch 96 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.055
#
# Epoch 96 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 97: iteration 106/107
# Epoch 97 --- loss:0.777, Epoch accuracy:98.69%, Validation loss:1.233, Validation accuracy:76.22%
#
# Epoch 97 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.061
#
# Epoch 97 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.822
#
#
# Epoch 98: iteration 106/107
# Epoch 98 --- loss:0.773, Epoch accuracy:99.01%, Validation loss:1.230, Validation accuracy:76.22%
#
# Epoch 98 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.055
#
# Epoch 98 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 99: iteration 106/107
# Epoch 99 --- loss:0.775, Epoch accuracy:98.87%, Validation loss:1.233, Validation accuracy:76.22%
#
# Epoch 99 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 99 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.822
#
#
# Epoch 100: iteration 106/107
# Epoch 100 --- loss:0.774, Epoch accuracy:99.22%, Validation loss:1.231, Validation accuracy:75.76%
#
# Epoch 100 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 100 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 101: iteration 106/107
# Epoch 101 --- loss:0.772, Epoch accuracy:99.07%, Validation loss:1.230, Validation accuracy:76.22%
#
# Epoch 101 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.054
#
# Epoch 101 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.818
#
#
# Epoch 102: iteration 106/107
# Epoch 102 --- loss:0.773, Epoch accuracy:98.92%, Validation loss:1.229, Validation accuracy:76.69%
#
# Epoch 102 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.055
#
# Epoch 102 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.815
#
#
# Epoch 103: iteration 106/107
# Epoch 103 --- loss:0.774, Epoch accuracy:98.81%, Validation loss:1.231, Validation accuracy:76.46%
#
# Epoch 103 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 103 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.819
#
#
# Epoch 104: iteration 106/107
# Epoch 104 --- loss:0.771, Epoch accuracy:99.22%, Validation loss:1.231, Validation accuracy:76.22%
#
# Epoch 104 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.052
#
# Epoch 104 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.819
#
#
# Epoch 105: iteration 106/107
# Epoch 105 --- loss:0.775, Epoch accuracy:98.75%, Validation loss:1.230, Validation accuracy:76.46%
#
# Epoch 105 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 105 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 106: iteration 106/107
# Epoch 106 --- loss:0.774, Epoch accuracy:98.95%, Validation loss:1.232, Validation accuracy:76.69%
#
# Epoch 106 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 106 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.820
#
#
# Epoch 107: iteration 106/107
# Epoch 107 --- loss:0.774, Epoch accuracy:98.98%, Validation loss:1.234, Validation accuracy:76.22%
#
# Epoch 107 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 107 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.824
#
#
# Epoch 108: iteration 106/107
# Epoch 108 --- loss:0.773, Epoch accuracy:99.01%, Validation loss:1.230, Validation accuracy:76.69%
#
# Epoch 108 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.055
#
# Epoch 108 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.818
#
#
# Epoch 109: iteration 106/107
# Epoch 109 --- loss:0.773, Epoch accuracy:99.07%, Validation loss:1.231, Validation accuracy:76.46%
#
# Epoch 109 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.055
#
# Epoch 109 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.820
#
#
# Epoch 110: iteration 106/107
# Epoch 110 --- loss:0.775, Epoch accuracy:98.92%, Validation loss:1.233, Validation accuracy:76.22%
#
# Epoch 110 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 110 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.822
#
#
# Epoch 111: iteration 106/107
# Epoch 111 --- loss:0.775, Epoch accuracy:98.72%, Validation loss:1.232, Validation accuracy:76.92%
#
# Epoch 111 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 111 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.820
#
#
# Epoch 112: iteration 106/107
# Epoch 112 --- loss:0.773, Epoch accuracy:98.98%, Validation loss:1.232, Validation accuracy:74.83%
#
# Epoch 112 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.055
#
# Epoch 112 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.820
#
#
# Epoch 113: iteration 106/107
# Epoch 113 --- loss:0.775, Epoch accuracy:98.72%, Validation loss:1.234, Validation accuracy:75.29%
#
# Epoch 113 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 113 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.824
#
#
# Epoch 114: iteration 106/107
# Epoch 114 --- loss:0.776, Epoch accuracy:98.63%, Validation loss:1.230, Validation accuracy:75.76%
#
# Epoch 114 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.060
#
# Epoch 114 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.817
#
#
# Epoch 115: iteration 106/107
# Epoch 115 --- loss:0.774, Epoch accuracy:98.78%, Validation loss:1.230, Validation accuracy:75.99%
#
# Epoch 115 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 115 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.817
#
#
# Epoch 116: iteration 106/107
# Epoch 116 --- loss:0.775, Epoch accuracy:98.87%, Validation loss:1.234, Validation accuracy:76.46%
#
# Epoch 116 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 116 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.825
#
#
# Epoch 117: iteration 106/107
# Epoch 117 --- loss:0.775, Epoch accuracy:98.95%, Validation loss:1.237, Validation accuracy:76.46%
#
# Epoch 117 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 117 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.830
#
#
# Epoch 118: iteration 106/107
# Epoch 118 --- loss:0.773, Epoch accuracy:98.90%, Validation loss:1.235, Validation accuracy:76.46%
#
# Epoch 118 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.056
#
# Epoch 118 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.826
#
#
# Epoch 119: iteration 106/107
# Epoch 119 --- loss:0.773, Epoch accuracy:99.04%, Validation loss:1.233, Validation accuracy:75.76%
#
# Epoch 119 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.055
#
# Epoch 119 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.824
#
#
# Epoch 120: iteration 106/107
# Epoch 120 --- loss:0.776, Epoch accuracy:98.84%, Validation loss:1.233, Validation accuracy:75.52%
#
# Epoch 120 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.061
#
# Epoch 120 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.823
#
#
# Epoch 121: iteration 106/107
# Epoch 121 --- loss:0.775, Epoch accuracy:98.84%, Validation loss:1.231, Validation accuracy:75.76%
#
# Epoch 121 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 121 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.819
#
#
# Epoch 122: iteration 106/107
# Epoch 122 --- loss:0.773, Epoch accuracy:99.01%, Validation loss:1.233, Validation accuracy:75.99%
#
# Epoch 122 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.055
#
# Epoch 122 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.822
#
#
# Epoch 123: iteration 106/107
# Epoch 123 --- loss:0.773, Epoch accuracy:99.04%, Validation loss:1.234, Validation accuracy:75.76%
#
# Epoch 123 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.055
#
# Epoch 123 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.823
#
#
# Epoch 124: iteration 106/107
# Epoch 124 --- loss:0.776, Epoch accuracy:98.75%, Validation loss:1.234, Validation accuracy:76.46%
#
# Epoch 124 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.061
#
# Epoch 124 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.825
#
#
# Epoch 125: iteration 106/107
# Epoch 125 --- loss:0.774, Epoch accuracy:99.13%, Validation loss:1.235, Validation accuracy:76.22%
#
# Epoch 125 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.056
#
# Epoch 125 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.826
#
#
# Epoch 126: iteration 106/107
# Epoch 126 --- loss:0.774, Epoch accuracy:98.75%, Validation loss:1.237, Validation accuracy:76.46%
#
# Epoch 126 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 126 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.829
#
#
# Epoch 127: iteration 106/107
# Epoch 127 --- loss:0.774, Epoch accuracy:98.92%, Validation loss:1.234, Validation accuracy:75.99%
#
# Epoch 127 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 127 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.825
#
#
# Epoch 128: iteration 106/107
# Epoch 128 --- loss:0.774, Epoch accuracy:99.04%, Validation loss:1.232, Validation accuracy:75.99%
#
# Epoch 128 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 128 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.821
#
#
# Epoch 129: iteration 106/107
# Epoch 129 --- loss:0.774, Epoch accuracy:98.98%, Validation loss:1.235, Validation accuracy:76.69%
#
# Epoch 129 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 129 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.825
#
#
# Epoch 130: iteration 106/107
# Epoch 130 --- loss:0.773, Epoch accuracy:99.04%, Validation loss:1.230, Validation accuracy:76.46%
#
# Epoch 130 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.054
#
# Epoch 130 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.817
#
#
# Epoch 131: iteration 106/107
# Epoch 131 --- loss:0.772, Epoch accuracy:99.07%, Validation loss:1.232, Validation accuracy:76.46%
#
# Epoch 131 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.054
#
# Epoch 131 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.821
#
#
# Epoch 132: iteration 106/107
# Epoch 132 --- loss:0.775, Epoch accuracy:99.01%, Validation loss:1.228, Validation accuracy:75.76%
#
# Epoch 132 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 132 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.815
#
#
# Epoch 133: iteration 106/107
# Epoch 133 --- loss:0.773, Epoch accuracy:98.95%, Validation loss:1.228, Validation accuracy:76.22%
#
# Epoch 133 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.056
#
# Epoch 133 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.815
#
#
# Epoch 134: iteration 106/107
# Epoch 134 --- loss:0.771, Epoch accuracy:99.01%, Validation loss:1.230, Validation accuracy:76.69%
#
# Epoch 134 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.053
#
# Epoch 134 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.817
#
#
# Epoch 135: iteration 106/107
# Epoch 135 --- loss:0.775, Epoch accuracy:98.87%, Validation loss:1.230, Validation accuracy:75.99%
#
# Epoch 135 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 135 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.818
#
#
# Epoch 136: iteration 106/107
# Epoch 136 --- loss:0.774, Epoch accuracy:98.81%, Validation loss:1.233, Validation accuracy:75.99%
#
# Epoch 136 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 136 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.823
#
#
# Epoch 137: iteration 106/107
# Epoch 137 --- loss:0.772, Epoch accuracy:99.07%, Validation loss:1.231, Validation accuracy:75.52%
#
# Epoch 137 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.055
#
# Epoch 137 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.819
#
#
# Epoch 138: iteration 106/107
# Epoch 138 --- loss:0.773, Epoch accuracy:98.72%, Validation loss:1.231, Validation accuracy:75.99%
#
# Epoch 138 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.057
#
# Epoch 138 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.819
#
#
# Epoch 139: iteration 106/107
# Epoch 139 --- loss:0.772, Epoch accuracy:98.92%, Validation loss:1.230, Validation accuracy:75.76%
#
# Epoch 139 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.054
#
# Epoch 139 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.816
#
#
# Epoch 140: iteration 106/107
# Epoch 140 --- loss:0.775, Epoch accuracy:98.75%, Validation loss:1.230, Validation accuracy:75.99%
#
# Epoch 140 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.058
#
# Epoch 140 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.818
#
#
# Epoch 141: iteration 106/107
# Epoch 141 --- loss:0.776, Epoch accuracy:98.87%, Validation loss:1.232, Validation accuracy:75.76%
#
# Epoch 141 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 141 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.821
#
#
# Epoch 142: iteration 106/107
# Epoch 142 --- loss:0.775, Epoch accuracy:98.92%, Validation loss:1.237, Validation accuracy:75.06%
#
# Epoch 142 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.059
#
# Epoch 142 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.94, valid_classifier_loss:0.830
#
#
# Epoch 143: iteration 106/107
# ...
#
# Epoch 452 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.819
#
#
# Epoch 453: iteration 106/107
# Epoch 453 --- loss:0.768, Epoch accuracy:99.19%, Validation loss:1.226, Validation accuracy:75.99%
#
# Epoch 453 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.049
#
# Epoch 453 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.813
#
#
# Epoch 454: iteration 106/107
# Epoch 454 --- loss:0.771, Epoch accuracy:98.92%, Validation loss:1.225, Validation accuracy:76.22%
#
# Epoch 454 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.054
#
# Epoch 454 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.812
#
#
# Epoch 455: iteration 106/107
# Epoch 455 --- loss:0.770, Epoch accuracy:99.07%, Validation loss:1.226, Validation accuracy:76.22%
#
# Epoch 455 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.052
#
# Epoch 455 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.813
#
#
# Epoch 456: iteration 106/107
# Epoch 456 --- loss:0.771, Epoch accuracy:98.92%, Validation loss:1.225, Validation accuracy:76.22%
#
# Epoch 456 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.053
#
# Epoch 456 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.811
#
#
# Epoch 457: iteration 106/107
# Epoch 457 --- loss:0.771, Epoch accuracy:98.87%, Validation loss:1.222, Validation accuracy:76.46%
#
# Epoch 457 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.054
#
# Epoch 457 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.806
#
#
# Epoch 458: iteration 106/107
# Epoch 458 --- loss:0.769, Epoch accuracy:99.04%, Validation loss:1.224, Validation accuracy:76.46%
#
# Epoch 458 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.051
#
# Epoch 458 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.810
#
#
# Epoch 459: iteration 106/107
# Epoch 459 --- loss:0.769, Epoch accuracy:99.07%, Validation loss:1.226, Validation accuracy:76.22%
#
# Epoch 459 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.051
#
# Epoch 459 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.813
#
#
# Epoch 460: iteration 106/107
# Epoch 460 --- loss:0.769, Epoch accuracy:98.98%, Validation loss:1.227, Validation accuracy:75.76%
#
# Epoch 460 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.051
#
# Epoch 460 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.815
#
#
# Epoch 461: iteration 106/107
# Epoch 461 --- loss:0.770, Epoch accuracy:99.13%, Validation loss:1.223, Validation accuracy:76.69%
#
# Epoch 461 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.051
#
# Epoch 461 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.807
#
#
# Epoch 462: iteration 106/107
# Epoch 462 --- loss:0.769, Epoch accuracy:99.10%, Validation loss:1.226, Validation accuracy:76.92%
#
# Epoch 462 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.051
#
# Epoch 462 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.814
#
#
# Epoch 463: iteration 106/107
# Epoch 463 --- loss:0.770, Epoch accuracy:98.81%, Validation loss:1.227, Validation accuracy:75.76%
#
# Epoch 463 --- epoch_autoencoder_loss1:0.909, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.053
#
# Epoch 463 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.814
#
#
# Epoch 464: iteration 106/107
# Epoch 464 --- loss:0.771, Epoch accuracy:98.87%, Validation loss:1.226, Validation accuracy:76.46%
#
# Epoch 464 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.053
#
# Epoch 464 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.813
#
#
# Epoch 465: iteration 106/107
# Epoch 465 --- loss:0.769, Epoch accuracy:99.19%, Validation loss:1.228, Validation accuracy:76.92%
#
# Epoch 465 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.050
#
# Epoch 465 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.817
#
#
# Epoch 466: iteration 106/107
# Epoch 466 --- loss:0.770, Epoch accuracy:98.84%, Validation loss:1.224, Validation accuracy:76.46%
#
# Epoch 466 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.052
#
# Epoch 466 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.811
#
#
# Epoch 467: iteration 106/107
# Epoch 467 --- loss:0.769, Epoch accuracy:99.13%, Validation loss:1.225, Validation accuracy:75.99%
#
# Epoch 467 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.051
#
# Epoch 467 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.812
#
#
# Epoch 468: iteration 106/107
# Epoch 468 --- loss:0.769, Epoch accuracy:98.92%, Validation loss:1.227, Validation accuracy:75.99%
#
# Epoch 468 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.050
#
# Epoch 468 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.815
#
#
# Epoch 469: iteration 106/107
# Epoch 469 --- loss:0.769, Epoch accuracy:99.07%, Validation loss:1.225, Validation accuracy:75.76%
#
# Epoch 469 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.050
#
# Epoch 469 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.812
#
#
# Epoch 470: iteration 106/107
# Epoch 470 --- loss:0.768, Epoch accuracy:99.27%, Validation loss:1.225, Validation accuracy:76.46%
#
# Epoch 470 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.049
#
# Epoch 470 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.813
#
#
# Epoch 471: iteration 106/107
# Epoch 471 --- loss:0.768, Epoch accuracy:99.04%, Validation loss:1.223, Validation accuracy:76.22%
#
# Epoch 471 --- epoch_autoencoder_loss1:0.909, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.049
#
# Epoch 471 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.809
#
#
# Epoch 472: iteration 106/107
# Epoch 472 --- loss:0.767, Epoch accuracy:99.13%, Validation loss:1.223, Validation accuracy:76.92%
#
# Epoch 472 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.047
#
# Epoch 472 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.809
#
#
# Epoch 473: iteration 106/107
# Epoch 473 --- loss:0.768, Epoch accuracy:98.95%, Validation loss:1.226, Validation accuracy:75.52%
#
# Epoch 473 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.050
#
# Epoch 473 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.813
#
#
# Epoch 474: iteration 106/107
# Epoch 474 --- loss:0.769, Epoch accuracy:99.10%, Validation loss:1.223, Validation accuracy:76.69%
#
# Epoch 474 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.051
#
# Epoch 474 --- valid_autoencoder_loss1:0.911, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.809
#
#
# Epoch 475: iteration 106/107
# Epoch 475 --- loss:0.769, Epoch accuracy:99.13%, Validation loss:1.223, Validation accuracy:76.22%
#
# Epoch 475 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.051
#
# Epoch 475 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.807
#
#
# Epoch 476: iteration 106/107
# Epoch 476 --- loss:0.770, Epoch accuracy:99.13%, Validation loss:1.221, Validation accuracy:76.69%
#
# Epoch 476 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.052
#
# Epoch 476 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.805
#
#
# Epoch 477: iteration 106/107
# Epoch 477 --- loss:0.770, Epoch accuracy:98.95%, Validation loss:1.223, Validation accuracy:75.99%
#
# Epoch 477 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.053
#
# Epoch 477 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.809
#
#
# Epoch 478: iteration 106/107
# Epoch 478 --- loss:0.770, Epoch accuracy:99.04%, Validation loss:1.225, Validation accuracy:76.69%
#
# Epoch 478 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.052
#
# Epoch 478 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.811
#
#
# Epoch 479: iteration 106/107
# Epoch 479 --- loss:0.770, Epoch accuracy:99.13%, Validation loss:1.225, Validation accuracy:76.46%
#
# Epoch 479 --- epoch_autoencoder_loss1:0.909, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.053
#
# Epoch 479 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.812
#
#
# Epoch 480: iteration 106/107
# Epoch 480 --- loss:0.769, Epoch accuracy:99.07%, Validation loss:1.227, Validation accuracy:75.99%
#
# Epoch 480 --- epoch_autoencoder_loss1:0.909, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.051
#
# Epoch 480 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.815
#
#
# Epoch 481: iteration 106/107
# Epoch 481 --- loss:0.768, Epoch accuracy:99.07%, Validation loss:1.226, Validation accuracy:76.46%
#
# Epoch 481 --- epoch_autoencoder_loss1:0.909, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.051
#
# Epoch 481 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.813
#
#
# Epoch 482: iteration 106/107
# Epoch 482 --- loss:0.771, Epoch accuracy:99.10%, Validation loss:1.227, Validation accuracy:76.22%
#
# Epoch 482 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.053
#
# Epoch 482 --- valid_autoencoder_loss1:0.911, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.816
#
#
# Epoch 483: iteration 106/107
# Epoch 483 --- loss:0.770, Epoch accuracy:98.84%, Validation loss:1.224, Validation accuracy:76.22%
#
# Epoch 483 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.052
#
# Epoch 483 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.811
#
#
# Epoch 484: iteration 106/107
# Epoch 484 --- loss:0.768, Epoch accuracy:98.95%, Validation loss:1.225, Validation accuracy:76.46%
#
# Epoch 484 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.049
#
# Epoch 484 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.811
#
#
# Epoch 485: iteration 106/107
# Epoch 485 --- loss:0.771, Epoch accuracy:98.87%, Validation loss:1.227, Validation accuracy:76.46%
#
# Epoch 485 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.053
#
# Epoch 485 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.816
#
#
# Epoch 486: iteration 106/107
# Epoch 486 --- loss:0.769, Epoch accuracy:99.19%, Validation loss:1.225, Validation accuracy:75.99%
#
# Epoch 486 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.051
#
# Epoch 486 --- valid_autoencoder_loss1:0.911, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.813
#
#
# Epoch 487: iteration 106/107
# Epoch 487 --- loss:0.769, Epoch accuracy:99.10%, Validation loss:1.227, Validation accuracy:75.99%
#
# Epoch 487 --- epoch_autoencoder_loss1:0.909, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.051
#
# Epoch 487 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.815
#
#
# Epoch 488: iteration 106/107
# Epoch 488 --- loss:0.771, Epoch accuracy:98.78%, Validation loss:1.224, Validation accuracy:76.46%
#
# Epoch 488 --- epoch_autoencoder_loss1:0.909, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.054
#
# Epoch 488 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.811
#
#
# Epoch 489: iteration 106/107
# Epoch 489 --- loss:0.769, Epoch accuracy:99.10%, Validation loss:1.226, Validation accuracy:75.99%
#
# Epoch 489 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.051
#
# Epoch 489 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.814
#
#
# Epoch 490: iteration 106/107
# Epoch 490 --- loss:0.769, Epoch accuracy:99.04%, Validation loss:1.227, Validation accuracy:75.99%
#
# Epoch 490 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.050
#
# Epoch 490 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.815
#
#
# Epoch 491: iteration 106/107
# Epoch 491 --- loss:0.768, Epoch accuracy:99.07%, Validation loss:1.227, Validation accuracy:75.52%
#
# Epoch 491 --- epoch_autoencoder_loss1:0.909, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.050
#
# Epoch 491 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.816
#
#
# Epoch 492: iteration 106/107
# Epoch 492 --- loss:0.768, Epoch accuracy:99.13%, Validation loss:1.229, Validation accuracy:75.99%
#
# Epoch 492 --- epoch_autoencoder_loss1:0.909, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.049
#
# Epoch 492 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.819
#
#
# Epoch 493: iteration 106/107
# Epoch 493 --- loss:0.768, Epoch accuracy:99.19%, Validation loss:1.229, Validation accuracy:75.52%
#
# Epoch 493 --- epoch_autoencoder_loss1:0.909, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.049
#
# Epoch 493 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.818
#
#
# Epoch 494: iteration 106/107
# Epoch 494 --- loss:0.771, Epoch accuracy:98.75%, Validation loss:1.225, Validation accuracy:75.99%
#
# Epoch 494 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.054
#
# Epoch 494 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.812
#
#
# Epoch 495: iteration 106/107
# Epoch 495 --- loss:0.769, Epoch accuracy:99.13%, Validation loss:1.226, Validation accuracy:75.76%
#
# Epoch 495 --- epoch_autoencoder_loss1:0.909, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.051
#
# Epoch 495 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.813
#
#
# Epoch 496: iteration 106/107
# Epoch 496 --- loss:0.770, Epoch accuracy:99.10%, Validation loss:1.223, Validation accuracy:76.46%
#
# Epoch 496 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.052
#
# Epoch 496 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.809
#
#
# Epoch 497: iteration 106/107
# Epoch 497 --- loss:0.770, Epoch accuracy:99.07%, Validation loss:1.224, Validation accuracy:75.76%
#
# Epoch 497 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.052
#
# Epoch 497 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.811
#
#
# Epoch 498: iteration 106/107
# Epoch 498 --- loss:0.770, Epoch accuracy:98.92%, Validation loss:1.222, Validation accuracy:75.99%
#
# Epoch 498 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.053
#
# Epoch 498 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.807
#
#
# Epoch 499: iteration 106/107
# Epoch 499 --- loss:0.769, Epoch accuracy:99.24%, Validation loss:1.224, Validation accuracy:76.46%
#
# Epoch 499 --- epoch_autoencoder_loss1:0.909, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:0.051
#
# Epoch 499 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.93, valid_classifier_loss:0.810

# %%
plt.title('Loss Curve for Parallel is All You Want Model')
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(train_losses[:],'b')
plt.plot(valid_losses[:],'r')
plt.legend(['Training loss','Validation loss'])
plt.show()

# %%
# pick load folder
load_folder = '/content'

# pick the epoch to load
epoch = '429'
model_name = f'parallel_all_you_wantFINAL.pkl'

# make full load path
load_path = os.path.join(load_folder, model_name)

## instantiate empty model and populate with params from binary
model = MultiTaskModel(len(emotions_dict)).to(device)
load_checkpoint(optimizer, model, load_path)

print(f'Loaded model from {load_path}')
# Out:
# Loaded model from /content/parallel_all_you_wantFINAL.pkl

# %%
# reinitialize validation function with model from chosen checkpoint
validate = make_validate_fnc(model,autoencoder_criterion, classifier_criterion)

# Convert 4D test feature set array to tensor and move to GPU
X_test_tensor = torch.tensor(X_test,device=device).float()
# Convert 4D test label set array to tensor and move to GPU
y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)

# Get the model's performance metrics using the validation function we defined
test_loss, test_acc, test_autoencoder_loss1, test_autoencoder_loss2, test_classifier_loss, predicted_emotions = validate(X_test_tensor,y_test_tensor)


print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test accuracy is 80.11%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

# because model tested on GPU, move prediction tensor to CPU then convert to array
predicted_emotions = predicted_emotions.cpu().numpy()
# use labels from test set
emotions_groundtruth = y_test

# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

# set labels for matrix axes from emotions
emotion_names = [emotion for emotion in emotions_dict.values()]

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

plt.show()

# %%
from sklearn.model_selection import KFold
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

for train_index, test_index in kfold.split(X_train, y_train):
    Xtrain, Xtest = X_train[train_index], X_train[test_index]
    ytrain, ytest = y_train[train_index], y_train[test_index]
    print(Xtrain.shape,train_index), print(Xtest.shape)
# Out:
# (3096, 1, 40, 282) [   0    1    2 ... 3437 3438 3440]
# (345, 1, 40, 282)
# (3097, 1, 40, 282) [   1    2    3 ... 3438 3439 3440]
# (344, 1, 40, 282)
# (3097, 1, 40, 282) [   0    1    2 ... 3438 3439 3440]
# (344, 1, 40, 282)
# (3097, 1, 40, 282) [   0    1    2 ... 3438 3439 3440]
# (344, 1, 40, 282)
# (3097, 1, 40, 282) [   0    1    2 ... 3438 3439 3440]
# (344, 1, 40, 282)
# (3097, 1, 40, 282) [   0    1    3 ... 3436 3439 3440]
# (344, 1, 40, 282)
# (3097, 1, 40, 282) [   0    1    2 ... 3438 3439 3440]
# (344, 1, 40, 282)
# (3097, 1, 40, 282) [   0    1    2 ... 3438 3439 3440]
# (344, 1, 40, 282)
# (3097, 1, 40, 282) [   0    1    2 ... 3437 3438 3439]
# (344, 1, 40, 282)
# (3097, 1, 40, 282) [   0    2    3 ... 3438 3439 3440]
# (344, 1, 40, 282)

# %%
# Out:
# (1, 40, 282)

# %%
Xtensor = torch.tensor(X_train[1], device=device).float()
Ytensor = torch.tensor(y_train[1], dtype=torch.long,device=device)

# %%
Xtensor.unsqueeze(dim=0).shape
# Out:
# torch.Size([1, 1, 40, 282])

# %%
decoded1, decoded2, output_logits, output_softmax = model(Xtensor.unsqueeze(dim=0))

# %%
d = decoded1.squeeze(dim=0)
d = d.squeeze(dim=0)
d=d.cpu().detach().numpy()
d.shape
# Out:
# (40, 282)

# %%
d2 = decoded2.squeeze(dim=0)
d2 = d2.squeeze(dim=0)
d2=d2.cpu().detach().numpy()
d2.shape
# Out:
# (40, 282)

# %%
i=Xtensor.squeeze(dim=0)
i=i.cpu().detach().numpy()
i.shape
# Out:
# (40, 282)

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(librosa.power_to_db(i, ref=np.max), y_axis='mel', x_axis='time', cmap='viridis')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(librosa.power_to_db(d, ref=np.max), y_axis='mel', x_axis='time',cmap='viridis')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(librosa.power_to_db(d2, ref=np.max), y_axis='mel', x_axis='time',cmap='viridis')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()
