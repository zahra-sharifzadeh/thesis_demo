# %% [markdown]
# <a href="https://colab.research.google.com/github/zahra-sharifzadeh/thesis_demo/blob/main/Ravdess/parallel_2D_CNN_Transformer/parallel_2dCNN_Transformer_orginal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Setup

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os, glob
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import warnings; warnings.filterwarnings('ignore') #matplot lib complains about librosa

# %%
#google colab has an old version of librosa with missing mel spectrogram args (for MFCC); upgrade to current
# !pip install -U librosa
# Out:
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.23.5)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.5.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.0.7)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (4.0.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (23.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.11.17)

# %%
# needed to import dataset from google drive into colab
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# copy RAVDESS dataset from gdrive and unzip
# !cp '/content/gdrive/MyDrive/RAVDESS.zip' .
# !unzip -q RAVDESS.zip

# %% [markdown]
# ## Define features

# %%
# RAVDESS native sample rate is 48k
sample_rate = 48000

# Mel Spectrograms are not directly used as a feature in this model
# Mel Spectrograms are used in calculating MFCCs, which are a higher-level representation of pitch transition
# MFCCs work better - left the mel spectrogram function here in case anyone wants to experiment
def feature_melspectrogram(
    waveform,
    sample_rate,
    fft = 1024,
    winlen = 512,
    window='hamming',
    hop=256,
    mels=128,
    ):

    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram = librosa.feature.melspectrogram(
        y=waveform,
        sr=sample_rate,
        n_fft=fft,
        win_length=winlen,
        window=window,
        hop_length=hop,
        n_mels=mels,
        fmax=sample_rate/2)

    # convert from power (amplitude**2) to decibels
    # necessary for network to learn - doesn't converge with raw power spectrograms
    melspectrogram = librosa.power_to_db(melspectrogram, ref=np.max)

    return melspectrogram

def feature_mfcc(
    waveform,
    sample_rate,
    n_mfcc = 40,
    fft = 1024,
    winlen = 512,
    window='hamming',
    #hop=256, # increases # of time steps; was not helpful
    mels=128
    ):

    # Compute the MFCCs for all STFT frames
    # 40 mel filterbanks (n_mfcc) = 40 coefficients
    mfc_coefficients=librosa.feature.mfcc(
        y=waveform,
        sr=sample_rate,
        n_mfcc=n_mfcc,
        n_fft=fft,
        win_length=winlen,
        window=window,
        #hop_length=hop,
        n_mels=mels,
        fmax=sample_rate/2
        )

    return mfc_coefficients

def get_features(waveforms, features, samplerate):

    # initialize counter to track progress
    file_count = 0

    # process each waveform individually to get its MFCCs
    for waveform in waveforms:
        mfccs = feature_mfcc(waveform, sample_rate)
        features.append(mfccs)
        file_count += 1
        # print progress
        print('\r'+f' Processed {file_count}/{len(waveforms)} waveforms',end='')

    # return all features from list of waveforms
    return features

def get_waveforms(file):

    # load an individual sample audio file
    # read the full 3 seconds of the file, cut off the first 0.5s of silence; native sample rate = 48k
    # don't need to store the sample rate that librosa.load returns
    waveform, _ = librosa.load(file, duration=3, offset=0.5, sr=sample_rate)

    # make sure waveform vectors are homogenous by defining explicitly
    waveform_homo = np.zeros((int(sample_rate*3,)))
    waveform_homo[:len(waveform)] = waveform

    # return a single file's waveform
    return waveform_homo

# RAVDESS dataset emotions
# shift emotions left to be 0 indexed for PyTorch
emotions_dict ={
    '0':'surprised',
    '1':'neutral',
    '2':'calm',
    '3':'happy',
    '4':'sad',
    '5':'angry',
    '6':'fearful',
    '7':'disgust'
}

# Additional attributes from RAVDESS to play with
emotion_attributes = {
    '01': 'normal',
    '02': 'strong'
}

# %% [markdown]
# ## Load Data and Extract Features
#
#
# We process each file in the dataset and extract its features.
#
# We return the waveforms and the labels (from the file names of the RAVDESS audio samples). We return the raw waveforms because we're going to do some extra processing.

# %%
# path to data for glob
data_path = '/content/Actor_*/*.wav'

def load_data():
    # features and labels
    emotions = []
    # raw waveforms to augment later
    waveforms = []
    # extra labels
    intensities, genders = [],[]
    # progress counter
    file_count = 0
    for file in glob.glob(data_path):
        # get file name with labels
        file_name = os.path.basename(file)

        # get emotion label from the sample's file
        emotion = int(file_name.split("-")[2])

        #  move surprise to 0 for cleaner behaviour with PyTorch/0-indexing
        if emotion == 8: emotion = 0 # surprise is now at 0 index; other emotion indeces unchanged

        # can convert emotion label to emotion string if desired, but
        # training on number is better; better convert to emotion string after predictions are ready
        # emotion = emotions_dict[str(emotion)]

        # get other labels we might want
        intensity = emotion_attributes[file_name.split("-")[3]]
        # even actors are female, odd are male
        if (int((file_name.split("-")[6]).split(".")[0]))%2==0:
            gender = 'female'
        else:
            gender = 'male'

        # get waveform from the sample
        waveform = get_waveforms(file)

        # store waveforms and labels
        waveforms.append(waveform)
        emotions.append(emotion)
        intensities.append(intensity) # store intensity in case we wish to predict
        genders.append(gender) # store gender in case we wish to predict

        file_count += 1
        # keep track of data loader's progress
        print('\r'+f' Processed {file_count}/{1440} audio samples',end='')

    return waveforms, emotions, intensities, genders

# %%
# load data
# init explicitly to prevent data leakage from past sessions, since load_data() appends
waveforms, emotions, intensities, genders = [],[],[],[]
waveforms, emotions, intensities, genders = load_data()
# Out:
#  Processed 1440/1440 audio samples

# %% [markdown]
# ## Check extracted audio waveforms and labels:

# %%
print(f'Waveforms set: {len(waveforms)} samples')
# we have 1440 waveforms but we need to know their length too; should be 3 sec * 48k = 144k
print(f'Waveform signal length: {len(waveforms[0])}')
print(f'Emotions set: {len(emotions)} sample labels')
# Out:
# Waveforms set: 1440 samples
# Waveform signal length: 144000
# Emotions set: 1440 sample labels

# %% [markdown]
# Looks good. 1440 samples and 1440 labels in total.
#
# **Waveforms are 144k long because 3 seconds * 48k sample rate = 144k length array representing the 3 second audio snippet.**

# %% [markdown]
# ## Split into Train/Validation/Test Sets

# %%
# create storage for train, validation, test sets and their indices
train_set,valid_set,test_set = [],[],[]
X_train,X_valid,X_test = [],[],[]
y_train,y_valid,y_test = [],[],[]

# convert waveforms to array for processing
waveforms = np.array(waveforms)

# process each emotion separately to make sure we builf balanced train/valid/test sets
for emotion_num in range(len(emotions_dict)):

    # find all indices of a single unique emotion
    emotion_indices = [index for index, emotion in enumerate(emotions) if emotion==emotion_num]

    # seed for reproducibility
    np.random.seed(69)
    # shuffle indicies
    emotion_indices = np.random.permutation(emotion_indices)

    # store dim (length) of the emotion list to make indices
    dim = len(emotion_indices)

    # store indices of training, validation and test sets in 80/10/10 proportion
    # train set is first 80%
    train_indices = emotion_indices[:int(0.8*dim)]
    # validation set is next 10% (between 80% and 90%)
    valid_indices = emotion_indices[int(0.8*dim):int(0.9*dim)]
    # test set is last 10% (between 90% - end/100%)
    test_indices = emotion_indices[int(0.9*dim):]

    # create train waveforms/labels sets
    X_train.append(waveforms[train_indices,:])
    y_train.append(np.array([emotion_num]*len(train_indices),dtype=np.int32))
    # create validation waveforms/labels sets
    X_valid.append(waveforms[valid_indices,:])
    y_valid.append(np.array([emotion_num]*len(valid_indices),dtype=np.int32))
    # create test waveforms/labels sets
    X_test.append(waveforms[test_indices,:])
    y_test.append(np.array([emotion_num]*len(test_indices),dtype=np.int32))

    # store indices for each emotion set to verify uniqueness between sets
    train_set.append(train_indices)
    valid_set.append(valid_indices)
    test_set.append(test_indices)

# concatenate, in order, all waveforms back into one array
X_train = np.concatenate(X_train,axis=0)
X_valid = np.concatenate(X_valid,axis=0)
X_test = np.concatenate(X_test,axis=0)

# concatenate, in order, all emotions back into one array
y_train = np.concatenate(y_train,axis=0)
y_valid = np.concatenate(y_valid,axis=0)
y_test = np.concatenate(y_test,axis=0)

# combine and store indices for all emotions' train, validation, test sets to verify uniqueness of sets
train_set = np.concatenate(train_set,axis=0)
valid_set = np.concatenate(valid_set,axis=0)
test_set = np.concatenate(test_set,axis=0)

# check shape of each set
print(f'Training waveforms:{X_train.shape}, y_train:{y_train.shape}')
print(f'Validation waveforms:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'Test waveforms:{X_test.shape}, y_test:{y_test.shape}')

# make sure train, validation, test sets have no overlap/are unique
# get all unique indices across all sets and how many times each index appears (count)
uniques, count = np.unique(np.concatenate([train_set,test_set,valid_set],axis=0), return_counts=True)

# if each index appears just once, and we have 1440 such unique indices, then all sets are unique
if sum(count==1) == len(emotions):
    print(f'\nSets are unique: {sum(count==1)} samples out of {len(emotions)} are unique')
else:
    print(f'\nSets are NOT unique: {sum(count==1)} samples out of {len(emotions)} are unique')
# Out:
# Training waveforms:(1147, 144000), y_train:(1147,)
# Validation waveforms:(143, 144000), y_valid:(143,)
# Test waveforms:(150, 144000), y_test:(150,)
#
# Sets are unique: 1440 samples out of 1440 are unique

# %% [markdown]
# ## Extract Features

# %% [markdown]
# Extract the features from unaugmented waveforms first. In the next step, we'll append features from augmented waveforms to these 'native' features.

# %%
# initialize feature arrays
# We extract MFCC features from waveforms and store in respective 'features' array
features_train, features_valid, features_test = [],[],[]

print('Train waveforms:') # get training set features
features_train = get_features(X_train, features_train, sample_rate)

print('\n\nValidation waveforms:') # get validation set features
features_valid = get_features(X_valid, features_valid, sample_rate)

print('\n\nTest waveforms:') # get test set features
features_test = get_features(X_test, features_test, sample_rate)

print(f'\n\nFeatures set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'Features (MFC coefficient matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
#  Processed 1147/1147 waveforms
#
# Validation waveforms:
#  Processed 143/143 waveforms
#
# Test waveforms:
#  Processed 150/150 waveforms
#
# Features set: 1440 total, 1147 train, 143 validation, 150 test samples
# Features (MFC coefficient matrix) shape: 40 mel frequency coefficients x 282 time steps

# %% [markdown]
# ## Augmenting the Data with AWGN - Additive White Gaussian Noise

# %%
def awgn_augmentation(waveform, multiples=2, bits=16, snr_min=15, snr_max=30):

    # get length of waveform (should be 3*48k = 144k)
    wave_len = len(waveform)

    # Generate normally distributed (Gaussian) noises
    # one for each waveform and multiple (i.e. wave_len*multiples noises)
    noise = np.random.normal(size=(multiples, wave_len))

    # Normalize waveform and noise
    norm_constant = 2.0**(bits-1)
    norm_wave = waveform / norm_constant
    norm_noise = noise / norm_constant

    # Compute power of waveform and power of noise
    signal_power = np.sum(norm_wave ** 2) / wave_len
    noise_power = np.sum(norm_noise ** 2, axis=1) / wave_len

    # Choose random SNR in decibels in range [15,30]
    snr = np.random.randint(snr_min, snr_max)

    # Apply whitening transformation: make the Gaussian noise into Gaussian white noise
    # Compute the covariance matrix used to whiten each noise
    # actual SNR = signal/noise (power)
    # actual noise power = 10**(-snr/10)
    covariance = np.sqrt((signal_power / noise_power) * 10 ** (- snr / 10))
    # Get covariance matrix with dim: (144000, 2) so we can transform 2 noises: dim (2, 144000)
    covariance = np.ones((wave_len, multiples)) * covariance

    # Since covariance and noise are arrays, * is the haddamard product
    # Take Haddamard product of covariance and noise to generate white noise
    multiple_augmented_waveforms = waveform + covariance.T * noise

    return multiple_augmented_waveforms

# %%
def augment_waveforms(waveforms, features, emotions, multiples):
    # keep track of how many waveforms we've processed so we can add correct emotion label in the same order
    emotion_count = 0
    # keep track of how many augmented samples we've added
    added_count = 0
    # convert emotion array to list for more efficient appending
    emotions = emotions.tolist()

    for waveform in waveforms:

        # Generate 2 augmented multiples of the dataset, i.e. 1440 native + 1440*2 noisy = 4320 samples total
        augmented_waveforms = awgn_augmentation(waveform, multiples=multiples)

        # compute spectrogram for each of 2 augmented waveforms
        for augmented_waveform in augmented_waveforms:

            # Compute MFCCs over augmented waveforms
            augmented_mfcc = feature_mfcc(augmented_waveform, sample_rate=sample_rate)

            # append the augmented spectrogram to the rest of the native data
            features.append(augmented_mfcc)
            emotions.append(emotions[emotion_count])

            # keep track of new augmented samples
            added_count += 1

            # check progress
            print('\r'+f'Processed {emotion_count + 1}/{len(waveforms)} waveforms for {added_count}/{len(waveforms)*multiples} new augmented samples',end='')

        # keep track of the emotion labels to append in order
        emotion_count += 1

        # store augmented waveforms to check their shape
        augmented_waveforms_temp.append(augmented_waveforms)

    return features, emotions

# %% [markdown]
# ### Compute AWGN-augmented features and add to the rest of the dataset

# %%
# store augmented waveforms to verify their shape and random-ness
augmented_waveforms_temp = []

# specify multiples of our dataset to add as augmented data
multiples = 2

print('Train waveforms:') # augment waveforms of training set
features_train , y_train = augment_waveforms(X_train, features_train, y_train, multiples)

print('\n\nValidation waveforms:') # augment waveforms of validation set
features_valid, y_valid = augment_waveforms(X_valid, features_valid, y_valid, multiples)

print('\n\nTest waveforms:') # augment waveforms of test set
features_test, y_test = augment_waveforms(X_test, features_test, y_test, multiples)

# Check new shape of extracted features and data:
print(f'\n\nNative + Augmented Features set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'{len(y_train)} training sample labels, {len(y_valid)} validation sample labels, {len(y_test)} test sample labels')
print(f'Features (MFCC matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
# Processed 1147/1147 waveforms for 2294/2294 new augmented samples
#
# Validation waveforms:
# Processed 143/143 waveforms for 286/286 new augmented samples
#
# Test waveforms:
# Processed 150/150 waveforms for 300/300 new augmented samples
#
# Native + Augmented Features set: 4320 total, 3441 train, 429 validation, 450 test samples
# 3441 training sample labels, 429 validation sample labels, 450 test sample labels
# Features (MFCC matrix) shape: 40 mel frequency coefficients x 282 time steps

# %% [markdown]
# ### Check Augmented Waveforms:

# %%
# pick a random waveform, but same one from native and augmented set for easier comparison
plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveshow(waveforms[12], sr=sample_rate)
plt.title('Native')

plt.subplot(1, 2, 2)
# augmented waveforms are 2D len 1440 list with 2 waveforms in each position
librosa.display.waveshow(augmented_waveforms_temp[0][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveshow(augmented_waveforms_temp[2][0], sr=sample_rate)
plt.title('AWGN Augmented')

plt.subplot(1, 2, 2)
librosa.display.waveshow(augmented_waveforms_temp[7][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

# %% [markdown]
# ## Format Data into Tensor Ready 4D Arrays

# %%
# need to make dummy input channel for CNN input feature tensor
X_train = np.expand_dims(features_train,1)
X_valid = np.expand_dims(features_valid, 1)
X_test = np.expand_dims(features_test,1)

# convert emotion labels from list back to numpy arrays for PyTorch to work with
y_train = np.array(y_train)
y_valid = np.array(y_valid)
y_test = np.array(y_test)

# confiorm that we have tensor-ready 4D data array
# should print (batch, channel, width, height) == (4320, 1, 128, 282) when multiples==2
print(f'Shape of 4D feature array for input tensor: {X_train.shape} train, {X_valid.shape} validation, {X_test.shape} test')
print(f'Shape of emotion labels: {y_train.shape} train, {y_valid.shape} validation, {y_test.shape} test')
# Out:
# Shape of 4D feature array for input tensor: (3441, 1, 40, 282) train, (429, 1, 40, 282) validation, (450, 1, 40, 282) test
# Shape of emotion labels: (3441,) train, (429,) validation, (450,) test

# %%
# free up some RAM - no longer need full feature set or any waveforms
del features_train, features_valid, features_test, waveforms, augmented_waveforms_temp

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

#### Scale the training data ####
# store shape so we can transform it back
N,C,H,W = X_train.shape
# Reshape to 1D because StandardScaler operates on a 1D array
# tell numpy to infer shape of 1D array with '-1' argument
X_train = np.reshape(X_train, (N,-1))
X_train = scaler.fit_transform(X_train)
# Transform back to NxCxHxW 4D tensor format
X_train = np.reshape(X_train, (N,C,H,W))

##### Scale the validation set ####
N,C,H,W = X_valid.shape
X_valid = np.reshape(X_valid, (N,-1))
X_valid = scaler.transform(X_valid)
X_valid = np.reshape(X_valid, (N,C,H,W))

#### Scale the test set ####
N,C,H,W = X_test.shape
X_test = np.reshape(X_test, (N,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, (N,C,H,W))

# check shape of each set again
print(f'X_train scaled:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid scaled:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test scaled:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train scaled:(3441, 1, 40, 282), y_train:(3441,)
# X_valid scaled:(429, 1, 40, 282), y_valid:(429,)
# X_test scaled:(450, 1, 40, 282), y_test:(450,)

# %% [markdown]
# ## Save and Reload Data as NumPy Arrays
# We can save the training/validation/test data as numpy arrays to enable faster loading in case the notebook kernel crashes / google colab runtime crashes / any number of reasons the training data might be cleared from memory. This is much faster than loading 1440 files and computing their features again - not to mention augmented features.

# %%
###### SAVE #########
# choose save file name
filename = 'features+labels.npy'

# open file in write mode and write data
with open(filename, 'wb') as f:
    np.save(f, X_train)
    np.save(f, X_valid)
    np.save(f, X_test)
    np.save(f, y_train)
    np.save(f, y_valid)
    np.save(f, y_test)

print(f'Features and labels saved to {filename}')
# Out:
# Features and labels saved to features+labels.npy

# %%
##### LOAD #########
# choose load file name
filename = 'features+labels.npy'

# open file in read mode and read data
with open(filename, 'rb') as f:
    X_train = np.load(f)
    X_valid = np.load(f)
    X_test = np.load(f)
    y_train = np.load(f)
    y_valid = np.load(f)
    y_test = np.load(f)

# Check that we've recovered the right data
print(f'X_train:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train:(3441, 1, 40, 282), y_train:(3441,)
# X_valid:(429, 1, 40, 282), y_valid:(429,)
# X_test:(450, 1, 40, 282), y_test:(450,)

# %% [markdown]
# # Build Model Architecture and Define Forward Pass

# %%
#change nn.sequential to take dict to make more readable

class parallel_cnn_Transformer(nn.Module):
    # Define all layers present in the network
    def __init__(self,num_emotions):
        super().__init__()

        ################ TRANSFORMER BLOCK #############################
        # maxpool the input feature map/tensor to the transformer
        # a rectangular kernel worked better here for the rectangular input spectrogram feature map/tensor
        self.transformer_maxpool = nn.MaxPool2d(kernel_size=[1,4], stride=[1,4])

        # define single transformer encoder layer
        # self-attention + feedforward network from "Attention is All You Need" paper
        # 4 multi-head self-attention layers each with 40-->512--->40 feedforward network
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=40, # input feature (frequency) dim after maxpooling 40*282 -> 40*70 (MFC*time)
            nhead=4, # 4 self-attention layers in each multi-head self-attention layer in each encoder block
            dim_feedforward=512, # 2 linear layers in each encoder block's feedforward network: dim 40-->512--->40
            dropout=0.4,
            activation='relu' # ReLU: avoid saturation/tame gradient/reduce compute time
        )

        # I'm using 4 instead of the 6 identical stacked encoder layrs used in Attention is All You Need paper
        # Complete transformer block contains 4 full transformer encoder layers (each w/ multihead self-attention+feedforward)
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=4)

        ############### 1ST PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock1 = nn.Sequential(

            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training

            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16,
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3),

            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )
        ############### 2ND PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock2 = nn.Sequential(

            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training

            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16,
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3),

            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )

        ################# FINAL LINEAR BLOCK ####################
        # Linear softmax layer to take final concatenated embedding tensor
        #    from parallel 2D convolutional and transformer blocks, output 8 logits
        # Each full convolution block outputs (64*1*8) embedding flattened to dim 512 1D array
        # Full transformer block outputs 40*70 feature map, which we time-avg to dim 40 1D array
        # 512*2+40 == 1064 input features --> 8 output emotions
        self.fc1_linear = nn.Linear(512*2+40,num_emotions)

        ### Softmax layer for the 8 output logits from final FC linear layer
        self.softmax_out = nn.Softmax(dim=1) # dim==1 is the freq embedding

    # define one complete parallel fwd pass of input feature tensor thru 2*conv+1*transformer blocks
    def forward(self,x):

        ############ 1st parallel Conv2D block: 4 Convolutional layers ############################
        # create final feature embedding from 1st convolutional layer
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding1 = self.conv2Dblock1(x) # x == N/batch * channel * freq * time

        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding1 = torch.flatten(conv2d_embedding1, start_dim=1)

        ############ 2nd parallel Conv2D block: 4 Convolutional layers #############################
        # create final feature embedding from 2nd convolutional layer
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding2 = self.conv2Dblock2(x) # x == N/batch * channel * freq * time

        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding2 = torch.flatten(conv2d_embedding2, start_dim=1)


        ########## 4-encoder-layer Transformer block w/ 40-->512-->40 feedfwd network ##############
        # maxpool input feature map: 1*40*282 w/ 1*4 kernel --> 1*40*70
        x_maxpool = self.transformer_maxpool(x)

        # remove channel dim: 1*40*70 --> 40*70
        x_maxpool_reduced = torch.squeeze(x_maxpool,1)

        # convert maxpooled feature map format: batch * freq * time ---> time * batch * freq format
        # because transformer encoder layer requires tensor in format: time * batch * embedding (freq)
        x = x_maxpool_reduced.permute(2,0,1)

        # finally, pass reduced input feature map x into transformer encoder layers
        transformer_output = self.transformer_encoder(x)

        # create final feature emedding from transformer layer by taking mean in the time dimension (now the 0th dim)
        # transformer outputs 2x40 (MFCC embedding*time) feature map, take mean of columns i.e. take time average
        transformer_embedding = torch.mean(transformer_output, dim=0) # dim 40x70 --> 40

        ############# concatenate freq embeddings from convolutional and transformer blocks ######
        # concatenate embedding tensors output by parallel 2*conv and 1*transformer blocks
        complete_embedding = torch.cat([conv2d_embedding1, conv2d_embedding2,transformer_embedding], dim=1)

        ######### final FC linear layer, need logits for loss #########################
        output_logits = self.fc1_linear(complete_embedding)

        ######### Final Softmax layer: use logits from FC linear, get softmax for prediction ######
        output_softmax = self.softmax_out(output_logits)

        # need output logits to compute cross entropy loss, need softmax probabilities to predict class
        return output_logits, output_softmax

# %% [markdown]
# ## Analyzing The Flow of Tensors Through the Network
# We zero-pad 1 the input feature map to each convolutional layer to get back from the layer the same shape tensor as we input: zero-pad 1 adds 2 to each of (H, W) dims, and the 3x3, stride 1 kernels cuts off (kernel - stride == 2) dims from each of (H,W). **Zero-pad 1 --> 3x3 stride 1 kernel effectively throws away the zero pads to get same input/output shape from each conv2D block.**
#
# At the end of first convolutional layer in each block we have a maxpool kernel of size 2x2, stride 2 which will take 1 of 4 pixels in its winddow. For the first input feature map the maxpool kernel will progress 40/2 = 20 times over the rows and 282/2=141 times over the columns, producing a 20x141 output map. **Nonoverlapping maxpool kernels reduce each output dim to _input dim / kernel size_.** We then expand the output channels to 16 making an output feature map of (16x20x141).
#
# The next two convolutional layers in each block have a maxpool kernel size 4x4, stride 4. Same math as above, maxpool reduces each dim/4. 2nd conv layer takes (16x20x141) --> (32x5x35). 3rd and final conv layer takes (32x5x35) --> (64x1x8).
#
# **Note that in (N,C,H,W) format, for MFCCs H = MFCC (pitch),  W = time step.**
#
# **Complete flow through each convolutional block (C,H,W):**
#
#     Layer 1 ---> 1x40x282 --> PAD-1 --> 1x42x284 --> FILTER 1x3x3 --> 16x40x282 --> MAXPOOL 2x2 stride 2 --> 16x20x141
#
#     Layer 2 ---> 16x20x141 --> PAD-1 --> 16x22x143 --> FILTER 16x3x3 --> 32x20x141 --> MAXPOOL 4x4 stride 4 --> 32x5x35
#
#     Layer 3 ---> 32x5x35 --> PAD-1 --> 32x7x37 --> FILTER 32x3x3 --> 64x5x35 --> MAXPOOL 4x4 stride 4 --> 64x1x8
#
#     Flatten ---> 64x1x8 --> Final convolutional embedding length 512 1D array
#
#
# **Complete flow through transformer encoder block (C,H,W):**
#
#     Maxpool 1x4 stride 1x4 ---> 1x40x282 --> 1x20x70
#
#     Drop channel ---> 1x20x70 --> 20x70 (H,W)
#
#     Change dims ---> 20x70 --> 70x40 (W,H)
#
#     4xTransformer encoder ---> 70x40 --> 2x40 (W,H)
#
#     Time average ---> 2x40 --> 1x40 --> Final transformer embedding length 40 1D array
#
# **FC Linear network (C,H,W):**
#
#     Concatenate ---> 512+512+40 --> 1064
#
#     FC Linear layer ---> 1064 --> Final linear logits output length 8 1D array
#
#     Softmax layer: 8 ----> 1 predicted emotion / max probability class
#
#
# We can confirm our network's tensor shapes and flow using the excellent torchsummary package which provides a PyTorch implementation of Keras' model.summary method:

# %%
from torchsummary import summary

# need device to instantiate model
device = 'cuda'

# instantiate model for 8 emotions and move to GPU
model = parallel_cnn_Transformer(len(emotions_dict)).to(device)

# %% [markdown]
# ## Define Loss/Criterion
#
# We must define the loss function (criterion per PyTorch notation) for the backwards pass of each training iteration. Since our classes our balanced we don't need to specify a class-weight parameter (to balance classes).
#
# **PyTorch nn.CrossEntropyLoss() implements log softmax and negative log likelihood loss (nn.NLLoss() --> nn.LogSoftmax())
# We use log softmax for computation benefits and faster gradient optimization. Log softmax heavily penalizes the model when failing to predict the correct class.**

# %%
# define loss function; CrossEntropyLoss() fairly standard for multiclass problems
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %% [markdown]
# ## Choose Optimizer
#
# I used Adam to train an MLP due to its faster compute and convergence. Adam is great and usually works well with defaults.
#
# **However, a lot of 2018-2020 papers still use SGD. It seems to me that the reason is SGD with properly tuned momentum sometimes (often) converges to lower loss with enough training.**
#
# **Quoting [Wilson et al, 2017](https://arxiv.org/abs/1705.08292):**
#
#     “We observe that the solutions found by adaptive methods generalize worse (often significantly worse) than SGD, even
#     when these solutions have better training performance. These results suggest that practitioners should reconsider the
#     use of adaptive methods to train neural networks."
#
#
# "Adaptive methods" refers to the likes of Adam.
#
# **I took full advantage of plain old SGD by using the highest momentum leading to convergence, plus a generously long training time.**

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=0.001, weight_decay=1e-3, momentum=0.8)

# %% [markdown]
# ## Define Training Step
#
# We define a function to return a single training step defining one iteration of our model.
#
#     Forward pass output logits and softmax probabilities.
#
#     Record the softmax probabilities to track accuracy.
#
#     Pass output logits to loss function to compute loss.
#
#     Call backwards pass with loss function (backpropogate errors).
#
#     Tell optimizer to apply one update step to network parameters.
#
#     Zero the accumulated gradient in the optimizer for next iteration.

# %%
# define function to create a single step of the training phase
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X,Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %% [markdown]
# ## Define Validation Step
#
# Define a function to return a single validation step on the 10% X,y tensor pair to get an idea of our model's generalizibiliy as it trains so we know whether and when to stop it and tune hyperparameters. **Make sure we _do not_ update network parameters during validation by setting model to validation mode. Do not waste resources computing gradients in validation phase by setting torch.no_grad().**

# %%
def make_validate_fnc(model,criterion):
    def validate(X,Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()

            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y==predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits,Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %% [markdown]
# # Make Checkpoint Functions
# It's a good idea to save checkpoints of the model state after each epoch. We'll then interrupt training when satisfied with the model's performance and load the appropriate model binary.
#
# - Resume training if hardware/software fails
# - Save compute re-training by training from checkpoint after tuning
# - Implement early stopping easily by keeping snapshot of most performant version of model
# - Google Colab throttles GPU usage eventually; can't keep re-training from scratch indefinitely

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint

def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
# get training set size to calculate # iterations and minibatch indices
train_size = X_train.shape[0]

# pick minibatch size (of 32... always)
minibatch = 32

# set device to GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'{device} selected')

# instantiate model and move to GPU for training
model = parallel_cnn_Transformer(num_emotions=len(emotions_dict)).to(device)
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )

# encountered bugs in google colab only, unless I explicitly defined optimizer in this cell...
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# instantiate the checkpoint save function
save_checkpoint = make_save_checkpoint()

# instantiate the training step function
train_step = make_train_step(model, criterion, optimizer=optimizer)

# instantiate the validation loop function
validate = make_validate_fnc(model,criterion)

# instantiate lists to hold scalar performance metrics to plot later
train_losses=[]
valid_losses = []

# create training loop for one complete epoch (entire training set)
def train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid):

    for epoch in range(num_epochs):

        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices,:,:,:]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end,:,:,:]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]

            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)

            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor,Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}',end='')

        # create tensors from validation set
        X_valid_tensor = torch.tensor(X_valid,device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)

        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor,Y_valid_tensor)

        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)

        # Save checkpoint of the model
        checkpoint_filename = '/content/gdrive/My Drive/DL/models/checkpoints/model_final.pkl'
        save_checkpoint(optimizer, model, epoch, checkpoint_filename)

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')
# Out:
# cuda selected
# Number of trainable params:  248488

# %% [markdown]
# ### Train Model

# %%
# choose number of epochs higher than reasonable so we can manually stop training
num_epochs = 1500

# train it!
train(optimizer, model, num_epochs, X_train, y_train, X_valid, y_valid)
# Out:
# Epoch 0: iteration 106/107
# Epoch 0 --- loss:3.240, Epoch accuracy:28.36%, Validation loss:1.783, Validation accuracy:38.00%
# Epoch 1: iteration 106/107
# Epoch 1 --- loss:1.600, Epoch accuracy:38.62%, Validation loss:1.704, Validation accuracy:37.30%
# Epoch 2: iteration 106/107
# Epoch 2 --- loss:1.486, Epoch accuracy:42.69%, Validation loss:1.465, Validation accuracy:46.15%
# Epoch 3: iteration 106/107
# Epoch 3 --- loss:1.343, Epoch accuracy:49.75%, Validation loss:1.396, Validation accuracy:47.55%
# Epoch 4: iteration 106/107
# Epoch 4 --- loss:1.293, Epoch accuracy:50.92%, Validation loss:1.327, Validation accuracy:53.15%
# Epoch 5: iteration 106/107
# Epoch 5 --- loss:1.203, Epoch accuracy:54.08%, Validation loss:1.385, Validation accuracy:55.01%
# Epoch 6: iteration 106/107
# Epoch 6 --- loss:1.148, Epoch accuracy:56.76%, Validation loss:1.222, Validation accuracy:55.24%
# Epoch 7: iteration 106/107
# Epoch 7 --- loss:1.064, Epoch accuracy:60.07%, Validation loss:1.254, Validation accuracy:53.15%
# Epoch 8: iteration 106/107
# Epoch 8 --- loss:0.998, Epoch accuracy:62.66%, Validation loss:1.229, Validation accuracy:57.58%
# Epoch 9: iteration 106/107
# Epoch 9 --- loss:0.925, Epoch accuracy:65.21%, Validation loss:1.321, Validation accuracy:58.04%
# Epoch 10: iteration 106/107
# Epoch 10 --- loss:0.891, Epoch accuracy:66.72%, Validation loss:1.185, Validation accuracy:58.51%
# Epoch 11: iteration 106/107
# Epoch 11 --- loss:0.822, Epoch accuracy:69.51%, Validation loss:1.261, Validation accuracy:55.71%
# Epoch 12: iteration 106/107
# Epoch 12 --- loss:0.818, Epoch accuracy:69.69%, Validation loss:1.190, Validation accuracy:61.07%
# Epoch 13: iteration 106/107
# Epoch 13 --- loss:0.738, Epoch accuracy:72.30%, Validation loss:1.157, Validation accuracy:62.47%
# Epoch 14: iteration 106/107
# Epoch 14 --- loss:0.664, Epoch accuracy:76.20%, Validation loss:1.175, Validation accuracy:61.07%
# Epoch 15: iteration 106/107
# Epoch 15 --- loss:0.652, Epoch accuracy:75.33%, Validation loss:1.194, Validation accuracy:61.54%
# Epoch 16: iteration 106/107
# Epoch 16 --- loss:0.614, Epoch accuracy:76.93%, Validation loss:1.299, Validation accuracy:61.07%
# Epoch 17: iteration 106/107
# Epoch 17 --- loss:0.577, Epoch accuracy:78.35%, Validation loss:1.168, Validation accuracy:60.37%
# Epoch 18: iteration 106/107
# Epoch 18 --- loss:0.553, Epoch accuracy:80.12%, Validation loss:1.290, Validation accuracy:61.77%
# Epoch 19: iteration 106/107
# Epoch 19 --- loss:0.523, Epoch accuracy:80.30%, Validation loss:1.240, Validation accuracy:64.57%
# Epoch 20: iteration 106/107
# Epoch 20 --- loss:0.518, Epoch accuracy:80.50%, Validation loss:1.200, Validation accuracy:61.77%
# Epoch 21: iteration 106/107
# Epoch 21 --- loss:0.506, Epoch accuracy:81.20%, Validation loss:1.163, Validation accuracy:63.87%
# Epoch 22: iteration 106/107
# Epoch 22 --- loss:0.469, Epoch accuracy:82.59%, Validation loss:1.340, Validation accuracy:59.67%
# Epoch 23: iteration 106/107
# Epoch 23 --- loss:0.441, Epoch accuracy:83.58%, Validation loss:1.255, Validation accuracy:65.50%
# Epoch 24: iteration 106/107
# Epoch 24 --- loss:0.407, Epoch accuracy:85.29%, Validation loss:1.293, Validation accuracy:64.10%
# Epoch 25: iteration 106/107
# Epoch 25 --- loss:0.386, Epoch accuracy:85.53%, Validation loss:1.345, Validation accuracy:61.54%
# Epoch 26: iteration 106/107
# Epoch 26 --- loss:0.401, Epoch accuracy:84.95%, Validation loss:1.388, Validation accuracy:64.10%
# Epoch 27: iteration 106/107
# Epoch 27 --- loss:0.371, Epoch accuracy:86.60%, Validation loss:1.311, Validation accuracy:64.57%
# Epoch 28: iteration 106/107
# Epoch 28 --- loss:0.366, Epoch accuracy:86.28%, Validation loss:1.244, Validation accuracy:63.40%
# Epoch 29: iteration 106/107
# Epoch 29 --- loss:0.397, Epoch accuracy:84.80%, Validation loss:1.293, Validation accuracy:63.64%
# Epoch 30: iteration 106/107
# Epoch 30 --- loss:0.331, Epoch accuracy:87.77%, Validation loss:1.301, Validation accuracy:64.10%
# Epoch 31: iteration 106/107
# Epoch 31 --- loss:0.320, Epoch accuracy:87.59%, Validation loss:1.312, Validation accuracy:64.57%
# Epoch 32: iteration 106/107
# Epoch 32 --- loss:0.305, Epoch accuracy:89.04%, Validation loss:1.318, Validation accuracy:63.87%
# Epoch 33: iteration 106/107
# Epoch 33 --- loss:0.298, Epoch accuracy:88.96%, Validation loss:1.204, Validation accuracy:67.13%
# Epoch 34: iteration 106/107
# Epoch 34 --- loss:0.320, Epoch accuracy:88.17%, Validation loss:1.198, Validation accuracy:66.67%
# Epoch 35: iteration 106/107
# Epoch 35 --- loss:0.276, Epoch accuracy:90.21%, Validation loss:1.344, Validation accuracy:63.17%
# Epoch 36: iteration 106/107
# Epoch 36 --- loss:0.249, Epoch accuracy:91.22%, Validation loss:1.379, Validation accuracy:65.03%
# Epoch 37: iteration 106/107
# Epoch 37 --- loss:0.262, Epoch accuracy:90.35%, Validation loss:1.278, Validation accuracy:68.30%
# Epoch 38: iteration 106/107
# Epoch 38 --- loss:0.244, Epoch accuracy:91.22%, Validation loss:1.255, Validation accuracy:67.13%
# Epoch 39: iteration 106/107
# Epoch 39 --- loss:0.248, Epoch accuracy:90.64%, Validation loss:1.562, Validation accuracy:62.47%
# Epoch 40: iteration 106/107
# Epoch 40 --- loss:0.255, Epoch accuracy:90.47%, Validation loss:1.208, Validation accuracy:67.83%
# Epoch 41: iteration 106/107
# Epoch 41 --- loss:0.238, Epoch accuracy:90.53%, Validation loss:1.527, Validation accuracy:65.50%
# Epoch 42: iteration 106/107
# Epoch 42 --- loss:0.217, Epoch accuracy:91.86%, Validation loss:1.400, Validation accuracy:64.34%
# Epoch 43: iteration 106/107
# Epoch 43 --- loss:0.219, Epoch accuracy:92.01%, Validation loss:1.245, Validation accuracy:68.30%
# Epoch 44: iteration 106/107
# Epoch 44 --- loss:0.228, Epoch accuracy:91.34%, Validation loss:1.341, Validation accuracy:66.90%
# Epoch 45: iteration 106/107
# Epoch 45 --- loss:0.217, Epoch accuracy:91.78%, Validation loss:1.452, Validation accuracy:63.40%
# Epoch 46: iteration 106/107
# Epoch 46 --- loss:0.205, Epoch accuracy:92.10%, Validation loss:1.625, Validation accuracy:63.64%
# Epoch 47: iteration 106/107
# Epoch 47 --- loss:0.189, Epoch accuracy:93.52%, Validation loss:1.287, Validation accuracy:69.93%
# Epoch 48: iteration 106/107
# Epoch 48 --- loss:0.191, Epoch accuracy:92.76%, Validation loss:1.422, Validation accuracy:65.97%
# Epoch 49: iteration 106/107
# Epoch 49 --- loss:0.184, Epoch accuracy:93.32%, Validation loss:1.377, Validation accuracy:69.23%
# Epoch 50: iteration 106/107
# Epoch 50 --- loss:0.176, Epoch accuracy:93.75%, Validation loss:1.411, Validation accuracy:69.00%
# Epoch 51: iteration 106/107
# Epoch 51 --- loss:0.165, Epoch accuracy:94.48%, Validation loss:1.310, Validation accuracy:68.53%
# Epoch 52: iteration 106/107
# Epoch 52 --- loss:0.161, Epoch accuracy:94.19%, Validation loss:1.333, Validation accuracy:69.00%
# Epoch 53: iteration 106/107
# Epoch 53 --- loss:0.158, Epoch accuracy:94.27%, Validation loss:1.399, Validation accuracy:66.67%
# Epoch 54: iteration 106/107
# Epoch 54 --- loss:0.174, Epoch accuracy:93.32%, Validation loss:1.517, Validation accuracy:69.00%
# Epoch 55: iteration 106/107
# Epoch 55 --- loss:0.149, Epoch accuracy:94.71%, Validation loss:1.395, Validation accuracy:69.00%
# Epoch 56: iteration 106/107
# Epoch 56 --- loss:0.154, Epoch accuracy:94.48%, Validation loss:1.324, Validation accuracy:70.16%
# Epoch 57: iteration 106/107
# Epoch 57 --- loss:0.159, Epoch accuracy:94.19%, Validation loss:1.348, Validation accuracy:69.00%
# Epoch 58: iteration 106/107
# Epoch 58 --- loss:0.138, Epoch accuracy:95.00%, Validation loss:1.449, Validation accuracy:69.00%
# Epoch 59: iteration 106/107
# Epoch 59 --- loss:0.143, Epoch accuracy:94.77%, Validation loss:1.363, Validation accuracy:70.16%
# Epoch 60: iteration 106/107
# Epoch 60 --- loss:0.128, Epoch accuracy:95.20%, Validation loss:1.535, Validation accuracy:66.90%
# Epoch 61: iteration 106/107
# Epoch 61 --- loss:0.147, Epoch accuracy:94.36%, Validation loss:1.514, Validation accuracy:67.13%
# Epoch 62: iteration 106/107
# Epoch 62 --- loss:0.125, Epoch accuracy:95.41%, Validation loss:1.405, Validation accuracy:66.20%
# Epoch 63: iteration 106/107
# Epoch 63 --- loss:0.121, Epoch accuracy:95.87%, Validation loss:1.430, Validation accuracy:68.53%
# Epoch 64: iteration 106/107
# Epoch 64 --- loss:0.123, Epoch accuracy:95.20%, Validation loss:1.441, Validation accuracy:67.60%
# Epoch 65: iteration 106/107
# Epoch 65 --- loss:0.119, Epoch accuracy:95.58%, Validation loss:1.459, Validation accuracy:68.53%
# Epoch 66: iteration 106/107
# Epoch 66 --- loss:0.128, Epoch accuracy:95.18%, Validation loss:1.431, Validation accuracy:70.16%
# Epoch 67: iteration 106/107
# Epoch 67 --- loss:0.121, Epoch accuracy:95.55%, Validation loss:1.457, Validation accuracy:67.60%
# Epoch 68: iteration 106/107
# Epoch 68 --- loss:0.112, Epoch accuracy:96.05%, Validation loss:1.478, Validation accuracy:69.23%
# Epoch 69: iteration 106/107
# Epoch 69 --- loss:0.100, Epoch accuracy:96.63%, Validation loss:1.495, Validation accuracy:67.37%
# Epoch 70: iteration 106/107
# Epoch 70 --- loss:0.126, Epoch accuracy:94.86%, Validation loss:1.722, Validation accuracy:65.50%
# Epoch 71: iteration 106/107
# Epoch 71 --- loss:0.094, Epoch accuracy:96.98%, Validation loss:1.392, Validation accuracy:68.30%
# Epoch 72: iteration 106/107
# Epoch 72 --- loss:0.135, Epoch accuracy:95.15%, Validation loss:1.425, Validation accuracy:67.83%
# Epoch 73: iteration 106/107
# Epoch 73 --- loss:0.117, Epoch accuracy:95.38%, Validation loss:1.504, Validation accuracy:66.67%
# Epoch 74: iteration 106/107
# Epoch 74 --- loss:0.099, Epoch accuracy:96.43%, Validation loss:1.612, Validation accuracy:64.57%
# Epoch 75: iteration 106/107
# Epoch 75 --- loss:0.112, Epoch accuracy:95.70%, Validation loss:1.449, Validation accuracy:65.73%
# Epoch 76: iteration 106/107
# Epoch 76 --- loss:0.113, Epoch accuracy:96.11%, Validation loss:1.447, Validation accuracy:67.13%
# Epoch 77: iteration 106/107
# Epoch 77 --- loss:0.092, Epoch accuracy:96.75%, Validation loss:1.534, Validation accuracy:65.73%
# Epoch 78: iteration 106/107
# Epoch 78 --- loss:0.094, Epoch accuracy:96.37%, Validation loss:1.405, Validation accuracy:69.46%
# Epoch 79: iteration 106/107
# Epoch 79 --- loss:0.091, Epoch accuracy:96.75%, Validation loss:1.436, Validation accuracy:67.13%
# Epoch 80: iteration 106/107
# Epoch 80 --- loss:0.084, Epoch accuracy:97.27%, Validation loss:1.527, Validation accuracy:68.76%
# Epoch 81: iteration 106/107
# Epoch 81 --- loss:0.080, Epoch accuracy:96.98%, Validation loss:1.527, Validation accuracy:66.67%
# Epoch 82: iteration 106/107
# Epoch 82 --- loss:0.077, Epoch accuracy:97.18%, Validation loss:1.636, Validation accuracy:67.37%
# Epoch 83: iteration 106/107
# Epoch 83 --- loss:0.097, Epoch accuracy:96.22%, Validation loss:1.615, Validation accuracy:64.80%
# Epoch 84: iteration 106/107
# Epoch 84 --- loss:0.080, Epoch accuracy:97.24%, Validation loss:1.574, Validation accuracy:66.90%
# Epoch 85: iteration 106/107
# Epoch 85 --- loss:0.088, Epoch accuracy:96.77%, Validation loss:1.397, Validation accuracy:67.37%
# Epoch 86: iteration 106/107
# Epoch 86 --- loss:0.069, Epoch accuracy:97.50%, Validation loss:1.555, Validation accuracy:67.37%
# Epoch 87: iteration 106/107
# Epoch 87 --- loss:0.086, Epoch accuracy:96.77%, Validation loss:1.438, Validation accuracy:67.37%
# Epoch 88: iteration 106/107
# Epoch 88 --- loss:0.076, Epoch accuracy:97.15%, Validation loss:1.472, Validation accuracy:66.20%
# Epoch 89: iteration 106/107
# Epoch 89 --- loss:0.088, Epoch accuracy:96.83%, Validation loss:1.511, Validation accuracy:69.23%
# Epoch 90: iteration 106/107
# Epoch 90 --- loss:0.079, Epoch accuracy:96.95%, Validation loss:1.420, Validation accuracy:70.86%
# Epoch 91: iteration 106/107
# Epoch 91 --- loss:0.081, Epoch accuracy:97.09%, Validation loss:1.408, Validation accuracy:70.16%
# Epoch 92: iteration 106/107
# Epoch 92 --- loss:0.099, Epoch accuracy:96.37%, Validation loss:1.429, Validation accuracy:71.56%
# Epoch 93: iteration 106/107
# Epoch 93 --- loss:0.077, Epoch accuracy:97.06%, Validation loss:1.590, Validation accuracy:67.37%
# Epoch 94: iteration 106/107
# Epoch 94 --- loss:0.076, Epoch accuracy:97.27%, Validation loss:1.557, Validation accuracy:69.23%
# Epoch 95: iteration 106/107
# Epoch 95 --- loss:0.071, Epoch accuracy:97.50%, Validation loss:1.440, Validation accuracy:66.67%
# Epoch 96: iteration 106/107
# Epoch 96 --- loss:0.080, Epoch accuracy:96.89%, Validation loss:1.591, Validation accuracy:66.43%
# Epoch 97: iteration 106/107
# Epoch 97 --- loss:0.068, Epoch accuracy:97.68%, Validation loss:1.566, Validation accuracy:67.83%
# Epoch 98: iteration 106/107
# Epoch 98 --- loss:0.068, Epoch accuracy:97.50%, Validation loss:1.575, Validation accuracy:67.37%
# Epoch 99: iteration 106/107
# Epoch 99 --- loss:0.069, Epoch accuracy:97.56%, Validation loss:1.444, Validation accuracy:68.07%
# Epoch 100: iteration 106/107
# Epoch 100 --- loss:0.057, Epoch accuracy:98.11%, Validation loss:1.509, Validation accuracy:68.76%
# Epoch 101: iteration 106/107
# Epoch 101 --- loss:0.070, Epoch accuracy:97.53%, Validation loss:1.478, Validation accuracy:67.83%
# Epoch 102: iteration 106/107
# Epoch 102 --- loss:0.061, Epoch accuracy:97.88%, Validation loss:1.575, Validation accuracy:67.13%
# Epoch 103: iteration 106/107
# Epoch 103 --- loss:0.061, Epoch accuracy:98.02%, Validation loss:1.585, Validation accuracy:66.43%
# Epoch 104: iteration 106/107
# Epoch 104 --- loss:0.061, Epoch accuracy:98.17%, Validation loss:1.578, Validation accuracy:69.23%
# Epoch 105: iteration 106/107
# Epoch 105 --- loss:0.072, Epoch accuracy:97.21%, Validation loss:1.779, Validation accuracy:64.10%
# Epoch 106: iteration 106/107
# Epoch 106 --- loss:0.080, Epoch accuracy:97.15%, Validation loss:1.458, Validation accuracy:69.46%
# Epoch 107: iteration 106/107
# Epoch 107 --- loss:0.087, Epoch accuracy:96.92%, Validation loss:1.773, Validation accuracy:66.67%
# Epoch 108: iteration 106/107
# Epoch 108 --- loss:0.066, Epoch accuracy:97.56%, Validation loss:1.547, Validation accuracy:69.46%
# Epoch 109: iteration 106/107
# Epoch 109 --- loss:0.058, Epoch accuracy:97.56%, Validation loss:1.578, Validation accuracy:70.86%
# Epoch 110: iteration 106/107
# Epoch 110 --- loss:0.059, Epoch accuracy:97.85%, Validation loss:1.470, Validation accuracy:69.46%
# Epoch 111: iteration 106/107
# Epoch 111 --- loss:0.064, Epoch accuracy:97.62%, Validation loss:1.715, Validation accuracy:66.20%
# Epoch 112: iteration 106/107
# Epoch 112 --- loss:0.045, Epoch accuracy:98.55%, Validation loss:1.586, Validation accuracy:69.93%
# Epoch 113: iteration 106/107
# Epoch 113 --- loss:0.051, Epoch accuracy:98.11%, Validation loss:1.624, Validation accuracy:68.76%
# Epoch 114: iteration 106/107
# Epoch 114 --- loss:0.055, Epoch accuracy:98.05%, Validation loss:1.456, Validation accuracy:70.16%
# Epoch 115: iteration 106/107
# Epoch 115 --- loss:0.050, Epoch accuracy:98.11%, Validation loss:1.685, Validation accuracy:68.76%
# Epoch 116: iteration 106/107
# Epoch 116 --- loss:0.077, Epoch accuracy:96.98%, Validation loss:1.691, Validation accuracy:64.80%
# Epoch 117: iteration 106/107
# Epoch 117 --- loss:0.060, Epoch accuracy:97.79%, Validation loss:1.502, Validation accuracy:69.70%
# Epoch 118: iteration 106/107
# Epoch 118 --- loss:0.052, Epoch accuracy:98.14%, Validation loss:1.538, Validation accuracy:71.56%
# Epoch 119: iteration 106/107
# Epoch 119 --- loss:0.046, Epoch accuracy:98.61%, Validation loss:1.524, Validation accuracy:69.00%
# Epoch 120: iteration 106/107
# Epoch 120 --- loss:0.048, Epoch accuracy:98.29%, Validation loss:1.460, Validation accuracy:72.26%
# Epoch 121: iteration 106/107
# Epoch 121 --- loss:0.047, Epoch accuracy:98.40%, Validation loss:1.603, Validation accuracy:68.30%
# Epoch 122: iteration 106/107
# Epoch 122 --- loss:0.048, Epoch accuracy:98.14%, Validation loss:1.560, Validation accuracy:69.00%
# Epoch 123: iteration 106/107
# Epoch 123 --- loss:0.072, Epoch accuracy:96.92%, Validation loss:1.456, Validation accuracy:69.46%
# Epoch 124: iteration 106/107
# Epoch 124 --- loss:0.051, Epoch accuracy:98.08%, Validation loss:1.632, Validation accuracy:67.13%
# Epoch 125: iteration 106/107
# Epoch 125 --- loss:0.040, Epoch accuracy:98.61%, Validation loss:1.447, Validation accuracy:69.93%
# Epoch 126: iteration 106/107
# Epoch 126 --- loss:0.045, Epoch accuracy:98.31%, Validation loss:1.576, Validation accuracy:69.93%
# Epoch 127: iteration 106/107
# Epoch 127 --- loss:0.033, Epoch accuracy:99.01%, Validation loss:1.555, Validation accuracy:69.93%
# Epoch 128: iteration 106/107
# Epoch 128 --- loss:0.052, Epoch accuracy:98.17%, Validation loss:1.478, Validation accuracy:69.93%
# Epoch 129: iteration 106/107
# Epoch 129 --- loss:0.038, Epoch accuracy:98.43%, Validation loss:1.518, Validation accuracy:70.40%
# Epoch 130: iteration 106/107
# Epoch 130 --- loss:0.056, Epoch accuracy:97.76%, Validation loss:1.543, Validation accuracy:69.70%
# Epoch 131: iteration 106/107
# Epoch 131 --- loss:0.049, Epoch accuracy:98.20%, Validation loss:1.546, Validation accuracy:69.93%
# Epoch 132: iteration 106/107
# Epoch 132 --- loss:0.057, Epoch accuracy:97.82%, Validation loss:1.500, Validation accuracy:71.56%
# Epoch 133: iteration 106/107
# Epoch 133 --- loss:0.036, Epoch accuracy:98.84%, Validation loss:1.436, Validation accuracy:70.63%
# Epoch 134: iteration 106/107
# Epoch 134 --- loss:0.052, Epoch accuracy:97.91%, Validation loss:1.530, Validation accuracy:68.76%
# Epoch 135: iteration 106/107
# Epoch 135 --- loss:0.046, Epoch accuracy:98.29%, Validation loss:1.564, Validation accuracy:67.83%
# Epoch 136: iteration 106/107
# Epoch 136 --- loss:0.062, Epoch accuracy:97.79%, Validation loss:1.552, Validation accuracy:68.76%
# Epoch 137: iteration 106/107
# Epoch 137 --- loss:0.060, Epoch accuracy:97.76%, Validation loss:1.500, Validation accuracy:68.76%
# Epoch 138: iteration 106/107
# Epoch 138 --- loss:0.062, Epoch accuracy:97.65%, Validation loss:1.882, Validation accuracy:63.87%
# Epoch 139: iteration 106/107
# Epoch 139 --- loss:0.058, Epoch accuracy:97.73%, Validation loss:1.713, Validation accuracy:67.60%
# Epoch 140: iteration 106/107
# Epoch 140 --- loss:0.042, Epoch accuracy:98.55%, Validation loss:1.532, Validation accuracy:69.23%
# Epoch 141: iteration 106/107
# Epoch 141 --- loss:0.057, Epoch accuracy:97.70%, Validation loss:1.589, Validation accuracy:69.00%
# Epoch 142: iteration 106/107
# Epoch 142 --- loss:0.059, Epoch accuracy:97.82%, Validation loss:1.518, Validation accuracy:69.70%
# Epoch 143: iteration 106/107
# Epoch 143 --- loss:0.038, Epoch accuracy:98.69%, Validation loss:1.398, Validation accuracy:70.40%
# Epoch 144: iteration 106/107
# Epoch 144 --- loss:0.048, Epoch accuracy:98.14%, Validation loss:1.513, Validation accuracy:68.76%
# Epoch 145: iteration 106/107
# Epoch 145 --- loss:0.042, Epoch accuracy:98.49%, Validation loss:1.393, Validation accuracy:71.10%
# Epoch 146: iteration 106/107
# Epoch 146 --- loss:0.051, Epoch accuracy:98.20%, Validation loss:1.510, Validation accuracy:68.76%
# Epoch 147: iteration 106/107
# Epoch 147 --- loss:0.047, Epoch accuracy:98.46%, Validation loss:1.495, Validation accuracy:69.23%
# Epoch 148: iteration 106/107
# Epoch 148 --- loss:0.031, Epoch accuracy:99.10%, Validation loss:1.470, Validation accuracy:70.40%
# Epoch 149: iteration 106/107
# Epoch 149 --- loss:0.042, Epoch accuracy:98.29%, Validation loss:1.493, Validation accuracy:67.37%
# Epoch 150: iteration 106/107
# Epoch 150 --- loss:0.047, Epoch accuracy:98.26%, Validation loss:1.585, Validation accuracy:68.53%
# Epoch 151: iteration 106/107
# Epoch 151 --- loss:0.042, Epoch accuracy:98.20%, Validation loss:1.516, Validation accuracy:68.76%
# Epoch 152: iteration 106/107
# Epoch 152 --- loss:0.056, Epoch accuracy:98.05%, Validation loss:1.521, Validation accuracy:68.53%
# Epoch 153: iteration 106/107
# Epoch 153 --- loss:0.054, Epoch accuracy:97.85%, Validation loss:1.434, Validation accuracy:69.23%
# Epoch 154: iteration 106/107
# Epoch 154 --- loss:0.070, Epoch accuracy:97.06%, Validation loss:1.438, Validation accuracy:68.76%
# Epoch 155: iteration 106/107
# Epoch 155 --- loss:0.041, Epoch accuracy:98.63%, Validation loss:1.373, Validation accuracy:70.86%
# Epoch 156: iteration 106/107
# Epoch 156 --- loss:0.054, Epoch accuracy:98.05%, Validation loss:1.468, Validation accuracy:69.93%
# Epoch 157: iteration 106/107
# Epoch 157 --- loss:0.046, Epoch accuracy:98.40%, Validation loss:1.541, Validation accuracy:69.00%
# Epoch 158: iteration 106/107
# Epoch 158 --- loss:0.049, Epoch accuracy:98.11%, Validation loss:1.523, Validation accuracy:68.53%
# Epoch 159: iteration 106/107
# Epoch 159 --- loss:0.044, Epoch accuracy:98.37%, Validation loss:1.616, Validation accuracy:68.30%
# Epoch 160: iteration 106/107
# Epoch 160 --- loss:0.028, Epoch accuracy:99.10%, Validation loss:1.535, Validation accuracy:68.07%
# Epoch 161: iteration 106/107
# Epoch 161 --- loss:0.042, Epoch accuracy:98.37%, Validation loss:1.575, Validation accuracy:68.53%
# Epoch 162: iteration 106/107
# Epoch 162 --- loss:0.037, Epoch accuracy:98.75%, Validation loss:1.526, Validation accuracy:68.76%
# Epoch 163: iteration 106/107
# Epoch 163 --- loss:0.041, Epoch accuracy:98.61%, Validation loss:1.496, Validation accuracy:68.76%
# Epoch 164: iteration 106/107
# Epoch 164 --- loss:0.036, Epoch accuracy:98.81%, Validation loss:1.778, Validation accuracy:68.53%
# Epoch 165: iteration 106/107
# Epoch 165 --- loss:0.048, Epoch accuracy:98.23%, Validation loss:1.625, Validation accuracy:68.07%
# Epoch 166: iteration 106/107
# Epoch 166 --- loss:0.042, Epoch accuracy:98.40%, Validation loss:1.491, Validation accuracy:70.16%
# Epoch 167: iteration 106/107
# Epoch 167 --- loss:0.056, Epoch accuracy:97.94%, Validation loss:1.490, Validation accuracy:68.53%
# Epoch 168: iteration 106/107
# Epoch 168 --- loss:0.055, Epoch accuracy:97.94%, Validation loss:1.620, Validation accuracy:66.90%
# Epoch 169: iteration 106/107
# Epoch 169 --- loss:0.061, Epoch accuracy:97.65%, Validation loss:1.699, Validation accuracy:68.07%
# Epoch 170: iteration 106/107
# Epoch 170 --- loss:0.043, Epoch accuracy:98.43%, Validation loss:1.585, Validation accuracy:69.70%
# Epoch 171: iteration 106/107
# Epoch 171 --- loss:0.047, Epoch accuracy:98.29%, Validation loss:1.577, Validation accuracy:69.46%
# Epoch 172: iteration 106/107
# Epoch 172 --- loss:0.032, Epoch accuracy:98.90%, Validation loss:1.665, Validation accuracy:66.90%
# Epoch 173: iteration 106/107
# Epoch 173 --- loss:0.038, Epoch accuracy:98.66%, Validation loss:1.515, Validation accuracy:68.76%
# Epoch 174: iteration 106/107
# Epoch 174 --- loss:0.042, Epoch accuracy:98.37%, Validation loss:1.789, Validation accuracy:66.43%
# Epoch 175: iteration 106/107
# Epoch 175 --- loss:0.044, Epoch accuracy:98.46%, Validation loss:1.528, Validation accuracy:69.46%
# Epoch 176: iteration 106/107
# Epoch 176 --- loss:0.043, Epoch accuracy:98.40%, Validation loss:1.437, Validation accuracy:69.46%
# Epoch 177: iteration 106/107
# Epoch 177 --- loss:0.058, Epoch accuracy:97.50%, Validation loss:1.573, Validation accuracy:67.37%
# Epoch 178: iteration 106/107
# Epoch 178 --- loss:0.079, Epoch accuracy:96.98%, Validation loss:1.710, Validation accuracy:68.07%
# Epoch 179: iteration 106/107
# Epoch 179 --- loss:0.062, Epoch accuracy:97.85%, Validation loss:1.877, Validation accuracy:65.27%
# Epoch 180: iteration 106/107
# Epoch 180 --- loss:0.040, Epoch accuracy:98.72%, Validation loss:1.595, Validation accuracy:68.07%
# Epoch 181: iteration 106/107
# Epoch 181 --- loss:0.046, Epoch accuracy:98.31%, Validation loss:1.671, Validation accuracy:68.30%
# Epoch 182: iteration 106/107
# Epoch 182 --- loss:0.032, Epoch accuracy:98.98%, Validation loss:1.572, Validation accuracy:70.40%
# Epoch 183: iteration 106/107
# Epoch 183 --- loss:0.050, Epoch accuracy:98.20%, Validation loss:1.450, Validation accuracy:70.63%
# Epoch 184: iteration 106/107
# Epoch 184 --- loss:0.041, Epoch accuracy:98.55%, Validation loss:1.499, Validation accuracy:68.76%
# Epoch 185: iteration 106/107
# Epoch 185 --- loss:0.052, Epoch accuracy:98.17%, Validation loss:1.765, Validation accuracy:67.83%
# Epoch 186: iteration 106/107
# Epoch 186 --- loss:0.042, Epoch accuracy:98.29%, Validation loss:1.569, Validation accuracy:67.37%
# Epoch 187: iteration 106/107
# Epoch 187 --- loss:0.037, Epoch accuracy:98.63%, Validation loss:1.515, Validation accuracy:69.00%
# Epoch 188: iteration 106/107
# Epoch 188 --- loss:0.040, Epoch accuracy:98.52%, Validation loss:1.536, Validation accuracy:68.76%
# Epoch 189: iteration 106/107
# Epoch 189 --- loss:0.059, Epoch accuracy:97.73%, Validation loss:1.678, Validation accuracy:67.37%
# Epoch 190: iteration 106/107
# Epoch 190 --- loss:0.049, Epoch accuracy:97.99%, Validation loss:1.583, Validation accuracy:67.83%
# Epoch 191: iteration 106/107
# Epoch 191 --- loss:0.031, Epoch accuracy:98.84%, Validation loss:1.520, Validation accuracy:68.07%
# Epoch 192: iteration 106/107
# Epoch 192 --- loss:0.029, Epoch accuracy:98.98%, Validation loss:1.596, Validation accuracy:68.30%
# Epoch 193: iteration 106/107
# Epoch 193 --- loss:0.052, Epoch accuracy:98.20%, Validation loss:1.660, Validation accuracy:64.34%
# Epoch 194: iteration 106/107
# Epoch 194 --- loss:0.032, Epoch accuracy:98.92%, Validation loss:1.467, Validation accuracy:70.16%
# Epoch 195: iteration 106/107
# Epoch 195 --- loss:0.061, Epoch accuracy:97.76%, Validation loss:1.628, Validation accuracy:69.46%
# Epoch 196: iteration 106/107
# Epoch 196 --- loss:0.046, Epoch accuracy:98.34%, Validation loss:1.509, Validation accuracy:70.16%
# Epoch 197: iteration 106/107
# Epoch 197 --- loss:0.036, Epoch accuracy:98.78%, Validation loss:1.480, Validation accuracy:69.93%
# Epoch 198: iteration 106/107
# Epoch 198 --- loss:0.031, Epoch accuracy:98.98%, Validation loss:1.581, Validation accuracy:69.00%
# Epoch 199: iteration 106/107
# Epoch 199 --- loss:0.043, Epoch accuracy:98.23%, Validation loss:1.519, Validation accuracy:69.23%
# Epoch 200: iteration 106/107
# Epoch 200 --- loss:0.029, Epoch accuracy:98.92%, Validation loss:1.476, Validation accuracy:67.83%
# Epoch 201: iteration 106/107
# Epoch 201 --- loss:0.036, Epoch accuracy:98.63%, Validation loss:1.494, Validation accuracy:68.53%
# Epoch 202: iteration 106/107
# Epoch 202 --- loss:0.027, Epoch accuracy:98.98%, Validation loss:1.515, Validation accuracy:69.70%
# Epoch 203: iteration 106/107
# Epoch 203 --- loss:0.073, Epoch accuracy:97.09%, Validation loss:1.580, Validation accuracy:68.07%
# Epoch 204: iteration 106/107
# Epoch 204 --- loss:0.044, Epoch accuracy:98.26%, Validation loss:1.500, Validation accuracy:69.70%
# Epoch 205: iteration 106/107
# Epoch 205 --- loss:0.045, Epoch accuracy:97.97%, Validation loss:1.482, Validation accuracy:69.00%
# Epoch 206: iteration 106/107
# Epoch 206 --- loss:0.050, Epoch accuracy:98.23%, Validation loss:1.595, Validation accuracy:68.30%
# Epoch 207: iteration 106/107
# Epoch 207 --- loss:0.066, Epoch accuracy:97.47%, Validation loss:1.628, Validation accuracy:66.20%
# Epoch 208: iteration 106/107
# Epoch 208 --- loss:0.041, Epoch accuracy:98.63%, Validation loss:1.599, Validation accuracy:68.30%
# Epoch 209: iteration 106/107
# Epoch 209 --- loss:0.106, Epoch accuracy:96.02%, Validation loss:1.732, Validation accuracy:63.17%
# Epoch 210: iteration 106/107
# Epoch 210 --- loss:0.060, Epoch accuracy:97.85%, Validation loss:1.631, Validation accuracy:69.46%
# Epoch 211: iteration 106/107
# Epoch 211 --- loss:0.039, Epoch accuracy:98.40%, Validation loss:1.513, Validation accuracy:70.16%
# Epoch 212: iteration 106/107
# Epoch 212 --- loss:0.033, Epoch accuracy:98.78%, Validation loss:1.456, Validation accuracy:70.16%
# Epoch 213: iteration 106/107
# Epoch 213 --- loss:0.041, Epoch accuracy:98.40%, Validation loss:1.531, Validation accuracy:69.00%
# Epoch 214: iteration 106/107
# Epoch 214 --- loss:0.026, Epoch accuracy:99.19%, Validation loss:1.577, Validation accuracy:69.23%
# Epoch 215: iteration 106/107
# Epoch 215 --- loss:0.027, Epoch accuracy:98.87%, Validation loss:1.635, Validation accuracy:67.83%
# Epoch 216: iteration 106/107
# Epoch 216 --- loss:0.041, Epoch accuracy:98.23%, Validation loss:1.510, Validation accuracy:72.49%
# Epoch 217: iteration 106/107
# Epoch 217 --- loss:0.037, Epoch accuracy:98.87%, Validation loss:1.603, Validation accuracy:67.37%
# Epoch 218: iteration 106/107
# Epoch 218 --- loss:0.028, Epoch accuracy:99.01%, Validation loss:1.644, Validation accuracy:68.30%
# Epoch 219: iteration 106/107
# Epoch 219 --- loss:0.032, Epoch accuracy:98.78%, Validation loss:1.476, Validation accuracy:70.63%
# Epoch 220: iteration 106/107
# Epoch 220 --- loss:0.047, Epoch accuracy:98.20%, Validation loss:1.581, Validation accuracy:70.40%
# Epoch 221: iteration 106/107
# Epoch 221 --- loss:0.058, Epoch accuracy:97.68%, Validation loss:1.689, Validation accuracy:67.60%
# Epoch 222: iteration 106/107
# Epoch 222 --- loss:0.043, Epoch accuracy:98.29%, Validation loss:1.808, Validation accuracy:62.47%
# Epoch 223: iteration 106/107
# Epoch 223 --- loss:0.050, Epoch accuracy:97.99%, Validation loss:1.907, Validation accuracy:65.97%
# Epoch 224: iteration 106/107
# Epoch 224 --- loss:0.088, Epoch accuracy:96.28%, Validation loss:1.688, Validation accuracy:68.07%
# Epoch 225: iteration 106/107
# Epoch 225 --- loss:0.093, Epoch accuracy:96.54%, Validation loss:1.654, Validation accuracy:66.20%
# Epoch 226: iteration 106/107
# Epoch 226 --- loss:0.047, Epoch accuracy:98.26%, Validation loss:1.510, Validation accuracy:67.60%
# Epoch 227: iteration 106/107
# Epoch 227 --- loss:0.035, Epoch accuracy:98.78%, Validation loss:1.676, Validation accuracy:67.60%
# Epoch 228: iteration 106/107
# Epoch 228 --- loss:0.030, Epoch accuracy:99.01%, Validation loss:1.544, Validation accuracy:68.30%
# Epoch 229: iteration 106/107
# Epoch 229 --- loss:0.022, Epoch accuracy:99.22%, Validation loss:1.606, Validation accuracy:67.60%
# Epoch 230: iteration 106/107
# Epoch 230 --- loss:0.028, Epoch accuracy:99.07%, Validation loss:1.596, Validation accuracy:68.53%
# Epoch 231: iteration 106/107
# Epoch 231 --- loss:0.038, Epoch accuracy:98.55%, Validation loss:1.654, Validation accuracy:66.20%
# Epoch 232: iteration 106/107
# Epoch 232 --- loss:0.036, Epoch accuracy:98.58%, Validation loss:1.628, Validation accuracy:68.76%
# Epoch 233: iteration 106/107
# Epoch 233 --- loss:0.043, Epoch accuracy:98.29%, Validation loss:1.667, Validation accuracy:68.30%
# Epoch 234: iteration 106/107
# Epoch 234 --- loss:0.047, Epoch accuracy:98.14%, Validation loss:1.573, Validation accuracy:68.30%
# Epoch 235: iteration 106/107
# Epoch 235 --- loss:0.043, Epoch accuracy:98.49%, Validation loss:1.597, Validation accuracy:67.60%
# Epoch 236: iteration 106/107
# Epoch 236 --- loss:0.033, Epoch accuracy:98.52%, Validation loss:1.510, Validation accuracy:70.16%
# Epoch 237: iteration 106/107
# Epoch 237 --- loss:0.036, Epoch accuracy:98.63%, Validation loss:1.571, Validation accuracy:69.46%
# Epoch 238: iteration 106/107
# Epoch 238 --- loss:0.030, Epoch accuracy:98.72%, Validation loss:1.525, Validation accuracy:71.10%
# Epoch 239: iteration 106/107
# Epoch 239 --- loss:0.145, Epoch accuracy:94.89%, Validation loss:1.515, Validation accuracy:65.50%
# Epoch 240: iteration 106/107
# Epoch 240 --- loss:0.068, Epoch accuracy:97.06%, Validation loss:1.546, Validation accuracy:68.07%
# Epoch 241: iteration 106/107
# Epoch 241 --- loss:0.046, Epoch accuracy:98.08%, Validation loss:1.577, Validation accuracy:67.83%
# Epoch 242: iteration 106/107
# Epoch 242 --- loss:0.049, Epoch accuracy:98.17%, Validation loss:1.678, Validation accuracy:66.67%
# Epoch 243: iteration 106/107
# Epoch 243 --- loss:0.047, Epoch accuracy:98.23%, Validation loss:1.558, Validation accuracy:69.00%
# Epoch 244: iteration 106/107
# Epoch 244 --- loss:0.042, Epoch accuracy:98.43%, Validation loss:1.616, Validation accuracy:71.56%
# Epoch 245: iteration 106/107
# Epoch 245 --- loss:0.032, Epoch accuracy:98.84%, Validation loss:1.563, Validation accuracy:69.93%
# Epoch 246: iteration 106/107
# Epoch 246 --- loss:0.030, Epoch accuracy:98.98%, Validation loss:1.472, Validation accuracy:66.90%
# Epoch 247: iteration 106/107
# Epoch 247 --- loss:0.020, Epoch accuracy:99.33%, Validation loss:1.559, Validation accuracy:68.76%
# Epoch 248: iteration 106/107
# Epoch 248 --- loss:0.024, Epoch accuracy:99.07%, Validation loss:1.557, Validation accuracy:69.93%
# Epoch 249: iteration 106/107
# Epoch 249 --- loss:0.029, Epoch accuracy:99.04%, Validation loss:1.698, Validation accuracy:64.34%
# Epoch 250: iteration 106/107
# Epoch 250 --- loss:0.025, Epoch accuracy:99.19%, Validation loss:1.618, Validation accuracy:69.23%
# Epoch 251: iteration 106/107
# Epoch 251 --- loss:0.035, Epoch accuracy:98.49%, Validation loss:1.678, Validation accuracy:67.37%
# Epoch 252: iteration 106/107
# Epoch 252 --- loss:0.041, Epoch accuracy:98.43%, Validation loss:1.684, Validation accuracy:67.13%
# Epoch 253: iteration 106/107
# Epoch 253 --- loss:0.044, Epoch accuracy:98.17%, Validation loss:1.733, Validation accuracy:66.90%
# Epoch 254: iteration 106/107
# Epoch 254 --- loss:0.090, Epoch accuracy:96.43%, Validation loss:1.707, Validation accuracy:64.57%
# Epoch 255: iteration 106/107
# Epoch 255 --- loss:0.057, Epoch accuracy:97.76%, Validation loss:1.973, Validation accuracy:64.10%
# Epoch 256: iteration 106/107
# Epoch 256 --- loss:0.097, Epoch accuracy:96.16%, Validation loss:1.661, Validation accuracy:66.43%
# Epoch 257: iteration 106/107
# Epoch 257 --- loss:0.059, Epoch accuracy:97.70%, Validation loss:1.490, Validation accuracy:68.30%
# Epoch 258: iteration 106/107
# Epoch 258 --- loss:0.039, Epoch accuracy:98.75%, Validation loss:1.482, Validation accuracy:67.83%
# Epoch 259: iteration 106/107
# Epoch 259 --- loss:0.030, Epoch accuracy:98.90%, Validation loss:1.564, Validation accuracy:68.53%
# Epoch 260: iteration 106/107
# Epoch 260 --- loss:0.038, Epoch accuracy:98.52%, Validation loss:1.532, Validation accuracy:69.46%
# Epoch 261: iteration 106/107
# Epoch 261 --- loss:0.041, Epoch accuracy:98.34%, Validation loss:1.494, Validation accuracy:68.53%
# Epoch 262: iteration 106/107
# Epoch 262 --- loss:0.059, Epoch accuracy:97.73%, Validation loss:1.619, Validation accuracy:67.83%
# Epoch 263: iteration 106/107
# Epoch 263 --- loss:0.056, Epoch accuracy:97.99%, Validation loss:1.623, Validation accuracy:69.70%
# Epoch 264: iteration 106/107
# Epoch 264 --- loss:0.034, Epoch accuracy:98.69%, Validation loss:1.591, Validation accuracy:66.43%
# Epoch 265: iteration 106/107
# Epoch 265 --- loss:0.035, Epoch accuracy:98.58%, Validation loss:1.534, Validation accuracy:67.60%
# Epoch 266: iteration 106/107
# Epoch 266 --- loss:0.043, Epoch accuracy:98.46%, Validation loss:1.538, Validation accuracy:72.03%
# Epoch 267: iteration 106/107
# Epoch 267 --- loss:0.038, Epoch accuracy:98.34%, Validation loss:1.605, Validation accuracy:67.83%
# Epoch 268: iteration 106/107
# Epoch 268 --- loss:0.037, Epoch accuracy:98.75%, Validation loss:1.577, Validation accuracy:67.13%
# Epoch 269: iteration 106/107
# Epoch 269 --- loss:0.035, Epoch accuracy:98.52%, Validation loss:1.813, Validation accuracy:66.90%
# Epoch 270: iteration 106/107
# Epoch 270 --- loss:0.043, Epoch accuracy:98.49%, Validation loss:1.683, Validation accuracy:66.67%
# Epoch 271: iteration 106/107
# Epoch 271 --- loss:0.026, Epoch accuracy:99.01%, Validation loss:1.656, Validation accuracy:66.67%
# Epoch 272: iteration 106/107
# Epoch 272 --- loss:0.031, Epoch accuracy:98.75%, Validation loss:1.960, Validation accuracy:63.40%
# Epoch 273: iteration 106/107
# Epoch 273 --- loss:0.068, Epoch accuracy:97.41%, Validation loss:1.585, Validation accuracy:70.86%
# Epoch 274: iteration 106/107
# Epoch 274 --- loss:0.065, Epoch accuracy:97.12%, Validation loss:1.665, Validation accuracy:64.34%
# Epoch 275: iteration 106/107
# Epoch 275 --- loss:0.070, Epoch accuracy:97.15%, Validation loss:1.788, Validation accuracy:66.90%
# Epoch 276: iteration 106/107
# Epoch 276 --- loss:0.071, Epoch accuracy:97.36%, Validation loss:1.744, Validation accuracy:67.60%
# Epoch 277: iteration 106/107
# Epoch 277 --- loss:0.042, Epoch accuracy:98.37%, Validation loss:1.532, Validation accuracy:71.10%
# Epoch 278: iteration 106/107
# Epoch 278 --- loss:0.048, Epoch accuracy:98.11%, Validation loss:1.597, Validation accuracy:67.83%
# Epoch 279: iteration 106/107
# Epoch 279 --- loss:0.034, Epoch accuracy:98.75%, Validation loss:1.825, Validation accuracy:66.43%
# Epoch 280: iteration 106/107
# Epoch 280 --- loss:0.033, Epoch accuracy:98.69%, Validation loss:1.555, Validation accuracy:68.07%
# Epoch 281: iteration 106/107
# Epoch 281 --- loss:0.034, Epoch accuracy:98.55%, Validation loss:1.578, Validation accuracy:70.63%
# Epoch 282: iteration 106/107
# Epoch 282 --- loss:0.033, Epoch accuracy:98.63%, Validation loss:1.923, Validation accuracy:65.73%
# Epoch 283: iteration 106/107
# Epoch 283 --- loss:0.050, Epoch accuracy:97.79%, Validation loss:1.713, Validation accuracy:66.43%
# Epoch 284: iteration 106/107
# Epoch 284 --- loss:0.087, Epoch accuracy:96.86%, Validation loss:1.546, Validation accuracy:68.76%
# Epoch 285: iteration 106/107
# Epoch 285 --- loss:0.033, Epoch accuracy:98.84%, Validation loss:1.660, Validation accuracy:68.76%
# Epoch 286: iteration 106/107
# Epoch 286 --- loss:0.031, Epoch accuracy:98.81%, Validation loss:1.650, Validation accuracy:70.40%
# Epoch 287: iteration 106/107
# Epoch 287 --- loss:0.030, Epoch accuracy:98.81%, Validation loss:1.532, Validation accuracy:70.86%
# Epoch 288: iteration 106/107
# Epoch 288 --- loss:0.027, Epoch accuracy:98.92%, Validation loss:1.692, Validation accuracy:67.83%
# Epoch 289: iteration 106/107
# Epoch 289 --- loss:0.039, Epoch accuracy:98.55%, Validation loss:1.828, Validation accuracy:66.20%
# Epoch 290: iteration 106/107
# Epoch 290 --- loss:0.036, Epoch accuracy:98.72%, Validation loss:1.541, Validation accuracy:70.63%
# Epoch 291: iteration 106/107
# Epoch 291 --- loss:0.034, Epoch accuracy:98.55%, Validation loss:1.589, Validation accuracy:69.46%
# Epoch 292: iteration 106/107
# Epoch 292 --- loss:0.024, Epoch accuracy:98.92%, Validation loss:1.648, Validation accuracy:71.79%
# Epoch 293: iteration 106/107
# Epoch 293 --- loss:0.027, Epoch accuracy:99.01%, Validation loss:1.518, Validation accuracy:71.33%
# Epoch 294: iteration 106/107
# Epoch 294 --- loss:0.026, Epoch accuracy:98.95%, Validation loss:1.672, Validation accuracy:67.13%
# Epoch 295: iteration 106/107
# Epoch 295 --- loss:0.043, Epoch accuracy:98.40%, Validation loss:1.560, Validation accuracy:68.30%
# Epoch 296: iteration 106/107
# Epoch 296 --- loss:0.035, Epoch accuracy:98.58%, Validation loss:1.519, Validation accuracy:70.16%
# Epoch 297: iteration 106/107
# Epoch 297 --- loss:0.086, Epoch accuracy:96.48%, Validation loss:1.651, Validation accuracy:67.83%
# Epoch 298: iteration 106/107
# Epoch 298 --- loss:0.067, Epoch accuracy:97.41%, Validation loss:1.571, Validation accuracy:68.30%
# Epoch 299: iteration 106/107
# Epoch 299 --- loss:0.039, Epoch accuracy:98.31%, Validation loss:1.641, Validation accuracy:67.60%
# Epoch 300: iteration 106/107
# Epoch 300 --- loss:0.055, Epoch accuracy:97.70%, Validation loss:1.618, Validation accuracy:69.00%
# Epoch 301: iteration 106/107
# Epoch 301 --- loss:0.036, Epoch accuracy:98.43%, Validation loss:1.726, Validation accuracy:65.03%
# Epoch 302: iteration 106/107
# Epoch 302 --- loss:0.030, Epoch accuracy:98.81%, Validation loss:1.654, Validation accuracy:67.83%
# Epoch 303: iteration 106/107
# Epoch 303 --- loss:0.026, Epoch accuracy:99.16%, Validation loss:1.597, Validation accuracy:67.60%
# Epoch 304: iteration 106/107
# Epoch 304 --- loss:0.022, Epoch accuracy:99.19%, Validation loss:1.603, Validation accuracy:68.76%
# Epoch 305: iteration 106/107
# Epoch 305 --- loss:0.052, Epoch accuracy:97.99%, Validation loss:1.844, Validation accuracy:65.50%
# Epoch 306: iteration 106/107
# Epoch 306 --- loss:0.032, Epoch accuracy:98.66%, Validation loss:1.711, Validation accuracy:67.83%
# Epoch 307: iteration 106/107
# Epoch 307 --- loss:0.036, Epoch accuracy:98.75%, Validation loss:1.603, Validation accuracy:68.76%
# Epoch 308: iteration 106/107
# Epoch 308 --- loss:0.032, Epoch accuracy:98.63%, Validation loss:1.553, Validation accuracy:68.07%
# Epoch 309: iteration 106/107
# Epoch 309 --- loss:0.035, Epoch accuracy:98.43%, Validation loss:1.556, Validation accuracy:68.76%
# Epoch 310: iteration 106/107
# Epoch 310 --- loss:0.030, Epoch accuracy:98.78%, Validation loss:1.620, Validation accuracy:67.83%
# Epoch 311: iteration 106/107
# Epoch 311 --- loss:0.043, Epoch accuracy:98.17%, Validation loss:1.682, Validation accuracy:65.73%
# Epoch 312: iteration 106/107
# Epoch 312 --- loss:0.105, Epoch accuracy:96.28%, Validation loss:1.870, Validation accuracy:62.24%
# Epoch 313: iteration 106/107
# Epoch 313 --- loss:0.078, Epoch accuracy:97.24%, Validation loss:1.644, Validation accuracy:67.83%
# Epoch 314: iteration 106/107
# Epoch 314 --- loss:0.036, Epoch accuracy:98.58%, Validation loss:1.633, Validation accuracy:68.07%
# Epoch 315: iteration 106/107
# Epoch 315 --- loss:0.034, Epoch accuracy:98.75%, Validation loss:1.593, Validation accuracy:70.40%
# Epoch 316: iteration 106/107
# Epoch 316 --- loss:0.033, Epoch accuracy:98.61%, Validation loss:1.652, Validation accuracy:69.00%
# Epoch 317: iteration 106/107
# Epoch 317 --- loss:0.120, Epoch accuracy:95.58%, Validation loss:1.663, Validation accuracy:66.67%
# Epoch 318: iteration 106/107
# Epoch 318 --- loss:0.054, Epoch accuracy:98.02%, Validation loss:1.572, Validation accuracy:68.30%
# Epoch 319: iteration 106/107
# Epoch 319 --- loss:0.029, Epoch accuracy:98.95%, Validation loss:1.641, Validation accuracy:67.83%
# Epoch 320: iteration 106/107
# Epoch 320 --- loss:0.026, Epoch accuracy:98.95%, Validation loss:1.547, Validation accuracy:71.10%
# Epoch 321: iteration 106/107
# Epoch 321 --- loss:0.024, Epoch accuracy:99.16%, Validation loss:1.511, Validation accuracy:69.93%
# Epoch 322: iteration 106/107
# Epoch 322 --- loss:0.031, Epoch accuracy:98.72%, Validation loss:1.528, Validation accuracy:70.63%
# Epoch 323: iteration 106/107
# Epoch 323 --- loss:0.035, Epoch accuracy:98.61%, Validation loss:1.561, Validation accuracy:69.93%
# Epoch 324: iteration 106/107
# Epoch 324 --- loss:0.057, Epoch accuracy:97.88%, Validation loss:1.527, Validation accuracy:69.46%
# Epoch 325: iteration 106/107
# Epoch 325 --- loss:0.063, Epoch accuracy:97.50%, Validation loss:1.534, Validation accuracy:67.83%
# Epoch 326: iteration 106/107
# Epoch 326 --- loss:0.028, Epoch accuracy:98.90%, Validation loss:1.514, Validation accuracy:67.13%
# Epoch 327: iteration 106/107
# Epoch 327 --- loss:0.026, Epoch accuracy:98.98%, Validation loss:1.599, Validation accuracy:69.93%
# Epoch 328: iteration 106/107
# Epoch 328 --- loss:0.026, Epoch accuracy:98.90%, Validation loss:1.541, Validation accuracy:69.23%
# Epoch 329: iteration 106/107
# Epoch 329 --- loss:0.035, Epoch accuracy:98.81%, Validation loss:1.679, Validation accuracy:67.13%
# Epoch 330: iteration 106/107
# Epoch 330 --- loss:0.033, Epoch accuracy:98.72%, Validation loss:1.733, Validation accuracy:68.30%
# Epoch 331: iteration 106/107
# Epoch 331 --- loss:0.044, Epoch accuracy:98.29%, Validation loss:2.132, Validation accuracy:61.77%
# Epoch 332: iteration 106/107
# Epoch 332 --- loss:0.056, Epoch accuracy:97.99%, Validation loss:1.585, Validation accuracy:65.97%
# Epoch 333: iteration 106/107
# Epoch 333 --- loss:0.043, Epoch accuracy:98.31%, Validation loss:1.576, Validation accuracy:66.20%
# Epoch 334: iteration 106/107
# Epoch 334 --- loss:0.032, Epoch accuracy:98.69%, Validation loss:1.586, Validation accuracy:66.20%
# Epoch 335: iteration 106/107
# Epoch 335 --- loss:0.035, Epoch accuracy:98.72%, Validation loss:1.588, Validation accuracy:68.53%
# Epoch 336: iteration 106/107
# Epoch 336 --- loss:0.041, Epoch accuracy:98.31%, Validation loss:1.841, Validation accuracy:65.27%
# Epoch 337: iteration 106/107
# Epoch 337 --- loss:0.051, Epoch accuracy:98.05%, Validation loss:1.649, Validation accuracy:67.37%
# Epoch 338: iteration 106/107
# Epoch 338 --- loss:0.022, Epoch accuracy:99.22%, Validation loss:1.733, Validation accuracy:67.13%
# Epoch 339: iteration 106/107
# Epoch 339 --- loss:0.062, Epoch accuracy:97.44%, Validation loss:1.566, Validation accuracy:66.67%
# Epoch 340: iteration 106/107
# Epoch 340 --- loss:0.084, Epoch accuracy:96.83%, Validation loss:1.626, Validation accuracy:69.23%
# Epoch 341: iteration 106/107
# Epoch 341 --- loss:0.050, Epoch accuracy:98.05%, Validation loss:1.536, Validation accuracy:70.40%
# Epoch 342: iteration 106/107
# Epoch 342 --- loss:0.041, Epoch accuracy:98.34%, Validation loss:1.590, Validation accuracy:69.46%
# Epoch 343: iteration 106/107
# Epoch 343 --- loss:0.047, Epoch accuracy:97.99%, Validation loss:1.565, Validation accuracy:72.03%
# Epoch 344: iteration 106/107
# Epoch 344 --- loss:0.025, Epoch accuracy:99.04%, Validation loss:1.589, Validation accuracy:70.63%
# Epoch 345: iteration 106/107
# Epoch 345 --- loss:0.039, Epoch accuracy:98.23%, Validation loss:1.624, Validation accuracy:68.53%
# Epoch 346: iteration 106/107
# Epoch 346 --- loss:0.071, Epoch accuracy:97.18%, Validation loss:1.724, Validation accuracy:66.67%
# Epoch 347: iteration 106/107
# Epoch 347 --- loss:0.033, Epoch accuracy:98.66%, Validation loss:1.616, Validation accuracy:67.83%
# Epoch 348: iteration 106/107
# Epoch 348 --- loss:0.040, Epoch accuracy:98.52%, Validation loss:1.578, Validation accuracy:72.26%
# Epoch 349: iteration 106/107
# Epoch 349 --- loss:0.034, Epoch accuracy:98.58%, Validation loss:1.711, Validation accuracy:68.07%
# Epoch 350: iteration 106/107
# Epoch 350 --- loss:0.033, Epoch accuracy:98.72%, Validation loss:1.587, Validation accuracy:69.93%
# Epoch 351: iteration 106/107
# Epoch 351 --- loss:0.024, Epoch accuracy:99.01%, Validation loss:1.626, Validation accuracy:68.30%
# Epoch 352: iteration 106/107
# Epoch 352 --- loss:0.036, Epoch accuracy:98.46%, Validation loss:1.875, Validation accuracy:64.57%
# Epoch 353: iteration 106/107
# Epoch 353 --- loss:0.077, Epoch accuracy:97.01%, Validation loss:1.590, Validation accuracy:69.00%
# Epoch 354: iteration 106/107
# Epoch 354 --- loss:0.026, Epoch accuracy:99.10%, Validation loss:1.507, Validation accuracy:69.70%
# Epoch 355: iteration 106/107
# Epoch 355 --- loss:0.018, Epoch accuracy:99.30%, Validation loss:1.622, Validation accuracy:67.83%
# Epoch 356: iteration 106/107
# Epoch 356 --- loss:0.026, Epoch accuracy:98.87%, Validation loss:1.595, Validation accuracy:72.26%
# Epoch 357: iteration 106/107
# Epoch 357 --- loss:0.018, Epoch accuracy:99.33%, Validation loss:1.590, Validation accuracy:69.00%
# Epoch 358: iteration 106/107
# Epoch 358 --- loss:0.017, Epoch accuracy:99.33%, Validation loss:1.569, Validation accuracy:69.46%
# Epoch 359: iteration 106/107
# Epoch 359 --- loss:0.012, Epoch accuracy:99.45%, Validation loss:1.610, Validation accuracy:67.60%
# Epoch 360: iteration 106/107
# Epoch 360 --- loss:0.016, Epoch accuracy:99.39%, Validation loss:1.589, Validation accuracy:71.56%
# Epoch 361: iteration 106/107
# Epoch 361 --- loss:0.017, Epoch accuracy:99.22%, Validation loss:1.557, Validation accuracy:69.70%
# Epoch 362: iteration 106/107
# Epoch 362 --- loss:0.030, Epoch accuracy:98.84%, Validation loss:1.659, Validation accuracy:67.60%
# Epoch 363: iteration 106/107
# Epoch 363 --- loss:0.027, Epoch accuracy:98.84%, Validation loss:1.700, Validation accuracy:67.13%
# Epoch 364: iteration 106/107
# Epoch 364 --- loss:0.048, Epoch accuracy:98.31%, Validation loss:1.593, Validation accuracy:70.16%
# Epoch 365: iteration 106/107
# Epoch 365 --- loss:0.042, Epoch accuracy:98.40%, Validation loss:1.635, Validation accuracy:65.27%
# Epoch 366: iteration 106/107
# Epoch 366 --- loss:0.039, Epoch accuracy:98.37%, Validation loss:1.785, Validation accuracy:67.83%
# Epoch 367: iteration 106/107
# Epoch 367 --- loss:0.052, Epoch accuracy:97.99%, Validation loss:1.643, Validation accuracy:66.67%
# Epoch 368: iteration 106/107
# Epoch 368 --- loss:0.040, Epoch accuracy:98.55%, Validation loss:1.505, Validation accuracy:68.07%
# Epoch 369: iteration 106/107
# Epoch 369 --- loss:0.024, Epoch accuracy:99.19%, Validation loss:1.483, Validation accuracy:70.40%
# Epoch 370: iteration 106/107
# Epoch 370 --- loss:0.021, Epoch accuracy:99.13%, Validation loss:1.547, Validation accuracy:69.23%
# Epoch 371: iteration 106/107
# Epoch 371 --- loss:0.031, Epoch accuracy:98.78%, Validation loss:1.572, Validation accuracy:65.27%
# Epoch 372: iteration 106/107
# Epoch 372 --- loss:0.061, Epoch accuracy:97.30%, Validation loss:1.546, Validation accuracy:70.40%
# Epoch 373: iteration 106/107
# Epoch 373 --- loss:0.050, Epoch accuracy:97.88%, Validation loss:1.605, Validation accuracy:68.30%
# Epoch 374: iteration 106/107
# Epoch 374 --- loss:0.032, Epoch accuracy:98.84%, Validation loss:1.620, Validation accuracy:69.46%
# Epoch 375: iteration 106/107
# Epoch 375 --- loss:0.029, Epoch accuracy:98.84%, Validation loss:1.690, Validation accuracy:66.43%
# Epoch 376: iteration 106/107
# ...
# Epoch 1377: iteration 106/107
# Epoch 1377 --- loss:0.065, Epoch accuracy:97.41%, Validation loss:1.726, Validation accuracy:69.23%
# Epoch 1378: iteration 106/107
# Epoch 1378 --- loss:0.022, Epoch accuracy:99.01%, Validation loss:1.664, Validation accuracy:68.53%
# Epoch 1379: iteration 106/107
# Epoch 1379 --- loss:0.013, Epoch accuracy:99.33%, Validation loss:1.679, Validation accuracy:68.76%
# Epoch 1380: iteration 106/107
# Epoch 1380 --- loss:0.032, Epoch accuracy:98.69%, Validation loss:1.571, Validation accuracy:70.63%
# Epoch 1381: iteration 106/107
# Epoch 1381 --- loss:0.053, Epoch accuracy:97.85%, Validation loss:1.608, Validation accuracy:68.53%
# Epoch 1382: iteration 106/107
# Epoch 1382 --- loss:0.019, Epoch accuracy:99.07%, Validation loss:1.690, Validation accuracy:69.46%
# Epoch 1383: iteration 106/107
# Epoch 1383 --- loss:0.021, Epoch accuracy:99.07%, Validation loss:1.856, Validation accuracy:65.50%
# Epoch 1384: iteration 106/107
# Epoch 1384 --- loss:0.026, Epoch accuracy:99.01%, Validation loss:1.725, Validation accuracy:65.03%
# Epoch 1385: iteration 106/107
# Epoch 1385 --- loss:0.023, Epoch accuracy:99.01%, Validation loss:1.662, Validation accuracy:69.00%
# Epoch 1386: iteration 106/107
# Epoch 1386 --- loss:0.015, Epoch accuracy:99.27%, Validation loss:1.723, Validation accuracy:68.30%
# Epoch 1387: iteration 106/107
# Epoch 1387 --- loss:0.016, Epoch accuracy:99.19%, Validation loss:1.767, Validation accuracy:67.13%
# Epoch 1388: iteration 106/107
# Epoch 1388 --- loss:0.013, Epoch accuracy:99.30%, Validation loss:1.683, Validation accuracy:69.93%
# Epoch 1389: iteration 106/107
# Epoch 1389 --- loss:0.009, Epoch accuracy:99.45%, Validation loss:1.638, Validation accuracy:68.30%
# Epoch 1390: iteration 106/107
# Epoch 1390 --- loss:0.011, Epoch accuracy:99.39%, Validation loss:1.708, Validation accuracy:69.00%
# Epoch 1391: iteration 106/107
# Epoch 1391 --- loss:0.009, Epoch accuracy:99.42%, Validation loss:1.681, Validation accuracy:66.90%
# Epoch 1392: iteration 106/107
# Epoch 1392 --- loss:0.040, Epoch accuracy:98.23%, Validation loss:2.347, Validation accuracy:59.44%
# Epoch 1393: iteration 106/107
# Epoch 1393 --- loss:0.114, Epoch accuracy:95.32%, Validation loss:1.840, Validation accuracy:65.73%
# Epoch 1394: iteration 106/107
# Epoch 1394 --- loss:0.034, Epoch accuracy:98.61%, Validation loss:1.670, Validation accuracy:67.60%
# Epoch 1395: iteration 106/107
# Epoch 1395 --- loss:0.018, Epoch accuracy:99.24%, Validation loss:1.579, Validation accuracy:69.70%
# Epoch 1396: iteration 106/107
# Epoch 1396 --- loss:0.012, Epoch accuracy:99.36%, Validation loss:1.602, Validation accuracy:67.37%
# Epoch 1397: iteration 106/107
# Epoch 1397 --- loss:0.011, Epoch accuracy:99.39%, Validation loss:1.621, Validation accuracy:68.53%
# Epoch 1398: iteration 106/107
# Epoch 1398 --- loss:0.025, Epoch accuracy:98.92%, Validation loss:1.579, Validation accuracy:70.16%
# Epoch 1399: iteration 106/107
# Epoch 1399 --- loss:0.009, Epoch accuracy:99.51%, Validation loss:1.619, Validation accuracy:70.16%
# Epoch 1400: iteration 106/107
# Epoch 1400 --- loss:0.010, Epoch accuracy:99.42%, Validation loss:1.620, Validation accuracy:69.70%
# Epoch 1401: iteration 106/107
# Epoch 1401 --- loss:0.009, Epoch accuracy:99.48%, Validation loss:1.680, Validation accuracy:70.40%
# Epoch 1402: iteration 106/107
# Epoch 1402 --- loss:0.010, Epoch accuracy:99.42%, Validation loss:1.596, Validation accuracy:71.10%
# Epoch 1403: iteration 106/107
# Epoch 1403 --- loss:0.015, Epoch accuracy:99.13%, Validation loss:1.740, Validation accuracy:69.00%
# Epoch 1404: iteration 106/107
# Epoch 1404 --- loss:0.033, Epoch accuracy:98.69%, Validation loss:1.629, Validation accuracy:66.43%
# Epoch 1405: iteration 106/107
# Epoch 1405 --- loss:0.020, Epoch accuracy:99.13%, Validation loss:1.741, Validation accuracy:70.63%
# Epoch 1406: iteration 106/107
# Epoch 1406 --- loss:0.018, Epoch accuracy:99.22%, Validation loss:1.636, Validation accuracy:72.49%
# Epoch 1407: iteration 106/107
# Epoch 1407 --- loss:0.027, Epoch accuracy:98.72%, Validation loss:1.777, Validation accuracy:65.97%
# Epoch 1408: iteration 106/107
# Epoch 1408 --- loss:0.070, Epoch accuracy:97.36%, Validation loss:1.732, Validation accuracy:69.46%
# Epoch 1409: iteration 106/107
# Epoch 1409 --- loss:0.025, Epoch accuracy:98.81%, Validation loss:1.752, Validation accuracy:70.16%
# Epoch 1410: iteration 106/107
# Epoch 1410 --- loss:0.029, Epoch accuracy:98.58%, Validation loss:1.771, Validation accuracy:68.76%
# Epoch 1411: iteration 106/107
# Epoch 1411 --- loss:0.071, Epoch accuracy:97.06%, Validation loss:2.016, Validation accuracy:65.73%
# Epoch 1412: iteration 106/107
# Epoch 1412 --- loss:0.050, Epoch accuracy:97.88%, Validation loss:1.749, Validation accuracy:66.20%
# Epoch 1413: iteration 106/107
# Epoch 1413 --- loss:0.035, Epoch accuracy:98.55%, Validation loss:1.755, Validation accuracy:68.53%
# Epoch 1414: iteration 106/107
# Epoch 1414 --- loss:0.025, Epoch accuracy:98.90%, Validation loss:1.729, Validation accuracy:70.40%
# Epoch 1415: iteration 106/107
# Epoch 1415 --- loss:0.012, Epoch accuracy:99.45%, Validation loss:1.726, Validation accuracy:67.13%
# Epoch 1416: iteration 106/107
# Epoch 1416 --- loss:0.016, Epoch accuracy:99.27%, Validation loss:1.684, Validation accuracy:70.40%
# Epoch 1417: iteration 106/107
# Epoch 1417 --- loss:0.017, Epoch accuracy:99.16%, Validation loss:1.748, Validation accuracy:68.76%
# Epoch 1418: iteration 106/107
# Epoch 1418 --- loss:0.035, Epoch accuracy:98.40%, Validation loss:1.703, Validation accuracy:64.57%
# Epoch 1419: iteration 106/107
# Epoch 1419 --- loss:0.020, Epoch accuracy:99.10%, Validation loss:1.663, Validation accuracy:69.00%
# Epoch 1420: iteration 106/107
# Epoch 1420 --- loss:0.015, Epoch accuracy:99.42%, Validation loss:1.682, Validation accuracy:69.23%
# Epoch 1421: iteration 106/107
# Epoch 1421 --- loss:0.041, Epoch accuracy:98.29%, Validation loss:1.727, Validation accuracy:68.30%
# Epoch 1422: iteration 106/107
# Epoch 1422 --- loss:0.024, Epoch accuracy:99.01%, Validation loss:1.650, Validation accuracy:70.63%
# Epoch 1423: iteration 106/107
# Epoch 1423 --- loss:0.018, Epoch accuracy:99.13%, Validation loss:1.676, Validation accuracy:69.46%
# Epoch 1424: iteration 106/107
# Epoch 1424 --- loss:0.014, Epoch accuracy:99.39%, Validation loss:1.756, Validation accuracy:68.76%
# Epoch 1425: iteration 106/107
# Epoch 1425 --- loss:0.011, Epoch accuracy:99.45%, Validation loss:1.670, Validation accuracy:69.46%
# Epoch 1426: iteration 106/107
# Epoch 1426 --- loss:0.051, Epoch accuracy:97.76%, Validation loss:2.135, Validation accuracy:62.00%
# Epoch 1427: iteration 106/107
# Epoch 1427 --- loss:0.039, Epoch accuracy:98.52%, Validation loss:1.714, Validation accuracy:67.37%
# Epoch 1428: iteration 106/107
# Epoch 1428 --- loss:0.038, Epoch accuracy:98.40%, Validation loss:1.817, Validation accuracy:66.43%
# Epoch 1429: iteration 106/107
# Epoch 1429 --- loss:0.035, Epoch accuracy:98.55%, Validation loss:1.823, Validation accuracy:66.20%
# Epoch 1430: iteration 106/107
# Epoch 1430 --- loss:0.035, Epoch accuracy:98.55%, Validation loss:1.810, Validation accuracy:68.30%
# Epoch 1431: iteration 106/107
# Epoch 1431 --- loss:0.022, Epoch accuracy:99.07%, Validation loss:1.852, Validation accuracy:63.64%
# Epoch 1432: iteration 106/107
# Epoch 1432 --- loss:0.038, Epoch accuracy:98.55%, Validation loss:1.696, Validation accuracy:68.76%
# Epoch 1433: iteration 106/107
# Epoch 1433 --- loss:0.015, Epoch accuracy:99.30%, Validation loss:1.666, Validation accuracy:69.00%
# Epoch 1434: iteration 106/107
# Epoch 1434 --- loss:0.010, Epoch accuracy:99.42%, Validation loss:1.688, Validation accuracy:68.30%
# Epoch 1435: iteration 106/107
# Epoch 1435 --- loss:0.010, Epoch accuracy:99.42%, Validation loss:1.563, Validation accuracy:69.46%
# Epoch 1436: iteration 106/107
# Epoch 1436 --- loss:0.034, Epoch accuracy:98.52%, Validation loss:1.760, Validation accuracy:67.83%
# Epoch 1437: iteration 106/107
# Epoch 1437 --- loss:0.020, Epoch accuracy:99.01%, Validation loss:1.808, Validation accuracy:68.07%
# Epoch 1438: iteration 106/107
# Epoch 1438 --- loss:0.027, Epoch accuracy:98.92%, Validation loss:1.732, Validation accuracy:68.76%
# Epoch 1439: iteration 106/107
# Epoch 1439 --- loss:0.063, Epoch accuracy:97.56%, Validation loss:1.583, Validation accuracy:70.40%
# Epoch 1440: iteration 106/107
# Epoch 1440 --- loss:0.019, Epoch accuracy:99.10%, Validation loss:1.643, Validation accuracy:69.93%
# Epoch 1441: iteration 106/107
# Epoch 1441 --- loss:0.062, Epoch accuracy:97.47%, Validation loss:1.656, Validation accuracy:67.83%
# Epoch 1442: iteration 106/107
# Epoch 1442 --- loss:0.041, Epoch accuracy:98.26%, Validation loss:1.676, Validation accuracy:65.50%
# Epoch 1443: iteration 106/107
# Epoch 1443 --- loss:0.030, Epoch accuracy:98.72%, Validation loss:1.705, Validation accuracy:68.07%
# Epoch 1444: iteration 106/107
# Epoch 1444 --- loss:0.015, Epoch accuracy:99.22%, Validation loss:1.922, Validation accuracy:64.57%
# Epoch 1445: iteration 106/107
# Epoch 1445 --- loss:0.075, Epoch accuracy:97.18%, Validation loss:1.771, Validation accuracy:67.13%
# Epoch 1446: iteration 106/107
# Epoch 1446 --- loss:0.030, Epoch accuracy:98.84%, Validation loss:1.778, Validation accuracy:68.07%
# Epoch 1447: iteration 106/107
# Epoch 1447 --- loss:0.026, Epoch accuracy:98.98%, Validation loss:1.640, Validation accuracy:70.16%
# Epoch 1448: iteration 106/107
# Epoch 1448 --- loss:0.012, Epoch accuracy:99.42%, Validation loss:1.589, Validation accuracy:69.23%
# Epoch 1449: iteration 106/107
# Epoch 1449 --- loss:0.016, Epoch accuracy:99.27%, Validation loss:1.833, Validation accuracy:65.27%
# Epoch 1450: iteration 106/107
# Epoch 1450 --- loss:0.021, Epoch accuracy:99.07%, Validation loss:1.861, Validation accuracy:68.30%
# Epoch 1451: iteration 106/107
# Epoch 1451 --- loss:0.029, Epoch accuracy:98.66%, Validation loss:1.580, Validation accuracy:71.33%
# Epoch 1452: iteration 106/107
# Epoch 1452 --- loss:0.049, Epoch accuracy:97.79%, Validation loss:1.577, Validation accuracy:69.70%
# Epoch 1453: iteration 106/107
# Epoch 1453 --- loss:0.048, Epoch accuracy:98.26%, Validation loss:1.695, Validation accuracy:69.00%
# Epoch 1454: iteration 106/107
# Epoch 1454 --- loss:0.033, Epoch accuracy:98.55%, Validation loss:1.760, Validation accuracy:69.70%
# Epoch 1455: iteration 106/107
# Epoch 1455 --- loss:0.023, Epoch accuracy:99.04%, Validation loss:1.817, Validation accuracy:68.30%
# Epoch 1456: iteration 106/107
# Epoch 1456 --- loss:0.017, Epoch accuracy:99.16%, Validation loss:1.695, Validation accuracy:70.86%
# Epoch 1457: iteration 106/107
# Epoch 1457 --- loss:0.018, Epoch accuracy:99.24%, Validation loss:1.666, Validation accuracy:68.76%
# Epoch 1458: iteration 106/107
# Epoch 1458 --- loss:0.017, Epoch accuracy:99.27%, Validation loss:1.781, Validation accuracy:68.07%
# Epoch 1459: iteration 106/107
# Epoch 1459 --- loss:0.016, Epoch accuracy:99.27%, Validation loss:1.870, Validation accuracy:66.20%
# Epoch 1460: iteration 106/107
# Epoch 1460 --- loss:0.027, Epoch accuracy:98.69%, Validation loss:1.836, Validation accuracy:68.53%
# Epoch 1461: iteration 106/107
# Epoch 1461 --- loss:0.026, Epoch accuracy:98.81%, Validation loss:1.749, Validation accuracy:66.90%
# Epoch 1462: iteration 106/107
# Epoch 1462 --- loss:0.024, Epoch accuracy:98.92%, Validation loss:1.608, Validation accuracy:70.16%
# Epoch 1463: iteration 106/107
# Epoch 1463 --- loss:0.011, Epoch accuracy:99.45%, Validation loss:1.634, Validation accuracy:71.10%
# Epoch 1464: iteration 106/107
# Epoch 1464 --- loss:0.014, Epoch accuracy:99.22%, Validation loss:1.711, Validation accuracy:68.76%
# Epoch 1465: iteration 106/107
# Epoch 1465 --- loss:0.033, Epoch accuracy:98.46%, Validation loss:1.710, Validation accuracy:65.97%
# Epoch 1466: iteration 106/107
# Epoch 1466 --- loss:0.055, Epoch accuracy:97.50%, Validation loss:1.953, Validation accuracy:63.87%
# Epoch 1467: iteration 106/107
# Epoch 1467 --- loss:0.023, Epoch accuracy:98.95%, Validation loss:1.822, Validation accuracy:67.60%
# Epoch 1468: iteration 106/107
# Epoch 1468 --- loss:0.024, Epoch accuracy:98.87%, Validation loss:1.707, Validation accuracy:68.76%
# Epoch 1469: iteration 106/107
# Epoch 1469 --- loss:0.015, Epoch accuracy:99.24%, Validation loss:1.727, Validation accuracy:68.76%
# Epoch 1470: iteration 106/107
# Epoch 1470 --- loss:0.011, Epoch accuracy:99.36%, Validation loss:1.701, Validation accuracy:70.86%
# Epoch 1471: iteration 106/107
# Epoch 1471 --- loss:0.006, Epoch accuracy:99.51%, Validation loss:1.706, Validation accuracy:70.16%
# Epoch 1472: iteration 106/107
# Epoch 1472 --- loss:0.010, Epoch accuracy:99.45%, Validation loss:1.623, Validation accuracy:71.33%
# Epoch 1473: iteration 106/107
# Epoch 1473 --- loss:0.045, Epoch accuracy:98.02%, Validation loss:1.798, Validation accuracy:69.00%
# Epoch 1474: iteration 106/107
# Epoch 1474 --- loss:0.049, Epoch accuracy:97.85%, Validation loss:1.790, Validation accuracy:65.27%
# Epoch 1475: iteration 106/107
# Epoch 1475 --- loss:0.027, Epoch accuracy:98.90%, Validation loss:1.630, Validation accuracy:68.76%
# Epoch 1476: iteration 106/107
# Epoch 1476 --- loss:0.018, Epoch accuracy:99.19%, Validation loss:1.768, Validation accuracy:68.07%
# Epoch 1477: iteration 106/107
# Epoch 1477 --- loss:0.011, Epoch accuracy:99.39%, Validation loss:1.745, Validation accuracy:67.13%
# Epoch 1478: iteration 106/107
# Epoch 1478 --- loss:0.023, Epoch accuracy:98.87%, Validation loss:1.688, Validation accuracy:69.00%
# Epoch 1479: iteration 106/107
# Epoch 1479 --- loss:0.015, Epoch accuracy:99.19%, Validation loss:1.754, Validation accuracy:68.76%
# Epoch 1480: iteration 106/107
# Epoch 1480 --- loss:0.015, Epoch accuracy:99.19%, Validation loss:1.806, Validation accuracy:68.07%
# Epoch 1481: iteration 106/107
# Epoch 1481 --- loss:0.013, Epoch accuracy:99.42%, Validation loss:1.772, Validation accuracy:68.76%
# Epoch 1482: iteration 106/107
# Epoch 1482 --- loss:0.020, Epoch accuracy:99.10%, Validation loss:1.674, Validation accuracy:70.16%
# Epoch 1483: iteration 106/107
# Epoch 1483 --- loss:0.017, Epoch accuracy:99.19%, Validation loss:1.784, Validation accuracy:67.83%
# Epoch 1484: iteration 106/107
# Epoch 1484 --- loss:0.011, Epoch accuracy:99.36%, Validation loss:1.745, Validation accuracy:66.67%
# Epoch 1485: iteration 106/107
# Epoch 1485 --- loss:0.041, Epoch accuracy:98.11%, Validation loss:1.755, Validation accuracy:67.83%
# Epoch 1486: iteration 106/107
# Epoch 1486 --- loss:0.039, Epoch accuracy:98.31%, Validation loss:1.824, Validation accuracy:67.37%
# Epoch 1487: iteration 106/107
# Epoch 1487 --- loss:0.047, Epoch accuracy:97.99%, Validation loss:1.815, Validation accuracy:65.97%
# Epoch 1488: iteration 106/107
# Epoch 1488 --- loss:0.029, Epoch accuracy:98.95%, Validation loss:1.632, Validation accuracy:69.70%
# Epoch 1489: iteration 106/107
# Epoch 1489 --- loss:0.018, Epoch accuracy:99.19%, Validation loss:1.705, Validation accuracy:67.60%
# Epoch 1490: iteration 106/107
# Epoch 1490 --- loss:0.014, Epoch accuracy:99.27%, Validation loss:1.606, Validation accuracy:68.53%
# Epoch 1491: iteration 106/107
# Epoch 1491 --- loss:0.017, Epoch accuracy:99.22%, Validation loss:1.674, Validation accuracy:70.40%
# Epoch 1492: iteration 106/107
# Epoch 1492 --- loss:0.032, Epoch accuracy:98.63%, Validation loss:1.711, Validation accuracy:64.80%
# Epoch 1493: iteration 106/107
# Epoch 1493 --- loss:0.047, Epoch accuracy:98.08%, Validation loss:2.006, Validation accuracy:60.37%
# Epoch 1494: iteration 106/107
# Epoch 1494 --- loss:0.032, Epoch accuracy:98.66%, Validation loss:1.862, Validation accuracy:66.20%
# Epoch 1495: iteration 106/107
# Epoch 1495 --- loss:0.040, Epoch accuracy:98.26%, Validation loss:1.718, Validation accuracy:68.07%
# Epoch 1496: iteration 106/107
# Epoch 1496 --- loss:0.056, Epoch accuracy:97.79%, Validation loss:1.751, Validation accuracy:66.20%
# Epoch 1497: iteration 106/107
# Epoch 1497 --- loss:0.035, Epoch accuracy:98.58%, Validation loss:1.715, Validation accuracy:69.70%
# Epoch 1498: iteration 106/107
# Epoch 1498 --- loss:0.024, Epoch accuracy:98.92%, Validation loss:1.725, Validation accuracy:68.76%
# Epoch 1499: iteration 106/107
# Epoch 1499 --- loss:0.022, Epoch accuracy:98.95%, Validation loss:1.675, Validation accuracy:67.60%

# %% [markdown]
# # Check the Loss Curve's Behaviour
# Let's see if we missed something egregious during training. Note that validation sets achieved 78-82% accuracy depending on the random split of data (checked after tuning; random seed was specified before splitting data while tuning the model).

# %%
plt.title('Loss Curve for parallel_cnn_Transformer Model')
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(train_losses[:],'b')
plt.plot(valid_losses[:],'r')
plt.legend(['Training loss','Validation loss'])
plt.show()

# %% [markdown]
# Looks good. Past about 78% validation accuracy, the model begins to overfit on the training set. Note that I ran the final model longer than necessary (500 epochs/20 minutes, vs the 200 epochs/8 minutes it takes to train to convergence as trained on a K80 from Google Colab).

# %% [markdown]
# # Load the Trained Model from Checkpoint for Evaluation

# %%
# pick load folder
load_folder = '/content/gdrive/My Drive/DL/models/checkpoints'

# pick the epoch to load
epoch = '429'
model_name = f'model_final.pkl'

# make full load path
load_path = os.path.join(load_folder, model_name)

## instantiate empty model and populate with params from binary
model = parallel_cnn_Transformer(len(emotions_dict)).to(device)
load_checkpoint(optimizer, model, load_path)

print(f'Loaded model from {load_path}')
# Out:
# Loaded model from /content/gdrive/My Drive/DL/models/checkpoints/model_final.pkl

# %% [markdown]
# # Evaluate the Model on Hold-Out Test Set
# Fingers crossed for generalizability.

# %%
# reinitialize validation function with model from chosen checkpoint
validate = make_validate_fnc(model,criterion)

# Convert 4D test feature set array to tensor and move to GPU
X_test_tensor = torch.tensor(X_test,device=device).float()
# Convert 4D test label set array to tensor and move to GPU
y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)

# Get the model's performance metrics using the validation function we defined
test_loss, test_acc, predicted_emotions = validate(X_test_tensor,y_test_tensor)

print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test accuracy is 68.00%

# %% [markdown]
# Not too shabby. Past epoch 200, test accuracy is between 75-80%; past epoch 400, test accuracy is between 77-80%; the final few epochs' test accuracy is between 78-80% - so there is a marginal amount of learning going on at the very end.
#
# For some reference points: **[A May 2020 paper](https://www.sciencedirect.com/science/article/abs/pii/S1746809420300501) claims to have achieved a "new SOTA" on RAVDESS speech audio with 71.61% accuracy on 8 emotions**, while [another May 2020 paper](https://ieeexplore.ieee.org/document/9122698) claims to have achieved the "new SOTA" with an 90% F1 score on 8 emotions. Both use CNN architectures. However, the paper reporting 90% F1 score is inflated by testing on training samples: [See the GitHub issue on this paper.](https://github.com/marcogdepinto/emotion-classification-from-audio-files/issues/11)
#
# From the author with a 90% score: _"Also, the previous versions of this work used audio features extracted from the videos of the RAVDESS dataset. This particular part of the pipeline has been removed because it was shuffling very similar files in the training and test sets, boosting accuracy of the model as a consequence (overfitting)."_
#
# The author has augmented the RAVDESS speech audio dataset with speech extracted from video data from RAVDESS - so the **dataset with 90% accuracy contained duplicate samples _before_ being split into training and test sets, causing leakage of test samples into the training set.** For reference, I achieved a 97% accuracy with my model when I similarly augmented the dataset with duplicate speech audio before splitting data. **I corrected this data-leakage issue by augmenting data only _after_ splitting into train/validation/test sets.**
#
# This is an excellent example of "if it's too good to be true". More conservative estimates are more likely to be reproducible, in my opinion.

# %% [markdown]
# # Analyze Performance on Test Set

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

# because model tested on GPU, move prediction tensor to CPU then convert to array
predicted_emotions = predicted_emotions.cpu().numpy()
# use labels from test set
emotions_groundtruth = y_test

# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

# set labels for matrix axes from emotions
emotion_names = [emotion for emotion in emotions_dict.values()]

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

plt.show()
